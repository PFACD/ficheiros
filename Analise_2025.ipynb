# %% [markdown]
# # Projeto Final Aplicado a Ciência de Dados
# ## Deteção de Outliers em Contratos Públicos e Previsão do Montante de Adjudição
#
# ## Grupo 08
# ## Membros:
# ###          - Afonso Alexandre nº 123425;
# ###          - André  Freitas nº 123409;
# ###          - Gonçalo Vilhena nº 123384;
# ###          - Rodolfo Nardy nº 123419

# %% [markdown]
# #### **Reading and checking data**

# %%
import pandas as pd

# %%
#Diretório onde os arquivos de dados do trabalho estão armazenados
data_dir = "./dados/"
df_2025 = pd.read_excel(data_dir + "contratos2025.xlsx")

# %% [markdown]
# ## Análise
#
#
# ### Funções auxiliares
#
# #### Função para os top X valores mais frequentes

# %%
def print_top_n(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate the top 'n' most frequent values
    top_n_values = df[column_name].value_counts().head(top_n)

    # Print the top 'n' values
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para os top X valores mais frequentes numa lista

# %%
def print_top_n_list(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Explode the lists into separate rows
    exploded = df[column_name].explode()

    # Calculate the top 'n' most frequent individual values
    top_n_values = exploded.value_counts().head(top_n)

    # Print the results
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para mostras os X menores valores menos frequentes

# %%
def print_bottom_n(df, column_name, bottom_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts and get the bottom 'n' values
    bottom_n_values = df[column_name].value_counts().sort_values(ascending=True).head(bottom_n)

    # Print the bottom 'n' values
    print(f"Bottom {bottom_n} least frequent values for '{column_name}':")

    print(bottom_n_values)

# %% [markdown]
#  #### Função para mostrar  X menores valores menos frequentes numa lista

# %% [markdown]
# #### Function to count null and empty values

# %%
def count_null_and_empty(df, column_name):
    total = len(df)

    # Count NaN (null) values
    null_count = df[column_name].isna().sum()
    null_pct = (null_count / total) * 100

    # Count empty string values (after stripping whitespace)
    empty_count = (df[column_name].astype(str).str.strip() == '').sum()
    empty_pct = (empty_count / total) * 100

    # Print results
    print(f"Null (NaN) values: {null_count} ({null_pct:.2f}%)")
    print(f"Empty string values: {empty_count} ({empty_pct:.2f}%)")

# %% [markdown]
# #### Informações gerais do ficheiro

# %%
df_2025.info()
df_2025.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 237180 entries, 0 to 237179
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                237180 non-null  int64
#  1   nAnuncio                  38050 non-null   str
#  2   TipoAnuncio               38050 non-null   str
#  3   idINCM                    38050 non-null   float64
#  4   tipoContrato              237180 non-null  str
#  5   idprocedimento            237180 non-null  int64
#  6   tipoprocedimento          237180 non-null  str
#  7   objectoContrato           237179 non-null  object
#  8   descContrato              237180 non-null  object
#  9   adjudicante               237180 non-null  str
#  10  adjudicatarios            237108 non-null  str
#  11  dataPublicacao            237180 non-null  datetime64[us]
#  12  dataCelebracaoContrato    236168 non-null  datetime64[us]
# ...

# %% [markdown]
# #### idcontrato (int64)

# %%
count_null_and_empty(df_2025, 'idcontrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
#não há repetidos
print_top_n(df_2025,"idcontrato",10)
# Out:
# Top 10 most frequent values for 'idcontrato':
# idcontrato
# 11158565    2
# 10855918    1
# 11122654    1
# 11122754    1
# 11122816    1
# 11122840    1
# 11122911    1
# 11103352    1
# 11104095    1
# 11106599    1
# Name: count, dtype: int64

# %% [markdown]
# #### tipoContrato (object)

# %%
count_null_and_empty(df_2025, 'tipoContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n_list(df_2025,"tipoContrato",10)
df_2025['tipoContrato'].unique()
# Out:
# Top 10 most frequent values for 'tipoContrato':
# tipoContrato
# Aquisição de bens móveis                            120733
# Aquisição de serviços                                95652
# Empreitadas de obras públicas                        15491
# Locação de bens móveis                                3149
# Aquisição de bens móveis\nAquisição de serviços       1445
# Aquisição de serviços\nLocação de bens móveis          185
# Concessão de serviços públicos                         152
# Aquisição de bens móveis\nLocação de bens móveis        82
# Concessão de obras públicas                             80
# Outros                                                  48
# Name: count, dtype: int64
# <StringArray>
# [                                                           'Aquisição de serviços',
#                                                          'Aquisição de bens móveis',
#                                                            'Locação de bens móveis',
# ...

# %% [markdown]
# #### idProcedimento (int64)

# %%
count_null_and_empty(df_2025, 'idprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025,"idprocedimento",10)
# Out:
# Top 10 most frequent values for 'idprocedimento':
# idprocedimento
# 7474261    503
# 7468015    472
# 7462678    420
# 7330046    345
# 7436773    293
# 7448320    283
# 7492522    242
# 7538649    240
# 7459975    237
# 7492572    234
# Name: count, dtype: int64

# %% [markdown]
# #### tipoprocedimento

# %%
count_null_and_empty(df_2025, 'tipoprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025,"tipoprocedimento",10)  #(nem ha 10)
# Out:
# Top 10 most frequent values for 'tipoprocedimento':
# tipoprocedimento
# Ajuste Direto Regime Geral                                           106876
# Consulta Prévia                                                       40751
# Concurso público                                                      37642
# Ao abrigo de acordo-quadro (art.º 259.º)                              29389
# Contratação excluída II                                               12552
# Ao abrigo de acordo-quadro (art.º 258.º)                               6289
# Setores especiais – isenção parte II                                   1366
# Ajuste direto simplificado ao abrigo da Lei n.º 30/2021, de 21.05      1011
# Concurso limitado por prévia qualificação                               677
# Consulta Prévia Simplificada                                            531
# Name: count, dtype: int64

# %% [markdown]
# #### objectoContrato

# %%
count_null_and_empty(df_2025, 'objectoContrato')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025,"objectoContrato",20)
# Out:
# Top 20 most frequent values for 'objectoContrato':
# objectoContrato
# ...

# %% [markdown]
# #### descContrato (object)

# %%
count_null_and_empty(df_2025, 'descContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025,"descContrato",20)
#df_2025[df_2025["descContrato"] == "Contrato de empreitada"]
# Out:
# Top 20 most frequent values for 'descContrato':
# descContrato
# Medicamentos                                                                                                                                                                                                2138
# Aquisição de serviço de viagens e alojamento – Plataforma SIAV                                                                                                                                               901
# Consulta Prévia ao abrigo do acordo-quadro da ESPAP\n                                                                                                                                                        743
# 1413/2025 - Convite à apresentação de propostas ao abrigo do(s) acordo(s)-quadro 2023/304 - Medicamentos do Grupo 4: Sangue ; 2023/491 - Medicamentos do foro oncológico e imunomoduladores e 2023/492 -     483
# ...

# %% [markdown]
# adjudicante (object)

# %%
count_null_and_empty(df_2025, 'adjudicante')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025,"adjudicante",20)
# Out:
# Top 20 most frequent values for 'adjudicante':
# adjudicante
# 506362299 - Instituto Português de Oncologia do Porto Francisco Gentil, E. P. E.    12517
# 508142156 - Unidade Local de Saúde de Gaia/Espinho, E. P. E.                         5702
# 508481287 - Unidade Local de Saúde de Santa Maria, E. P. E.                          4880
# 508080142 - Unidade Local de Saúde de São José, E. P. E.                             3606
# 510103448 - Unidade Local de Saúde de Coimbra, E. P. E.                              3284
# 513606084 - Águas do Norte, S. A.                                                    2783
# 508094461 - Unidade Local de Saúde do Alto Alentejo, E. P. E.                        2662
# 500122237 - Fundação INATEL                                                          1993
# 510745997 - Unidade Local de Saúde do Algarve, E. P. E.                              1969
# 502011378 - Universidade do Minho                                                    1917
# ...

# %% [markdown]
# adjudicatarios (object)

# %%
count_null_and_empty(df_2025, 'adjudicatarios')
# Out:
# Null (NaN) values: 72 (0.03%)
# Empty string values: 0 (0.00%)

# %%
print(df_2025['adjudicatarios'].head(20))
# Out:
# 0                    510763464 - Loop Audiovisual, Lda.
# 1                           500113270 - FERRAZ LYNCE SA
# 2        500906181 - SABSEG - CORRETOR DE SEGUROS, S.A.
# 3                              513185526 - MADMEN, Lda.
# 4      506093190 - Penasegur - Mediação de Seguros, Lda
# 5     513505512 - Prosegur - Logística e Tratamento ...
# 6                                       500326517 - CJR
# 7                  - - ROLLS-ROYCE SOLUTIONS IBERICA SL
# 8          510122639 - AGR - Engenharia e Serviços, Lda
# 9             501445226 - TK Elevadores, Unipessoal Lda
# 10                                  500187916 - Mathias
# 11                                  500187916 - Mathias
# 12             511135610 - ACIN - iCloud Solutions, Lda
# 13                      511060963 - J. Nelson Abreu, SA
# 14                      - - Filomena Guimarães Ferreira
# 15    516774255 - Romag construções e obras publicas...
# 16                        - - TERUMO EUROPE ESPANHA SL
# ...

# %% [markdown]
# dataPublicacao (object)

# %%
count_null_and_empty(df_2025, 'dataPublicacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2025['dataPublicacao'].head(10))
# Out:
# 0   2024-08-06
# 1   2025-01-02
# 2   2025-01-02
# 3   2025-01-02
# 4   2025-01-02
# 5   2025-01-02
# 6   2024-12-23
# 7   2024-12-23
# 8   2024-12-24
# 9   2024-12-30
# Name: dataPublicacao, dtype: datetime64[us]

# %% [markdown]
# dataCelebracaoContrato (object)

# %%
count_null_and_empty(df_2025, 'dataCelebracaoContrato')
# Out:
# Null (NaN) values: 1012 (0.43%)
# Empty string values: 0 (0.00%)

# %%
print(df_2025['dataCelebracaoContrato'].head(10))
# Out:
# 0          NaT
# 1   2025-01-02
# 2   2025-01-02
# 3   2025-01-02
# 4   2025-01-02
# 5   2025-01-01
# 6   2025-04-24
# 7   2025-02-07
# 8   2025-01-14
# 9   2025-01-01
# Name: dataCelebracaoContrato, dtype: datetime64[us]

# %% [markdown]
# precoContratual (float64)

# %%
count_null_and_empty(df_2025, 'precoContratual')
min(df_2025['precoContratual'])
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# -111732.16

# %%
print(df_2025['precoContratual'].head(10))
# Out:
# 0       11500.00
# 1        2158.99
# 2        4173.75
# 3       30000.00
# 4         527.96
# 5        6000.00
# 6    14665084.64
# 7      979644.72
# 8       10776.00
# 9       52511.52
# Name: precoContratual, dtype: float64

# %%
print_top_n(df_2025,'precoContratual',10)
# Out:
# Top 10 most frequent values for 'precoContratual':
# precoContratual
# 10000.0    1050
# 15000.0    1021
# 6000.0      928
# 12000.0     867
# 9000.0      676
# 18000.0     665
# 19500.0     661
# 7500.0      620
# 19900.0     618
# 8000.0      613
# Name: count, dtype: int64

# %% [markdown]
# cpv (object)

# %%
count_null_and_empty(df_2025, 'CPV')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2025['CPV'].head(10))
# Out:
# 0                  79970000-4 - Serviços de publicação
# 1    33622000-6 - Medicamentos para o aparelho card...
# 2        66512100-3 - Serviços de seguros de acidentes
# 3     79340000-9 - Serviços de publicidade e marketing
# 4            66514110-0 - Serviços de seguro automóvel
# 5          42965100-9 - Sistema de gestão de depósitos
# 6                  45233120-6 - Construção de estradas
# 7    50241000-6 - Serviços de reparação e manutençã...
# 8      50000000-5 - Serviços de reparação e manutenção
# 9    50750000-7 - Serviços de manutenção de elevadores
# Name: CPV, dtype: str

# %% [markdown]
# prazoExecucao (int64)

# %%
count_null_and_empty(df_2025, 'prazoExecucao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025, 'prazoExecucao', 10)
# Out:
# Top 10 most frequent values for 'prazoExecucao':
# prazoExecucao
# 365     33239
# 20      21847
# 30      16836
# 1        9979
# 60       7949
# 1096     7729
# 90       6970
# 730      5747
# 5        5704
# 120      3927
# Name: count, dtype: int64

# %%
print_bottom_n(df_2025,'prazoExecucao',10)
# Out:
# Bottom 10 least frequent values for 'prazoExecucao':
# prazoExecucao
# 746      1
# 1473     1
# 1381     1
# 1470     1
# 757      1
# 1157     1
# 825      1
# 1341     1
# 10958    1
# 1049     1
# Name: count, dtype: int64

# %%
max_prazo_valor = df_2025['prazoExecucao'].max()
print("Maximum 'prazoExecucao (dias)':", max_prazo_valor)
print("Maximum 'prazoExecucao (anos)':", max_prazo_valor/365)
#impossível
# Out:
# Maximum 'prazoExecucao (dias)': 739616
# Maximum 'prazoExecucao (anos)': 2026.345205479452

# %% [markdown]
# localExecucao (object)

# %%
count_null_and_empty(df_2025, 'LocalExecucao')
# Out:
# Null (NaN) values: 831 (0.35%)
# Empty string values: 0 (0.00%)

# %%
print(df_2025['LocalExecucao'].head(10))
# Out:
# 0                             Portugal, Lisboa, Lisboa
# 1                             Portugal, Lisboa, Lisboa
# 2    Portugal, Braga, Amares\nPortugal, Braga, Barc...
# 3                               Portugal, Braga, Braga
# 4                   Portugal, Aveiro, Castelo de Paiva
# 5                           Portugal, Leiria, Alcobaça
# 6    Portugal, Porto, Baião\nPortugal, Porto, Marco...
# 7                            Portugal, Setúbal, Almada
# 8                               Portugal, Viseu, Nelas
# 9                                             Portugal
# Name: LocalExecucao, dtype: str

# %% [markdown]
# fundamentacao (object)

# %%
count_null_and_empty(df_2025, 'fundamentacao')
# Out:
# Null (NaN) values: 1013 (0.43%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025, 'fundamentacao', 10)
# Out:
# Top 10 most frequent values for 'fundamentacao':
# fundamentacao
# Artigo 20.º, n.º 1, alínea d) do Código dos Contratos Públicos                    41855
# Artigo 20.º, n.º 1, alínea c) do Código dos Contratos Públicos                    33767
# Artigo 24.º, n.º 1, alínea c) do Código dos Contratos Públicos                    30108
# Artigo 259.º do Código dos Contratos Públicos                                     28526
# Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos                    19026
# Artigo 24.º, n.º 1, alínea e), subalínea ii) do Código dos Contratos Públicos     11624
# Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos                    11370
# artigo 6.º-A n.º 1 do Código dos Contratos Públicos                                8549
# Artigo 24.º, n.º 1, alínea e), subalínea iii) do Código dos Contratos Públicos     7516
# Artigo 258.º do Código dos Contratos Públicos                                      5694
# Name: count, dtype: int64

# %% [markdown]
# ProcedimentoCentralizado (object)

# %%
count_null_and_empty(df_2025, 'ProcedimentoCentralizado')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025, 'ProcedimentoCentralizado', 10)
# Out:
# Top 10 most frequent values for 'ProcedimentoCentralizado':
# ProcedimentoCentralizado
# Não    223408
# Sim     13772
# Name: count, dtype: int64

# %% [markdown]
# DescrAcordoQuadro (object)

# %%
count_null_and_empty(df_2025, 'DescrAcordoQuadro')
# Out:
# Null (NaN) values: 202248 (85.27%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025,"DescrAcordoQuadro",10)
# Out:
# Top 10 most frequent values for 'DescrAcordoQuadro':
# DescrAcordoQuadro
# Acordo Quadro de Viagens e Alojamento                                                                                                                                     5569
# 491/2023 - Concurso público internacional para formação do acordo quadro de medicamentos do foro oncológico e imunomoduladores                                            3422
# 961/2024 - Concurso público internacional para formação do acordo quadro de medicamentos diversos na área da saúde                                                        2248
# 671/2023 - Concurso público internacional para formação do acordo quadro de medicamentos diversos                                                                         1583
# 492/2023 - Concurso público internacional para formação do acordo quadro de medicamentos anti-infeciosos na área da saúde                                                  995
# ...

# %% [markdown]
# precoBaseProcedimento (float64)

# %%
count_null_and_empty(df_2025, 'precoBaseProcedimento')
min(df_2025['precoBaseProcedimento'])
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# -2250.0

# %%
print_top_n(df_2025,"precoBaseProcedimento",10)
# Out:
# Top 10 most frequent values for 'precoBaseProcedimento':
# precoBaseProcedimento
# 0.00         4700
# 15000.00     1292
# 10000.00     1260
# 12000.00     1015
# 6000.00       994
# 402439.02     902
# 20000.00      832
# 50000.00      825
# 18000.00      823
# 30000.00      782
# Name: count, dtype: int64

# %% [markdown]
# dataDecisaoAdjudicacao (object)

# %%
count_null_and_empty(df_2025, 'dataDecisaoAdjudicacao')
# Out:
# Null (NaN) values: 1012 (0.43%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025,"dataDecisaoAdjudicacao",20)
# Out:
# Top 20 most frequent values for 'dataDecisaoAdjudicacao':
# dataDecisaoAdjudicacao
# 2025-01-23    1680
# 2025-01-30    1655
# 2025-02-19    1529
# 2025-03-13    1521
# 2025-03-27    1490
# 2025-02-13    1485
# 2025-02-27    1452
# 2025-04-03    1445
# 2025-04-24    1412
# 2025-03-19    1401
# 2025-02-20    1388
# 2025-03-06    1344
# 2025-02-12    1331
# 2025-01-08    1316
# 2025-07-17    1287
# 2025-02-06    1273
# 2025-01-09    1255
# 2025-05-19    1234
# 2025-03-20    1230
# 2025-10-10    1222
# Name: count, dtype: int64

# %% [markdown]
# dataFechoContrato (object)

# %%
count_null_and_empty(df_2025, 'dataFechoContrato')
# Out:
# Null (NaN) values: 206498 (87.06%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025,"dataFechoContrato",10)
# Out:
# Top 10 most frequent values for 'dataFechoContrato':
# dataFechoContrato
# 2025-12-31    1541
# 2025-12-30     631
# 2025-12-23     542
# 2025-12-29     512
# 2025-12-22     416
# 2025-12-19     388
# 2025-06-30     365
# 2025-12-18     296
# 2025-04-04     284
# 2026-01-22     265
# Name: count, dtype: int64

# %% [markdown]
# PrecoTotalEfetivo

# %%
count_null_and_empty(df_2025, 'PrecoTotalEfetivo')
min(df_2025['PrecoTotalEfetivo'])
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# -3245.2

# %%
print(df_2025['PrecoTotalEfetivo'].head(10))
# Out:
# 0    11500.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4      527.96
# 5     6000.00
# 6        0.00
# 7        0.00
# 8        0.00
# 9        0.00
# Name: PrecoTotalEfetivo, dtype: float64

# %%
print_top_n(df_2025,"PrecoTotalEfetivo",10)
# Out:
# Top 10 most frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 0.0        206927
# 6000.0        158
# 15000.0       143
# 10000.0       142
# 7500.0        120
# 7000.0        117
# 8000.0        110
# 12000.0       107
# 9000.0         98
# 5000.0         86
# Name: count, dtype: int64

# %%
print_bottom_n(df_2025,"PrecoTotalEfetivo",10)
# Out:
# Bottom 10 least frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 17454.56     1
# 7222.50      1
# 76464.00     1
# 43145.12     1
# 231953.00    1
# 5091.18      1
# 9973.27      1
# 11424.00     1
# 5401.70      1
# 144223.84    1
# Name: count, dtype: int64

# %% [markdown]
# regime (object)

# %%
count_null_and_empty(df_2025, 'regime')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2025['regime'].head(10))
# Out:
# 0    Medidas Especiais de Contratação Pública (Lei ...
# 1    Código dos Contratos Públicos (DL111-B/2017) e...
# 2    Código dos Contratos Públicos (DL111-B/2017) e...
# 3    Código dos Contratos Públicos (DL111-B/2017) e...
# 4    Código dos Contratos Públicos (DL111-B/2017) e...
# 5      Código dos Contratos Públicos ( DL 111-B/2017 )
# 6      Código dos Contratos Públicos ( DL 111-B/2017 )
# 7    Código dos Contratos Públicos (DL111-B/2017) e...
# 8    Código dos Contratos Públicos (DL111-B/2017) e...
# 9    Código dos Contratos Públicos (DL111-B/2017) e...
# Name: regime, dtype: str

# %% [markdown]
# tipoFimContrato (object)

# %%
count_null_and_empty(df_2025, 'tipoFimContrato')
# Out:
# Null (NaN) values: 207516 (87.49%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025, 'tipoFimContrato', 10)
# Out:
# Top 10 most frequent values for 'tipoFimContrato':
# tipoFimContrato
# O cumprimento, a impossibilidade definitiva e todas as restantes causas de extinção das obrigações reconhecidas pelo direito civil    29114
# Revogação do Contrato                                                                                                                   277
# Resolução do Contrato                                                                                                                   225
# Anulado ou Declarado Nulo                                                                                                                37
# Contrato Anulado, Declarado Nulo ou Objecto de Recusa de Visto                                                                            9
# Objeto de recusa de visto do Tribunal de Contas                                                                                           2
# Name: count, dtype: int64

# %% [markdown]
# CritMateriais (object)

# %%
count_null_and_empty(df_2025, 'CritMateriais')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2025['CritMateriais'].head(10))
# Out:
# 0    Não
# 1    Não
# 2    Não
# 3    Sim
# 4    Não
# 5    Não
# 6    Não
# 7    Sim
# 8    Não
# 9    Não
# Name: CritMateriais, dtype: str

# %%
print_top_n(df_2025,"CritMateriais",20)
# Out:
# Top 20 most frequent values for 'CritMateriais':
# CritMateriais
# Não    193423
# Sim     43757
# Name: count, dtype: int64

# %% [markdown]
# concorrentes (object)

# %%
count_null_and_empty(df_2025, 'concorrentes')
# Out:
# Null (NaN) values: 135847 (57.28%)
# Empty string values: 0 (0.00%)

# %%
print(df_2025['concorrentes'].tail(10))
# Out:
# 237170                                --GENTAUR EUROPE BVBA
# 237171                              --AXION BIOSYSTEMS INC.
# 237172                  510638490-PATENTREE, UNIPESSOAL LDA
# 237173                                                  NaN
# 237174             --Principia Ingenieros Consultores, S.A.
# 237175    509014208-Scansci - Equipamentos de laboratóri...
# 237176     --Tokyo Measuring Instruments Laboratory Co.,Ltd
# 237177    508643759-F-Iniciativas Consultadoria e Gestão...
# 237178                                                  NaN
# 237179                                                  NaN
# Name: concorrentes, dtype: str

# %% [markdown]
# linkPecasProc (object)

# %%
count_null_and_empty(df_2025, 'linkPecasProc')
# Out:
# Null (NaN) values: 117376 (49.49%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Observacoes (object)

# %%
count_null_and_empty(df_2025, 'Observacoes')
# Out:
# Null (NaN) values: 229721 (96.86%)
# Empty string values: 79 (0.03%)

# %% [markdown]
# ContratEcologico (object)

# %%
count_null_and_empty(df_2025, 'ContratEcologico')
print_top_n(df_2025, 'ContratEcologico',2)
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# Top 2 most frequent values for 'ContratEcologico':
# ContratEcologico
# Não    233248
# Sim      3932
# Name: count, dtype: int64

# %% [markdown]
# Ano (int64)

# %%
count_null_and_empty(df_2025, 'Ano')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2025['Ano'].head(10))
# Out:
# 0    2025
# 1    2025
# 2    2025
# 3    2025
# 4    2025
# 5    2025
# 6    2025
# 7    2025
# 8    2025
# 9    2025
# Name: Ano, dtype: int64

# %% [markdown]
# fundamentAjusteDireto (object)

# %%
count_null_and_empty(df_2025, 'fundamentAjusteDireto')
# Out:
# Null (NaN) values: 223454 (94.21%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2025,'fundamentAjusteDireto',2)
# Out:
# Top 2 most frequent values for 'fundamentAjusteDireto':
# fundamentAjusteDireto
# ausência de recursos próprios    13714
# outros                              12
# Name: count, dtype: int64

# %% [markdown]
# Informação geral

# %%
df_2025.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 237180 entries, 0 to 237179
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                237180 non-null  int64
#  1   nAnuncio                  38050 non-null   str
#  2   TipoAnuncio               38050 non-null   str
#  3   idINCM                    38050 non-null   float64
#  4   tipoContrato              237180 non-null  str
#  5   idprocedimento            237180 non-null  int64
#  6   tipoprocedimento          237180 non-null  str
#  7   objectoContrato           237179 non-null  object
#  8   descContrato              237180 non-null  object
#  9   adjudicante               237180 non-null  str
#  10  adjudicatarios            237108 non-null  str
#  11  dataPublicacao            237180 non-null  datetime64[us]
#  12  dataCelebracaoContrato    236168 non-null  datetime64[us]
# ...
