# %% [markdown]
# # Projeto Final Aplicado a Ciência de Dados
# ## Deteção de Outliers em Contratos Públicos e Previsão do Montante de Adjudição
#
# ## Grupo 08
# ## Membros:
# ###          - Afonso Alexandre nº 123425;
# ###          - André  Freitas nº 123409;
# ###          - Gonçalo Vilhena nº 123384;
# ###          - Rodolfo Nardy nº 123419

# %% [markdown]
# #### **Reading and checking data**

# %%
import pandas as pd

# %%
#Diretório onde os arquivos de dados do trabalho estão armazenados
data_dir = "./dados/"
df_2024 = pd.read_excel(data_dir + "contratos2024.xlsx")

# %% [markdown]
# ## Análise
#
#
# ### Funções auxiliares
#
# #### Função para os top X valores mais frequentes

# %%
def print_top_n(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate the top 'n' most frequent values
    top_n_values = df[column_name].value_counts().head(top_n)

    # Print the top 'n' values
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para os top X valores mais frequentes numa lista

# %%
def print_top_n_list(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Explode the lists into separate rows
    exploded = df[column_name].explode()

    # Calculate the top 'n' most frequent individual values
    top_n_values = exploded.value_counts().head(top_n)

    # Print the results
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para mostras os X menores valores menos frequentes

# %%
def print_bottom_n(df, column_name, bottom_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts and get the bottom 'n' values
    bottom_n_values = df[column_name].value_counts().sort_values(ascending=True).head(bottom_n)

    # Print the bottom 'n' values
    print(f"Bottom {bottom_n} least frequent values for '{column_name}':")

    print(bottom_n_values)

# %% [markdown]
#  #### Função para mostrar  X menores valores menos frequentes numa lista

# %% [markdown]
# #### Function to count null and empty values

# %%
def count_null_and_empty(df, column_name):
    total = len(df)

    # Count NaN (null) values
    null_count = df[column_name].isna().sum()
    null_pct = (null_count / total) * 100

    # Count empty string values (after stripping whitespace)
    empty_count = (df[column_name].astype(str).str.strip() == '').sum()
    empty_pct = (empty_count / total) * 100

    # Print results
    print(f"Null (NaN) values: {null_count} ({null_pct:.2f}%)")
    print(f"Empty string values: {empty_count} ({empty_pct:.2f}%)")

# %% [markdown]
# #### Informações gerais do ficheiro

# %%
df_2024.info()
df_2024.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 225478 entries, 0 to 225477
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                225478 non-null  int64
#  1   nAnuncio                  34783 non-null   str
#  2   TipoAnuncio               34783 non-null   str
#  3   idINCM                    34783 non-null   float64
#  4   tipoContrato              225478 non-null  str
#  5   idprocedimento            225478 non-null  int64
#  6   tipoprocedimento          225478 non-null  str
#  7   objectoContrato           225477 non-null  object
#  8   descContrato              225478 non-null  object
#  9   adjudicante               225478 non-null  str
#  10  adjudicatarios            225376 non-null  str
#  11  dataPublicacao            225478 non-null  datetime64[us]
#  12  dataCelebracaoContrato    225181 non-null  datetime64[us]
# ...

# %% [markdown]
# #### idcontrato (int64)

# %%
count_null_and_empty(df_2024, 'idcontrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
#não há repetidos
print_top_n(df_2024,"idcontrato",10)
# Out:
# Top 10 most frequent values for 'idcontrato':
# idcontrato
# 10424261    2
# 10424271    2
# 10424433    2
# 10424795    2
# 10424599    2
# 10425032    2
# 10424773    2
# 10424853    2
# 10424823    2
# 10424839    2
# Name: count, dtype: int64

# %%
df_2024[df_2024["idcontrato"]==10424261]
#só muda na variável "ContratEcologico"
# Out:
#     idcontrato nAnuncio TipoAnuncio  idINCM           tipoContrato  \
# 5     10424261      NaN         NaN     NaN  Aquisição de serviços
# 34    10424261      NaN         NaN     NaN  Aquisição de serviços
#
#     idprocedimento tipoprocedimento  \
# 5          6802432  Consulta Prévia
# 34         6802432  Consulta Prévia
#
#                                       objectoContrato  \
# 5   Seguro de Acidentes de Trabalho para os Funcio...
# 34  Seguro de Acidentes de Trabalho para os Funcio...
#
#                                          descContrato  \
# 5   Seguro de Acidentes de Trabalho para os Funcio...
# 34  Seguro de Acidentes de Trabalho para os Funcio...
#
#                                         adjudicante  ...  \
# 5   505111667 - Urbe - Consultores Associados, L.da  ...
# 34  505111667 - Urbe - Consultores Associados, L.da  ...
#
#                                                regime  \
# 5   Código dos Contratos Públicos (DL111-B/2017) e...
# ...

# %% [markdown]
# #### tipoContrato (object)

# %%
count_null_and_empty(df_2024, 'tipoContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n_list(df_2024,"tipoContrato",10)
df_2024['tipoContrato'].unique()
# Out:
# Top 10 most frequent values for 'tipoContrato':
# tipoContrato
# Aquisição de bens móveis                                118740
# Aquisição de serviços                                    88143
# Empreitadas de obras públicas                            13993
# Locação de bens móveis                                    2506
# Aquisição de bens móveis\nAquisição de serviços           1415
# Aquisição de serviços\nLocação de bens móveis              202
# Concessão de serviços públicos                             174
# Concessão de obras públicas                                 75
# Aquisição de serviços\nEmpreitadas de obras públicas        53
# Aquisição de bens móveis\nLocação de bens móveis            43
# Name: count, dtype: int64
# <StringArray>
# [                                                             'Aquisição de serviços',
#                                                            'Aquisição de bens móveis',
# ...

# %% [markdown]
# #### idProcedimento (int64)

# %%
count_null_and_empty(df_2024, 'idprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,"idprocedimento",10)
# Out:
# Top 10 most frequent values for 'idprocedimento':
# idprocedimento
# 6938074    216
# 6980312    190
# 6823524    181
# 7061867    173
# 7037424    167
# 7459975    167
# 7038748    162
# 6980081    160
# 7204094    159
# 7295101    158
# Name: count, dtype: int64

# %% [markdown]
# #### tipoprocedimento

# %%
count_null_and_empty(df_2024, 'tipoprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,"tipoprocedimento",10)  #(nem ha 10)
# Out:
# Top 10 most frequent values for 'tipoprocedimento':
# tipoprocedimento
# Ajuste Direto Regime Geral                                           109643
# Consulta Prévia                                                       41223
# Concurso público                                                      34432
# Ao abrigo de acordo-quadro (art.º 259.º)                              27108
# Ao abrigo de acordo-quadro (art.º 258.º)                               5595
# Contratação excluída II                                                5239
# Setores especiais – isenção parte II                                    988
# Concurso limitado por prévia qualificação                               486
# Consulta Prévia Simplificada                                            407
# Ajuste direto simplificado ao abrigo da Lei n.º 30/2021, de 21.05       217
# Name: count, dtype: int64

# %% [markdown]
# #### objectoContrato

# %%
count_null_and_empty(df_2024, 'objectoContrato')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,"objectoContrato",20)
# Out:
# Top 20 most frequent values for 'objectoContrato':
# objectoContrato
# MEDICAMENTOS                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1876
# ...

# %% [markdown]
# #### descContrato (object)

# %%
count_null_and_empty(df_2024, 'descContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,"descContrato",20)
# Out:
# Top 20 most frequent values for 'descContrato':
# descContrato
# MEDICAMENTOS                                                                                                                                                                                                1748
# Aquisição de serviço de viagens e alojamento – Plataforma SIAV                                                                                                                                               776
# Consulta Prévia ao abrigo do acordo-quadro da ESPAP\n                                                                                                                                                        713
# Consulta Prévia ao abrigo do acordo-quadro da ESPAP                                                                                                                                                          466
# ...

# %% [markdown]
# adjudicante (object)

# %%
count_null_and_empty(df_2024, 'adjudicante')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,"adjudicante",20)
# Out:
# Top 20 most frequent values for 'adjudicante':
# adjudicante
# 506362299 - Instituto Português de Oncologia do Porto Francisco Gentil, E. P. E.     18315
# 508142156 - Unidade Local de Saúde de Gaia/Espinho, E. P. E.                          4431
# 508481287 - Unidade Local de Saúde de Santa Maria, E. P. E.                           3279
# 509822940 - Unidade Local de Saúde de Viseu Dão-Lafões, E. P. E.                      2807
# 600010180 - Estado-Maior-General das Forças Armadas (EMGFA)                           2635
# 513606084 - Águas do Norte, S. A.                                                     2582
# 508080142 - Unidade Local de Saúde de São José, E. P. E.                              2436
# 508094461 - Unidade Local de Saúde do Alto Alentejo, E. P. E.                         2367
# 509822932 - Unidade Local de Saúde da Região de Leiria, E. P. E.                      2102
# 510745997 - Unidade Local de Saúde do Algarve, E. P. E.                               2050
# ...

# %% [markdown]
# adjudicatarios (object)

# %%
count_null_and_empty(df_2024, 'adjudicatarios')
# Out:
# Null (NaN) values: 102 (0.05%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['adjudicatarios'].head(20))
# Out:
# 0             501445226 - TK Elevadores, Unipessoal Lda
# 1        - - Manuel Fernando da Conceição Pinto Azevedo
# 2     500917477 - Casa do Frio - Distribuição Alimen...
# 3                             - - José Teixeira Moreira
# 4     512046468 - GLOBALEDA -Telecomunicações e Sist...
# 5      506093190 - Penasegur - Mediação de Seguros, Lda
# 6      506093190 - Penasegur - Mediação de Seguros, Lda
# 7                     - - Telma Cláudia Lourenço Macedo
# 8                                - - António José Pinto
# 9     513365800 - Jardinagem José Freitas, Unipessoa...
# 10    510382258 - SOCIASFALTOS ASFALTAGEM DE VIAS DE...
# 11                         - - Maria Alice Martins Dias
# 12                      500347506 - Eurest Portugal Lda
# 13    505111500 - JRJ - Comércio de Equipamentos de ...
# 14                      - - Filomena Guimarães Ferreira
# 15            - - Catarina Alexandra Martins dos Santos
# 16                  - - Mónica Emanuela Lobo Gonçalves
# ...

# %% [markdown]
# dataPublicacao (object)

# %%
count_null_and_empty(df_2024, 'dataPublicacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['dataPublicacao'].head(10))
# Out:
# 0   2023-12-20
# 1   2024-01-02
# 2   2024-01-02
# 3   2024-01-02
# 4   2023-05-16
# 5   2024-01-01
# 6   2024-01-02
# 7   2024-01-02
# 8   2024-01-02
# 9   2024-01-02
# Name: dataPublicacao, dtype: datetime64[us]

# %% [markdown]
# dataCelebracaoContrato (object)

# %%
count_null_and_empty(df_2024, 'dataCelebracaoContrato')
# Out:
# Null (NaN) values: 297 (0.13%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['dataCelebracaoContrato'].head(10))
# Out:
# 0   2024-01-01
# 1   2024-01-02
# 2   2024-01-02
# 3   2024-01-02
# 4   2024-02-08
# 5   2024-01-01
# 6   2024-01-02
# 7   2024-01-02
# 8   2024-01-02
# 9   2024-01-02
# Name: dataCelebracaoContrato, dtype: datetime64[us]

# %% [markdown]
# precoContratual (float64)

# %%
count_null_and_empty(df_2024, 'precoContratual')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['precoContratual'].head(10))
# Out:
# 0     1843.20
# 1     9900.00
# 2    10116.84
# 3     9840.00
# 4        0.00
# 5     3918.75
# 6      467.95
# 7    10800.00
# 8     9840.00
# 9    19018.80
# Name: precoContratual, dtype: float64

# %%
min(df_2024['precoContratual'])
# Out:
# -207000.0

# %% [markdown]
# cpv (object)

# %%
count_null_and_empty(df_2024, 'CPV')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['CPV'].head(10))
# Out:
# 0    50750000-7 - Serviços de manutenção de elevadores
# 1    90600000-3 - Serviços de saneamento e limpeza ...
# 2    15000000-8 - Produtos alimentares, bebidas, ta...
# 3             90611000-3 - Serviços de limpeza de ruas
# 4                 30230000-0 - Equipamento informático
# 5        66512100-3 - Serviços de seguros de acidentes
# 6            66514110-0 - Serviços de seguro automóvel
# 7                75110000-0 - Serviços públicos gerais
# 8    90600000-3 - Serviços de saneamento e limpeza ...
# 9    90611000-3 - Serviços de limpeza de ruas\n7731...
# Name: CPV, dtype: str

# %% [markdown]
# prazoExecucao (int64)

# %%
count_null_and_empty(df_2024, 'prazoExecucao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024, 'prazoExecucao', 10)
# Out:
# Top 10 most frequent values for 'prazoExecucao':
# prazoExecucao
# 365     28254
# 20      26096
# 30      16279
# 60       8701
# 1095     7959
# 1        7539
# 90       6216
# 5        5213
# 730      5172
# 366      4543
# Name: count, dtype: int64

# %%
print_bottom_n(df_2024,'prazoExecucao',10)
# Out:
# Bottom 10 least frequent values for 'prazoExecucao':
# prazoExecucao
# 8217     1
# 25567    1
# 599      1
# 1178     1
# 17532    1
# 1139     1
# 1339     1
# 1429     1
# 795      1
# 8490     1
# Name: count, dtype: int64

# %%
max_prazo_valor = df_2024['prazoExecucao'].max()
print("Maximum 'prazoExecucao (dias)':", max_prazo_valor)
print("Maximum 'prazoExecucao (anos)':", max_prazo_valor/365)
#impossível
# Out:
# Maximum 'prazoExecucao (dias)': 365744304
# Maximum 'prazoExecucao (anos)': 1002039.1890410959

# %% [markdown]
# localExecucao (object)

# %%
count_null_and_empty(df_2024, 'LocalExecucao')
# Out:
# Null (NaN) values: 161 (0.07%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['LocalExecucao'].head(10))
# Out:
# 0                                 Portugal, Faro, Faro
# 1                               Portugal, Porto, Baião
# 2                     Portugal, Leiria, Marinha Grande
# 3                          Portugal, Porto, Felgueiras
# 4    Portugal, Região Autónoma dos Açores, Ponta De...
# 5                   Portugal, Aveiro, Castelo de Paiva
# 6                   Portugal, Aveiro, Castelo de Paiva
# 7                               Portugal, Porto, Baião
# 8                               Portugal, Porto, Baião
# 9                          Portugal, Porto, Felgueiras
# Name: LocalExecucao, dtype: str

# %% [markdown]
# fundamentacao (object)

# %%
count_null_and_empty(df_2024, 'fundamentacao')
# Out:
# Null (NaN) values: 303 (0.13%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024, 'fundamentacao', 10)
# Out:
# Top 10 most frequent values for 'fundamentacao':
# fundamentacao
# Artigo 20.º, n.º 1, alínea d) do Código dos Contratos Públicos                    42717
# Artigo 20.º, n.º 1, alínea c) do Código dos Contratos Públicos                    34759
# Artigo 24.º, n.º 1, alínea c) do Código dos Contratos Públicos                    31914
# Artigo 259.º do Código dos Contratos Públicos                                     26439
# Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos                    17647
# Artigo 24.º, n.º 1, alínea e), subalínea ii) do Código dos Contratos Públicos     11186
# Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos                     9815
# Artigo 24.º, n.º 1, alínea e), subalínea iii) do Código dos Contratos Públicos     7987
# Artigo 258.º do Código dos Contratos Públicos                                      5149
# Artigo 19.º, alínea b) do Código dos Contratos Públicos                            4421
# Name: count, dtype: int64

# %% [markdown]
# ProcedimentoCentralizado (object)

# %%
count_null_and_empty(df_2024, 'ProcedimentoCentralizado')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024, 'ProcedimentoCentralizado', 10)
# Out:
# Top 10 most frequent values for 'ProcedimentoCentralizado':
# ProcedimentoCentralizado
# Não    214458
# Sim     11020
# Name: count, dtype: int64

# %% [markdown]
# DescrAcordoQuadro (object)

# %%
count_null_and_empty(df_2024, 'DescrAcordoQuadro')
# Out:
# Null (NaN) values: 193608 (85.87%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,"DescrAcordoQuadro",10)
# Out:
# Top 10 most frequent values for 'DescrAcordoQuadro':
# DescrAcordoQuadro
# 491/2023 - Concurso público internacional para formação do acordo quadro de medicamentos do foro oncológico e imunomoduladores    4758
# Acordo Quadro de Viagens e Alojamento                                                                                             4293
# 492/2023 - Concurso público internacional para formação do acordo quadro de medicamentos anti-infeciosos na área da saúde         1247
# CP 2021/6 - Medicamentos do foro oncológico e imunomoduladores                                                                     993
# CP 2022/14 - Medicamentos do aparelho digestivo                                                                                    818
# 436/2023 - Medicamentos para o sistema nervoso central                                                                             770
# ...

# %% [markdown]
# precoBaseProcedimento (float64)

# %%
count_null_and_empty(df_2024, 'precoBaseProcedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,"precoBaseProcedimento",10)
# Out:
# Top 10 most frequent values for 'precoBaseProcedimento':
# precoBaseProcedimento
# 0.00         4573
# 15000.00     1317
# 10000.00     1171
# 20000.00     1039
# 12000.00     1029
# 6000.00       912
# 18000.00      900
# 357723.58     816
# 30000.00      781
# 9000.00       766
# Name: count, dtype: int64

# %% [markdown]
# dataDecisaoAdjudicacao (object)

# %%
count_null_and_empty(df_2024, 'dataDecisaoAdjudicacao')
# Out:
# Null (NaN) values: 297 (0.13%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,"dataDecisaoAdjudicacao",20)
# Out:
# Top 20 most frequent values for 'dataDecisaoAdjudicacao':
# dataDecisaoAdjudicacao
# 2024-02-29    1424
# 2024-12-11    1409
# 2024-04-24    1398
# 2024-12-03    1319
# 2024-02-07    1299
# 2024-03-07    1297
# 2024-02-22    1283
# 2024-03-14    1274
# 2024-02-08    1272
# 2024-03-21    1231
# 2024-01-31    1223
# 2024-05-09    1222
# 2024-06-27    1211
# 2024-01-18    1205
# 2024-02-14    1198
# 2024-02-15    1193
# 2024-02-01    1178
# 2024-01-25    1176
# 2024-04-18    1141
# 2024-02-20    1138
# Name: count, dtype: int64

# %% [markdown]
# dataFechoContrato (object)

# %%
count_null_and_empty(df_2024, 'dataFechoContrato')
# Out:
# Null (NaN) values: 174327 (77.31%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,"dataFechoContrato",10)
# Out:
# Top 10 most frequent values for 'dataFechoContrato':
# dataFechoContrato
# 2024-12-31    4610
# 2024-12-30    1296
# 2024-12-27     912
# 2024-12-20     686
# 2024-12-23     524
# 2024-12-19     439
# 2024-12-18     428
# 2024-12-26     383
# 2024-12-17     345
# 2025-12-31     321
# Name: count, dtype: int64

# %% [markdown]
# PrecoTotalEfetivo

# %%
count_null_and_empty(df_2024, 'PrecoTotalEfetivo')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['PrecoTotalEfetivo'].head(10))
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
# 5    3918.75
# 6     467.92
# 7       0.00
# 8       0.00
# 9       0.00
# Name: PrecoTotalEfetivo, dtype: float64

# %%
print_top_n(df_2024,"PrecoTotalEfetivo",10)
# Out:
# Top 10 most frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 0.0        174979
# 6000.0        236
# 15000.0       219
# 7500.0        217
# 10000.0       198
# 7000.0        184
# 12000.0       172
# 8000.0        161
# 9000.0        156
# 6500.0        133
# Name: count, dtype: int64

# %%
print_bottom_n(df_2024,"PrecoTotalEfetivo",10)
# Out:
# Bottom 10 least frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 72579.98    1
# 36259.48    1
# 6394.41     1
# 13992.54    1
# 95.42       1
# 717.90      1
# 19998.46    1
# 74749.90    1
# 10676.05    1
# 42156.25    1
# Name: count, dtype: int64

# %% [markdown]
# regime (object)

# %%
count_null_and_empty(df_2024, 'regime')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['regime'].head(10))
# Out:
# 0    Código dos Contratos Públicos (DL111-B/2017) e...
# 1    Código dos Contratos Públicos (DL111-B/2017) e...
# 2      Código dos Contratos Públicos ( DL 111-B/2017 )
# 3    Código dos Contratos Públicos (DL111-B/2017) e...
# 4    Código dos Contratos Públicos (DL111-B/2017) e...
# 5    Código dos Contratos Públicos (DL111-B/2017) e...
# 6    Código dos Contratos Públicos (DL111-B/2017) e...
# 7    Código dos Contratos Públicos (DL111-B/2017) e...
# 8    Código dos Contratos Públicos (DL111-B/2017) e...
# 9    Código dos Contratos Públicos (DL111-B/2017) e...
# Name: regime, dtype: str

# %% [markdown]
# tipoFimContrato (object)

# %%
count_null_and_empty(df_2024, 'tipoFimContrato')
# Out:
# Null (NaN) values: 174620 (77.44%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024, 'tipoFimContrato', 10)
# Out:
# Top 10 most frequent values for 'tipoFimContrato':
# tipoFimContrato
# O cumprimento, a impossibilidade definitiva e todas as restantes causas de extinção das obrigações reconhecidas pelo direito civil    49739
# Resolução do Contrato                                                                                                                   589
# Revogação do Contrato                                                                                                                   472
# Anulado ou Declarado Nulo                                                                                                                39
# Contrato Anulado, Declarado Nulo ou Objecto de Recusa de Visto                                                                           17
# Objeto de recusa de visto do Tribunal de Contas                                                                                           2
# Name: count, dtype: int64

# %% [markdown]
# CritMateriais (object)

# %%
count_null_and_empty(df_2024, 'CritMateriais')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['CritMateriais'].head(10))
# Out:
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# 5    Não
# 6    Não
# 7    Não
# 8    Não
# 9    Não
# Name: CritMateriais, dtype: str

# %%
print_top_n(df_2024,"CritMateriais",20)
# Out:
# Top 20 most frequent values for 'CritMateriais':
# CritMateriais
# Não    176527
# Sim     48951
# Name: count, dtype: int64

# %% [markdown]
# concorrentes (object)

# %%
count_null_and_empty(df_2024, 'concorrentes')
# Out:
# Null (NaN) values: 127634 (56.61%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['concorrentes'].tail(10))
# Out:
# 225468                            508876745-Streamline, Lda
# 225469                                  509137067-SWTL, Lda
# 225470                                                  NaN
# 225471    503531588-LUSOPALEX PRODUTOS DE SAUDE UNIPESSO...
# 225472                                                  NaN
# 225473    500615250-NASACAR-SOCIEDADE DE IMPORTAÇÃO E CO...
# 225474    514925922-+ATLANTIC - Associação para um Labor...
# 225475                                  500199906-MUNDINTER
# 225476                     510861504-KEY ENERGY TARGET, LDA
# 225477                             --CIRENIA ARIAS BALDRICH
# Name: concorrentes, dtype: str

# %% [markdown]
# linkPecasProc (object)

# %%
count_null_and_empty(df_2024, 'linkPecasProc')
# Out:
# Null (NaN) values: 117284 (52.02%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Observacoes (object)

# %%
count_null_and_empty(df_2024, 'Observacoes')
# Out:
# Null (NaN) values: 217450 (96.44%)
# Empty string values: 72 (0.03%)

# %% [markdown]
# ContratEcologico (object)

# %%
count_null_and_empty(df_2024, 'ContratEcologico')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Ano (int64)

# %%
count_null_and_empty(df_2024, 'Ano')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2024['Ano'].head(10))
# Out:
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# 4    2024
# 5    2024
# 6    2024
# 7    2024
# 8    2024
# 9    2024
# Name: Ano, dtype: int64

# %%
print_top_n(df_2024,"Ano",20)
# Out:
# Top 20 most frequent values for 'Ano':
# Ano
# 2024    225478
# Name: count, dtype: int64

# %% [markdown]
# fundamentAjusteDireto (object)

# %%
count_null_and_empty(df_2024, 'fundamentAjusteDireto')
# Out:
# Null (NaN) values: 210531 (93.37%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2024,'fundamentAjusteDireto',2)
# Out:
# Top 2 most frequent values for 'fundamentAjusteDireto':
# fundamentAjusteDireto
# ausência de recursos próprios    14811
# outros                             136
# Name: count, dtype: int64

# %% [markdown]
# Informação geral

# %%
df_2024.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 225478 entries, 0 to 225477
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                225478 non-null  int64
#  1   nAnuncio                  34783 non-null   str
#  2   TipoAnuncio               34783 non-null   str
#  3   idINCM                    34783 non-null   float64
#  4   tipoContrato              225478 non-null  str
#  5   idprocedimento            225478 non-null  int64
#  6   tipoprocedimento          225478 non-null  str
#  7   objectoContrato           225477 non-null  object
#  8   descContrato              225478 non-null  object
#  9   adjudicante               225478 non-null  str
#  10  adjudicatarios            225376 non-null  str
#  11  dataPublicacao            225478 non-null  datetime64[us]
#  12  dataCelebracaoContrato    225181 non-null  datetime64[us]
# ...
