# %% [markdown]
# # Projeto Final Aplicado a Ciência de Dados
# ## Deteção de Outliers em Contratos Públicos e Previsão do Montante de Adjudição
#
# ## Grupo 08
# ## Membros:
# ###          - Afonso Alexandre nº 123425;
# ###          - André  Freitas nº 123409;
# ###          - Gonçalo Vilhena nº 123384;
# ###          - Rodolfo Nardy nº 123419

# %% [markdown]
# #### **Reading and checking data**

# %%
import pandas as pd

# %%
#Diretório onde os arquivos de dados do trabalho estão armazenados
data_dir = "./dados/"
df_2017 = pd.read_excel(data_dir + "contratos2017.xlsx")

# %% [markdown]
# ## Análise
#
#
# ### Funções auxiliares
#
# #### Função para os top X valores mais frequentes

# %%
def print_top_n(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate the top 'n' most frequent values
    top_n_values = df[column_name].value_counts().head(top_n)

    # Print the top 'n' values
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para os top X valores mais frequentes numa lista

# %%
def print_top_n_list(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Explode the lists into separate rows
    exploded = df[column_name].explode()

    # Calculate the top 'n' most frequent individual values
    top_n_values = exploded.value_counts().head(top_n)

    # Print the results
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para mostras os X menores valores menos frequentes

# %%
def print_bottom_n(df, column_name, bottom_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts and get the bottom 'n' values
    bottom_n_values = df[column_name].value_counts().sort_values(ascending=True).head(bottom_n)

    # Print the bottom 'n' values
    print(f"Bottom {bottom_n} least frequent values for '{column_name}':")

    print(bottom_n_values)

# %% [markdown]
#  #### Função para mostrar  X menores valores menos frequentes numa lista

# %% [markdown]
# #### Function to count null and empty values

# %%
def count_null_and_empty(df, column_name):
    total = len(df)

    # Count NaN (null) values
    null_count = df[column_name].isna().sum()
    null_pct = (null_count / total) * 100

    # Count empty string values (after stripping whitespace)
    empty_count = (df[column_name].astype(str).str.strip() == '').sum()
    empty_pct = (empty_count / total) * 100

    # Print results
    print(f"Null (NaN) values: {null_count} ({null_pct:.2f}%)")
    print(f"Empty string values: {empty_count} ({empty_pct:.2f}%)")

# %% [markdown]
# #### Informações gerais do ficheiro

# %%
df_2017.info()
df_2017.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128578 entries, 0 to 128577
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                128578 non-null  int64
#  1   nAnuncio                  10956 non-null   str
#  2   TipoAnuncio               10956 non-null   str
#  3   idINCM                    10956 non-null   float64
#  4   tipoContrato              128574 non-null  str
#  5   idprocedimento            128578 non-null  int64
#  6   tipoprocedimento          128577 non-null  str
#  7   objectoContrato           128535 non-null  object
#  8   descContrato              128502 non-null  object
#  9   adjudicante               128577 non-null  str
#  10  adjudicatarios            128578 non-null  str
#  11  dataPublicacao            128578 non-null  datetime64[us]
#  12  dataCelebracaoContrato    128577 non-null  datetime64[us]
# ...

# %% [markdown]
# #### idcontrato (int64)

# %%
count_null_and_empty(df_2017, 'idcontrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
#não há repetidos
print_top_n(df_2017,"idcontrato",10)
# Out:
# Top 10 most frequent values for 'idcontrato':
# idcontrato
# 2450108    1
# 2838794    1
# 2838816    1
# 2839061    1
# 2839123    1
# 2839254    1
# 2839861    1
# 2840038    1
# 2840454    1
# 2840514    1
# Name: count, dtype: int64

# %% [markdown]
# #### tipoContrato (object)

# %%
count_null_and_empty(df_2017, 'tipoContrato')
# Out:
# Null (NaN) values: 4 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n_list(df_2017,"tipoContrato",10)
df_2017['tipoContrato'].unique()
# Out:
# Top 10 most frequent values for 'tipoContrato':
# tipoContrato
# Aquisição de bens móveis                            57173
# Aquisição de serviços                               52368
# Empreitadas de obras públicas                       16182
# Locação de bens móveis                               1170
# Aquisição de bens móveis\nAquisição de serviços       886
# Outros                                                304
# Aquisição de serviços\nLocação de bens móveis         187
# Concessão de obras públicas                            61
# Concessão de serviços públicos                         60
# Aquisição de bens móveis\nLocação de bens móveis       42
# Name: count, dtype: int64
# <StringArray>
# [                                                               'Aquisição de serviços',
#                                                              'Aquisição de bens móveis',
#                                                                'Locação de bens móveis',
# ...

# %% [markdown]
# #### idProcedimento (int64)

# %%
count_null_and_empty(df_2017, 'idprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,"idprocedimento",10)
# Out:
# Top 10 most frequent values for 'idprocedimento':
# idprocedimento
# 3143337    48
# 2710849    45
# 2903528    45
# 3141032    33
# 2427636    31
# 2810098    31
# 2437034    31
# 2427664    29
# 2714995    29
# 3056208    29
# Name: count, dtype: int64

# %% [markdown]
# #### tipoprocedimento

# %%
count_null_and_empty(df_2017, 'tipoprocedimento')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,"tipoprocedimento",10)  #(nem ha 10)
# Out:
# Top 10 most frequent values for 'tipoprocedimento':
# tipoprocedimento
# Ajuste Direto Regime Geral                   104697
# Ao abrigo de acordo-quadro (art.º 259.º)      11203
# Concurso público                              10659
# Ao abrigo de acordo-quadro (art.º 258.º)       1683
# Concurso limitado por prévia qualificação       334
# Ajuste direto simplificado                        1
# Name: count, dtype: int64

# %% [markdown]
# #### objectoContrato

# %%
count_null_and_empty(df_2017, 'objectoContrato')
# Out:
# Null (NaN) values: 43 (0.03%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,"objectoContrato",20)
# Out:
# Top 20 most frequent values for 'objectoContrato':
# objectoContrato
# Prestação Serviços                                                                                                                                                                                400
# Aquisição de produtos de apoio                                                                                                                                                                    358
# medicamento                                                                                                                                                                                       268
# MEDICAMENTOS                                                                                                                                                                                      266
# ...

# %% [markdown]
# #### descContrato (object)

# %%
count_null_and_empty(df_2017, 'descContrato')
# Out:
# Null (NaN) values: 76 (0.06%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,"descContrato",20)
#df_2017[df_2017["descContrato"] == "Contrato de empreitada"]
# Out:
# Top 20 most frequent values for 'descContrato':
# descContrato
# Contrato de Prestação de Serviços                                                                        397
# Ajuste direto                                                                                            191
# Aquisição de serviços                                                                                    169
# Aquisição de medicamentos                                                                                110
# Contrato de aquisição de serviços                                                                         97
# Prestação de serviços                                                                                     93
# CONTRATO DE AVENÇA                                                                                        86
# Contrato de Aquisição de Serviços                                                                         86
# ...

# %% [markdown]
# adjudicante (object)

# %%
count_null_and_empty(df_2017, 'adjudicante')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,"adjudicante",20)
# Out:
# Top 20 most frequent values for 'adjudicante':
# adjudicante
# 508142156 - Centro Hospitalar Vila Nova de Gaia - Espinho, E. P. E.                                             2878
# 508481287 - Centro Hospitalar Lisboa Norte, E. P. E.                                                            2641
# 508080142 - Centro Hospitalar de Lisboa Central, E. P. E.                                                       1776
# 511228848 - Serviço de Saúde da Região Autónoma da Madeira, E. P. E.                                            1521
# 509186998 - Centro Hospitalar Barreiro Montijo, E. P. E.                                                        1487
# 510103448 - Centro Hospitalar e Universitário de Coimbra, E. P. E.                                              1458
# 500051070 - Município de Lisboa                                                                                 1444
# ...

# %% [markdown]
# adjudicatarios (object)

# %%
count_null_and_empty(df_2017, 'adjudicatarios')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['adjudicatarios'].head(20))
# Out:
# 0     506876632 - TBP Consultoria e Gestão do Arquiv...
# 1      501393005 - PARAMEDICA EQUIPAMENTOS MEDICOS, LDA
# 2                     503232785 - VYGON (PORTUGAL) LDA.
# 3                           - - INNOVA SCIENTIFIC, S.L.
# 4     502042044 - Fernando L. Gaspar Sinalização e E...
# 5         510167780 - Paulo Jesus Costa Unipessoal, Lda
# 6                       500069190 - Ferrer Portugal, SA
# 7            502177420 - SERVIER PORTUGAL-ESP.FARM.,LDA
# 8                        - - Anabela Barreiros Estrompa
# 9                           - - João José Patrão Nabais
# 10                  980369959 - MEDAC SUCURSAL PORTUGAL
# 11                  - - Jeronimo Mariano Pistola Rosado
# 12    513718117 - Enfeites Prometidos - Jardinagem U...
# 13                              - - José Costa Teixeira
# 14    501467939 - Expandindústria - Estudos, Project...
# 15               - - Rui Domingos Ribeiro Cunha Marques
# 16    510369308 - Patamar Positivo - Sociedade de Co...
# ...

# %% [markdown]
# dataPublicacao (object)

# %%
count_null_and_empty(df_2017, 'dataPublicacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['dataPublicacao'].head(10))
# Out:
# 0   2016-09-22
# 1   2017-01-02
# 2   2017-01-02
# 3   2017-01-02
# 4   2017-01-02
# 5   2017-01-02
# 6   2017-01-02
# 7   2017-01-02
# 8   2017-01-02
# 9   2017-01-02
# Name: dataPublicacao, dtype: datetime64[us]

# %% [markdown]
# dataCelebracaoContrato (object)

# %%
count_null_and_empty(df_2017, 'dataCelebracaoContrato')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['dataCelebracaoContrato'].head(10))
# Out:
# 0   2017-10-02
# 1   2017-01-02
# 2   2017-01-02
# 3   2017-05-19
# 4   2017-01-02
# 5   2017-01-02
# 6   2017-01-02
# 7   2017-01-02
# 8   2017-01-02
# 9   2017-01-02
# Name: dataCelebracaoContrato, dtype: datetime64[us]

# %% [markdown]
# precoContratual (float64)

# %%
count_null_and_empty(df_2017, 'precoContratual')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['precoContratual'].head(10))
# Out:
# 0    26084.06
# 1     2175.00
# 2    15840.00
# 3    21000.00
# 4     7956.00
# 5     5304.00
# 6     5735.80
# 7     6630.63
# 8     7558.80
# 9     9898.80
# Name: precoContratual, dtype: float64

# %%
print_top_n(df_2017,'precoContratual',10)
# Out:
# Top 10 most frequent values for 'precoContratual':
# precoContratual
# 0.0        906
# 10000.0    637
# 15000.0    603
# 9000.0     469
# 6000.0     461
# 20000.0    414
# 12000.0    408
# 7500.0     400
# 30000.0    373
# 18000.0    363
# Name: count, dtype: int64

# %% [markdown]
# cpv (object)

# %%
count_null_and_empty(df_2017, 'CPV')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['CPV'].head(10))
# Out:
# 0                     79995100-6 - Serviços de arquivo
# 1                      33100000-1 - Equipamento médico
# 2                                  33141641-5 - Sondas
# 3      50000000-5 - Serviços de reparação e manutenção
# 4                       22457000-8 - Cartões de acesso
# 5                       22457000-8 - Cartões de acesso
# 6    33640000-8 - Medicamentos para o aparelho geni...
# 7                     33690000-3 - Medicamentos vários
# 8             90611000-3 - Serviços de limpeza de ruas
# 9    90600000-3 - Serviços de saneamento e limpeza ...
# Name: CPV, dtype: str

# %% [markdown]
# prazoExecucao (int64)

# %%
count_null_and_empty(df_2017, 'prazoExecucao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017, 'prazoExecucao', 10)
# Out:
# Top 10 most frequent values for 'prazoExecucao':
# prazoExecucao
# 365     21901
# 30      13681
# 60       6323
# 1        5994
# 20       5216
# 90       4870
# 15       4069
# 1095     3477
# 10       3240
# 180      3227
# Name: count, dtype: int64

# %%
print_bottom_n(df_2017,'prazoExecucao',10)
# Out:
# Bottom 10 least frequent values for 'prazoExecucao':
# prazoExecucao
# 1545     1
# 851      1
# 11680    1
# 779      1
# 799      1
# 1153     1
# 1072     1
# 935      1
# 891      1
# 1232     1
# Name: count, dtype: int64

# %%
max_prazo_valor = df_2017['prazoExecucao'].max()
print("Maximum 'prazoExecucao (dias)':", max_prazo_valor)
print("Maximum 'prazoExecucao (anos)':", max_prazo_valor/365)
#impossível
# Out:
# Maximum 'prazoExecucao (dias)': 509948286
# Maximum 'prazoExecucao (anos)': 1397118.591780822

# %% [markdown]
# localExecucao (object)

# %%
count_null_and_empty(df_2017, 'LocalExecucao')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['LocalExecucao'].head(10))
# Out:
# 0        Portugal, Lisboa, Lisboa
# 1        Portugal, Lisboa, Lisboa
# 2        Portugal, Lisboa, Lisboa
# 3          Portugal, Braga, Braga
# 4        Portugal, Lisboa, Lisboa
# 5        Portugal, Lisboa, Lisboa
# 6        Portugal, Lisboa, Lisboa
# 7        Portugal, Lisboa, Lisboa
# 8    Portugal, Évora, Vila Viçosa
# 9    Portugal, Évora, Vila Viçosa
# Name: LocalExecucao, dtype: str

# %% [markdown]
# fundamentacao (object)

# %%
count_null_and_empty(df_2017, 'fundamentacao')
# Out:
# Null (NaN) values: 2 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017, 'fundamentacao', 10)
# Out:
# Top 10 most frequent values for 'fundamentacao':
# fundamentacao
# Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos                    70627
# Artigo 19.º, alínea a) do Código dos Contratos Públicos                           12939
# Artigo 24.º, n.º 1, alínea e) do Código dos Contratos Públicos                    11930
# Artigo 259.º do Código dos Contratos Públicos                                     10626
# Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos                     7991
# Artigo 24.º, n.º 1, alínea c) do Código dos Contratos Públicos                     2565
# Artigo 19.º, alínea b) do Código dos Contratos Públicos                            2433
# Artigo 258.º do Código dos Contratos Públicos                                      1502
# Artigo 20.º, alínea a) do Decreto Legislativo Regional n.º 27/2015/A, de 29.12     1008
# Artigo 26.º, n.º 1, alínea e) do Código dos Contratos Públicos                      733
# Name: count, dtype: int64

# %% [markdown]
# ProcedimentoCentralizado (object)

# %%
count_null_and_empty(df_2017, 'ProcedimentoCentralizado')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017, 'ProcedimentoCentralizado', 10)
# Out:
# Top 10 most frequent values for 'ProcedimentoCentralizado':
# ProcedimentoCentralizado
# Não    127138
# Sim      1440
# Name: count, dtype: int64

# %% [markdown]
# DescrAcordoQuadro (object)

# %%
count_null_and_empty(df_2017, 'DescrAcordoQuadro')
# Out:
# Null (NaN) values: 115692 (89.98%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,"DescrAcordoQuadro",10)
# Out:
# Top 10 most frequent values for 'DescrAcordoQuadro':
# DescrAcordoQuadro
# CP 2015/6 - Acordo quadro para o fornecimento de Medicamentos do Foro Oncológico                                                                                                                                                                                                                                       2312
# Acordo quadro de licenciamento de software e serviços conexos                                                                                                                                                                                                                                                           516
# ...

# %% [markdown]
# precoBaseProcedimento (float64)

# %%
count_null_and_empty(df_2017, 'precoBaseProcedimento')
# Out:
# Null (NaN) values: 30 (0.02%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,"precoBaseProcedimento",10)
# Out:
# Top 10 most frequent values for 'precoBaseProcedimento':
# precoBaseProcedimento
# 0.0        5977
# 10000.0    1042
# 15000.0     982
# 20000.0     787
# 30000.0     717
# 25000.0     670
# 12000.0     666
# 6000.0      656
# 9000.0      647
# 8000.0      584
# Name: count, dtype: int64

# %% [markdown]
# dataDecisaoAdjudicacao (object)

# %%
count_null_and_empty(df_2017, 'dataDecisaoAdjudicacao')
# Out:
# Null (NaN) values: 4 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,"dataDecisaoAdjudicacao",20)
# Out:
# Top 20 most frequent values for 'dataDecisaoAdjudicacao':
# dataDecisaoAdjudicacao
# 2017-01-02    1115
# 2017-01-03     821
# 2017-01-19     765
# 2017-01-23     717
# 2017-03-07     695
# 2017-01-31     673
# 2017-06-21     655
# 2017-03-01     640
# 2017-05-04     636
# 2017-02-21     633
# 2017-03-23     630
# 2017-06-30     630
# 2017-03-02     629
# 2017-01-26     626
# 2017-02-22     625
# 2017-05-18     625
# 2017-09-29     624
# 2017-04-05     622
# 2017-02-20     616
# 2017-05-10     615
# Name: count, dtype: int64

# %% [markdown]
# dataFechoContrato (object)

# %%
count_null_and_empty(df_2017, 'dataFechoContrato')
# Out:
# Null (NaN) values: 81681 (63.53%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,"dataFechoContrato",10)
# Out:
# Top 10 most frequent values for 'dataFechoContrato':
# dataFechoContrato
# 2017-12-31    4445
# 2017-12-29    2778
# 2018-12-31    1197
# 2017-12-27     535
# 2017-06-30     501
# 2017-12-28     472
# 2017-07-31     427
# 2017-12-22     395
# 2017-08-31     382
# 2017-12-20     355
# Name: count, dtype: int64

# %% [markdown]
# PrecoTotalEfetivo

# %%
count_null_and_empty(df_2017, 'PrecoTotalEfetivo')
min(df_2017['PrecoTotalEfetivo'])
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# -17666.0

# %%
print(df_2017['PrecoTotalEfetivo'].head(10))
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
# 5       0.00
# 6       0.00
# 7       0.00
# 8    5669.10
# 9    9744.58
# Name: PrecoTotalEfetivo, dtype: float64

# %%
print_top_n(df_2017,"PrecoTotalEfetivo",10)
# Out:
# Top 10 most frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 0.00        74917
# 722.50        215
# 10000.00      189
# 15000.00      181
# 6000.00       171
# 7500.00       155
# 9000.00       147
# 1276.58       139
# 12000.00      136
# 750.00        122
# Name: count, dtype: int64

# %%
print_bottom_n(df_2017,"PrecoTotalEfetivo",10)
# Out:
# Bottom 10 least frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 6057.83      1
# 19211.48     1
# 22.60        1
# 192242.00    1
# 8225.62      1
# 3362.88      1
# 104000.00    1
# 73877.00     1
# 33202.64     1
# 212941.36    1
# Name: count, dtype: int64

# %% [markdown]
# regime (object)

# %%
count_null_and_empty(df_2017, 'regime')
# Out:
# Null (NaN) values: 4 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['regime'].head(10))
# Out:
# 0    Código dos Contratos Públicos (DL 18/2008)
# 1    Código dos Contratos Públicos (DL 18/2008)
# 2    Código dos Contratos Públicos (DL 18/2008)
# 3    Código dos Contratos Públicos (DL 18/2008)
# 4    Código dos Contratos Públicos (DL 18/2008)
# 5    Código dos Contratos Públicos (DL 18/2008)
# 6    Código dos Contratos Públicos (DL 18/2008)
# 7    Código dos Contratos Públicos (DL 18/2008)
# 8    Código dos Contratos Públicos (DL 18/2008)
# 9    Código dos Contratos Públicos (DL 18/2008)
# Name: regime, dtype: str

# %% [markdown]
# tipoFimContrato (object)

# %%
count_null_and_empty(df_2017, 'tipoFimContrato')
# Out:
# Null (NaN) values: 74266 (57.76%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017, 'tipoFimContrato', 10)
# Out:
# Top 10 most frequent values for 'tipoFimContrato':
# tipoFimContrato
# O cumprimento, a impossibilidade definitiva e todas as restantes causas de extinção das obrigações reconhecidas pelo direito civil    52726
# Resolução do Contrato                                                                                                                  1222
# Revogação do Contrato                                                                                                                   304
# Anulado ou Declarado Nulo                                                                                                                49
# Contrato Anulado, Declarado Nulo ou Objecto de Recusa de Visto                                                                            7
# Objeto de recusa de visto do Tribunal de Contas                                                                                           4
# Name: count, dtype: int64

# %% [markdown]
# CritMateriais (object)

# %%
count_null_and_empty(df_2017, 'CritMateriais')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['CritMateriais'].head(10))
# Out:
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# 5    Não
# 6    Não
# 7    Não
# 8    Não
# 9    Não
# Name: CritMateriais, dtype: str

# %%
print_top_n(df_2017,"CritMateriais",20)
# Out:
# Top 20 most frequent values for 'CritMateriais':
# CritMateriais
# Não    128577
# Sim         1
# Name: count, dtype: int64

# %% [markdown]
# concorrentes (object)

# %%
count_null_and_empty(df_2017, 'concorrentes')
# Out:
# Null (NaN) values: 96497 (75.05%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['concorrentes'].tail(10))
# Out:
# 128568    501179259-FERREIRA &amp; BEBIANO, LDA\n5036719...
# 128569    503637530-HIGIENE PLUS - PRODUTOS E MATERIAIS ...
# 128570                                                  NaN
# 128571                                                  NaN
# 128572                             503040630-VITOR HUGO, SA
# 128573                                                  NaN
# 128574    503790354-Jobipiso - Construção Civil e Obras ...
# 128575                                                  NaN
# 128576    510194990-Protectrilho - Construções Unipessoa...
# 128577    508705959-RENTECI- DEMOLIÇÕES, MOVIMENTOS DE T...
# Name: concorrentes, dtype: str

# %% [markdown]
# linkPecasProc (object)

# %%
count_null_and_empty(df_2017, 'linkPecasProc')
# Out:
# Null (NaN) values: 128578 (100.00%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Observacoes (object)

# %%
count_null_and_empty(df_2017, 'Observacoes')
# Out:
# Null (NaN) values: 118234 (91.96%)
# Empty string values: 535 (0.42%)

# %% [markdown]
# ContratEcologico (object)

# %%
count_null_and_empty(df_2017, 'ContratEcologico')
print_top_n(df_2017, 'ContratEcologico',2)
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# Top 2 most frequent values for 'ContratEcologico':
# ContratEcologico
# Não    124033
# Sim      4545
# Name: count, dtype: int64

# %% [markdown]
# Ano (int64)

# %%
count_null_and_empty(df_2017, 'Ano')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2017['Ano'].head(10))
# Out:
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2017
# 5    2017
# 6    2017
# 7    2017
# 8    2017
# 9    2017
# Name: Ano, dtype: int64

# %% [markdown]
# fundamentAjusteDireto (object)

# %%
count_null_and_empty(df_2017, 'fundamentAjusteDireto')
# Out:
# Null (NaN) values: 73255 (56.97%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2017,'fundamentAjusteDireto',2)
# Out:
# Top 2 most frequent values for 'fundamentAjusteDireto':
# fundamentAjusteDireto
# ausência de recursos próprios    53652
# outros                            1671
# Name: count, dtype: int64

# %% [markdown]
# Informação geral

# %%
df_2017.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128578 entries, 0 to 128577
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                128578 non-null  int64
#  1   nAnuncio                  10956 non-null   str
#  2   TipoAnuncio               10956 non-null   str
#  3   idINCM                    10956 non-null   float64
#  4   tipoContrato              128574 non-null  str
#  5   idprocedimento            128578 non-null  int64
#  6   tipoprocedimento          128577 non-null  str
#  7   objectoContrato           128535 non-null  object
#  8   descContrato              128502 non-null  object
#  9   adjudicante               128577 non-null  str
#  10  adjudicatarios            128578 non-null  str
#  11  dataPublicacao            128578 non-null  datetime64[us]
#  12  dataCelebracaoContrato    128577 non-null  datetime64[us]
# ...
