# %% [markdown]
# # Projeto Final Aplicado a Ciência de Dados
# ## Deteção de Outliers em Contratos Públicos e Previsão do Montante de Adjudição
#
# ## Grupo 08
# ## Membros:
# ###          - Afonso Alexandre nº 123425;
# ###          - André  Freitas nº 123409;
# ###          - Gonçalo Vilhena nº 123384;
# ###          - Rodolfo Nardy nº 123419

# %% [markdown]
# #### **Reading and checking data**

# %%
import pandas as pd

# %%
#Diretório onde os arquivos de dados do trabalho estão armazenados
data_dir = "./dados/"
df_2019 = pd.read_excel(data_dir + "contratos2019.xlsx")

# %% [markdown]
# ## Análise
#
#
# ### Funções auxiliares
#
# #### Função para os top X valores mais frequentes

# %%
def print_top_n(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate the top 'n' most frequent values
    top_n_values = df[column_name].value_counts().head(top_n)

    # Print the top 'n' values
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para os top X valores mais frequentes numa lista

# %%
def print_top_n_list(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Explode the lists into separate rows
    exploded = df[column_name].explode()

    # Calculate the top 'n' most frequent individual values
    top_n_values = exploded.value_counts().head(top_n)

    # Print the results
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para mostras os X menores valores menos frequentes

# %%
def print_bottom_n(df, column_name, bottom_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts and get the bottom 'n' values
    bottom_n_values = df[column_name].value_counts().sort_values(ascending=True).head(bottom_n)

    # Print the bottom 'n' values
    print(f"Bottom {bottom_n} least frequent values for '{column_name}':")

    print(bottom_n_values)

# %% [markdown]
#  #### Função para mostrar  X menores valores menos frequentes numa lista

# %% [markdown]
# #### Function to count null and empty values

# %%
def count_null_and_empty(df, column_name):
    total = len(df)

    # Count NaN (null) values
    null_count = df[column_name].isna().sum()
    null_pct = (null_count / total) * 100

    # Count empty string values (after stripping whitespace)
    empty_count = (df[column_name].astype(str).str.strip() == '').sum()
    empty_pct = (empty_count / total) * 100

    # Print results
    print(f"Null (NaN) values: {null_count} ({null_pct:.2f}%)")
    print(f"Empty string values: {empty_count} ({empty_pct:.2f}%)")

# %% [markdown]
# #### Informações gerais do ficheiro

# %%
df_2019.info()
df_2019.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145499 entries, 0 to 145498
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                145499 non-null  int64
#  1   nAnuncio                  15958 non-null   str
#  2   TipoAnuncio               15973 non-null   str
#  3   idINCM                    15973 non-null   float64
#  4   tipoContrato              145499 non-null  str
#  5   idprocedimento            145499 non-null  int64
#  6   tipoprocedimento          145499 non-null  str
#  7   objectoContrato           145498 non-null  object
#  8   descContrato              145499 non-null  object
#  9   adjudicante               145499 non-null  str
#  10  adjudicatarios            145272 non-null  str
#  11  dataPublicacao            145499 non-null  datetime64[us]
#  12  dataCelebracaoContrato    145470 non-null  datetime64[us]
# ...

# %% [markdown]
# #### idcontrato (int64)

# %%
count_null_and_empty(df_2019, 'idcontrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
#não há repetidos
print_top_n(df_2019,"idcontrato",10)
#df_2019[df_2019["idcontrato"] == 10458767 ]
# Out:
#         idcontrato nAnuncio TipoAnuncio  idINCM           tipoContrato  \
# 142513    10458767      NaN         NaN     NaN  Aquisição de serviços
# 142514    10458767      NaN         NaN     NaN  Aquisição de serviços
#
#         idprocedimento tipoprocedimento  \
# 142513         4307698  Consulta Prévia
# 142514         4307698  Consulta Prévia
#
#                               objectoContrato  \
# 142513  Transporte Especial de alunos com NEE
# 142514  Transporte Especial de alunos com NEE
#
#                                  descContrato  \
# 142513  Transporte Especial de alunos com NEE
# 142514  Transporte Especial de alunos com NEE
#
#                                               adjudicante  ...  \
# 142513  600082172 - Agrupamento de Escolas de Venda do...  ...
# 142514  600082172 - Agrupamento de Escolas de Venda do...  ...
#
#                                                  regime  \
# 142513  Código dos Contratos Públicos ( DL 111-B/2017 )
# ...

# %% [markdown]
# #### tipoContrato (object)

# %%
count_null_and_empty(df_2019, 'tipoContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n_list(df_2019,"tipoContrato",10)
set(df_2019['tipoContrato'])
# Out:
# Top 10 most frequent values for 'tipoContrato':
# tipoContrato
# Aquisição de bens móveis                           70324
# Aquisição de serviços                              60066
# Empreitadas de obras públicas                      11521
# Locação de bens móveis                              1646
# Aquisição de bens móveis\nAquisição de serviços     1219
# Aquisição de serviços\nLocação de bens móveis        233
# Concessão de serviços públicos                       118
# Outros                                                77
# Aquisição de serviços\nSociedade                      61
# Concessão de obras públicas                           50
# Name: count, dtype: int64
# {'Aquisição de bens móveis',
#  'Aquisição de bens móveis\nAquisição de serviços',
#  'Aquisição de bens móveis\nAquisição de serviços\nConcessão de obras públicas',
#  'Aquisição de bens móveis\nAquisição de serviços\nConcessão de serviços públicos',
# ...

# %% [markdown]
# #### idProcedimento (int64)

# %%
count_null_and_empty(df_2019, 'idprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,"idprocedimento",10)
# Out:
# Top 10 most frequent values for 'idprocedimento':
# idprocedimento
# 4342117    106
# 4285109     91
# 3709583     77
# 3638384     64
# 3900723     62
# 4274209     52
# 3839029     51
# 3958674     50
# 4253129     50
# 3966018     48
# Name: count, dtype: int64

# %% [markdown]
# #### tipoprocedimento

# %%
count_null_and_empty(df_2019, 'tipoprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,"tipoprocedimento",15)  #(nem ha 10)
# Out:
# Top 15 most frequent values for 'tipoprocedimento':
# tipoprocedimento
# Ajuste Direto Regime Geral                   71874
# Consulta Prévia                              38601
# Concurso público                             16214
# Ao abrigo de acordo-quadro (art.º 259.º)     15938
# Ao abrigo de acordo-quadro (art.º 258.º)      2545
# Concurso limitado por prévia qualificação      292
# Ajuste direto simplificado                      29
# Contratação excluída II                          3
# Setores especiais – isenção parte II             2
# Parceria para a inovação                         1
# Name: count, dtype: int64

# %% [markdown]
# #### objectoContrato

# %%
count_null_and_empty(df_2019, 'objectoContrato')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,"objectoContrato",20)
# Out:
# Top 20 most frequent values for 'objectoContrato':
# objectoContrato
# MEDICAMENTOS                                                                                                                                                                                                                                                             1551
# REAGENTES                                                                                                                                                                                                                                                                 320
# Medicamentos                                                                                                                                                                                                                                                              205
# ...

# %% [markdown]
# #### descContrato (object)

# %%
count_null_and_empty(df_2019, 'descContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,"descContrato",20)
# Out:
# Top 20 most frequent values for 'descContrato':
# descContrato
# MEDICAMENTOS                                                                                                                                                                                                                                                             1503
# REAGENTES                                                                                                                                                                                                                                                                 313
# MEDICAMENTOS                                                                                                                                                                                                                                                              183
# ...

# %% [markdown]
# adjudicante (object)

# %%
count_null_and_empty(df_2019, 'adjudicante')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,"adjudicante",20)
# Out:
# Top 20 most frequent values for 'adjudicante':
# adjudicante
# 508481287 - Centro Hospitalar Universitário de Lisboa Norte, E. P. E.                                           4172
# 508094461 - Unidade Local de Saúde do Norte Alentejano, E. P. E.                                                3520
# 600012662 - Ministério da Defesa Nacional - Marinha                                                             3440
# 508142156 - Centro Hospitalar Vila Nova de Gaia - Espinho, E. P. E.                                             2637
# 508080142 - Centro Hospitalar Universitário Lisboa Central, E. P. E.                                            1919
# 510745997 - Centro Hospitalar Universitário do Algarve, E. P. E.                                                1881
# 500051070 - Município de Lisboa                                                                                 1596
# ...

# %% [markdown]
# adjudicatarios (object)

# %%
count_null_and_empty(df_2019, 'adjudicatarios')
# Out:
# Null (NaN) values: 227 (0.16%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['adjudicatarios'].head(20))
# Out:
# 0                                                   NaN
# 1     509683681 - Probroker, Mediação de Seguros Uni...
# 2                           505042037 - Sumol+Compal,SA
# 3      503239470 - Corbroker, Corretores de Seguros SA
# 4                               - - José Costa Teixeira
# 5     503290688 - Qualitalhos - Indústria e Comércio...
# 6          501145923 - Canas Engenharia e Construção SA
# 7                             508305691 - MICATERM, Lda
# 8              510792804 - WEEKENDAPARTY UNIPESSOAL,LDA
# 9                      507477740 - Canon Portugal, S.A.
# 10                       500632758 - Aquário Mundo, Lda
# 11        500233810 - ROCHE  FARMACÊUTICA QUÍMICA, lDA.
# 12                         - - Matilde Rosa Lopes Neves
# 13    505235781 - Hpz, Com. Equip de telecomunicaçõe...
# 14    504970003 - POLARGEL, COMÉRCIO DE PRODUTOS ALI...
# 15                503015385 - MX3 - ARTES GRÁFICAS, LDA
# 16    502983485 - Kodis Comércio de Bebidas e Produt...
# ...

# %% [markdown]
# dataPublicacao (object)

# %%
count_null_and_empty(df_2019, 'dataPublicacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['dataPublicacao'].head(10))
# Out:
# 0   2019-01-02
# 1   2019-01-02
# 2   2019-01-02
# 3   2019-01-02
# 4   2019-01-02
# 5   2019-01-02
# 6   2019-01-02
# 7   2019-01-02
# 8   2019-01-02
# 9   2019-01-03
# Name: dataPublicacao, dtype: datetime64[us]

# %% [markdown]
# dataCelebracaoContrato (object)

# %%
count_null_and_empty(df_2015, 'dataCelebracaoContrato')
# Out:
# Null (NaN) values: 9 (0.01%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['dataCelebracaoContrato'].head(10))
# Out:
# 0          NaT
# 1   2015-01-02
# 2   2015-01-02
# 3   2015-01-02
# 4   2015-01-02
# 5   2015-01-02
# 6          NaT
# 7          NaT
# 8   2015-01-02
# 9   2015-01-02
# Name: dataCelebracaoContrato, dtype: datetime64[us]

# %% [markdown]
# precoContratual (float64)

# %%
count_null_and_empty(df_2019, 'precoContratual')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['precoContratual'].head(10))
min(df_2019['precoContratual'])
# Out:
# 0         0.00
# 1      3973.57
# 2      2268.00
# 3      1575.61
# 4      8869.44
# 5      9748.60
# 6    333810.86
# 7      8920.00
# 8     74999.97
# 9      6950.00
# Name: precoContratual, dtype: float64
# -952500.0

# %% [markdown]
# cpv (object)

# %%
count_null_and_empty(df_2019, 'CPV')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['CPV'].head(10))
# Out:
# 0    24900000-3 - Produtos químicos variados e de a...
# 1        66512100-3 - Serviços de seguros de acidentes
# 2                          15321000-4 - Sumos de fruta
# 3            66512200-4 - Serviços de seguros de saúde
# 4    77311000-3 - Serviços de manutenção de jardins...
# 5                         15119000-5 - Carnes diversas
# 6    51110000-6 - Serviços de instalação de equipam...
# 7    50330000-7 - Serviços de manutenção de equipam...
# 8    92620000-3 - Serviços relacionados com o desporto
# 9    30232100-5 - Impressoras e traçadores de gráficos
# Name: CPV, dtype: str

# %% [markdown]
# prazoExecucao (int64)

# %%
count_null_and_empty(df_2019, 'prazoExecucao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019, 'prazoExecucao', 10)
# Out:
# Top 10 most frequent values for 'prazoExecucao':
# prazoExecucao
# 365     23657
# 30      13307
# 1        6797
# 60       6100
# 20       5721
# 1095     4713
# 90       4528
# 15       3837
# 180      3596
# 5        3013
# Name: count, dtype: int64

# %%
print_bottom_n(df_2019,'prazoExecucao',10)
# Out:
# Bottom 10 least frequent values for 'prazoExecucao':
# prazoExecucao
# 1767    1
# 806     1
# 494     1
# 1091    1
# 1218    1
# 2112    1
# 1645    1
# 2769    1
# 1613    1
# 1412    1
# Name: count, dtype: int64

# %%
max_prazo_valor = df_2019['prazoExecucao'].max()
print("Maximum 'prazoExecucao (dias)':", max_prazo_valor)
print("Maximum 'prazoExecucao (anos)':", max_prazo_valor/365)
#impossível
# Out:
# Maximum 'prazoExecucao (dias)': 36522400
# Maximum 'prazoExecucao (anos)': 100061.3698630137

# %% [markdown]
# localExecucao (object)

# %%
count_null_and_empty(df_2019, 'LocalExecucao')
# Out:
# Null (NaN) values: 29 (0.02%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['LocalExecucao'].head(10))
# Out:
# 0         Portugal, Braga, Barcelos
# 1    Portugal, Portugal Continental
# 2             Portugal, Faro, Olhão
# 3            Portugal, Braga, Braga
# 4       Portugal, Porto, Felgueiras
# 5             Portugal, Faro, Olhão
# 6      Portugal, Santarém, Alpiarça
# 7           Portugal, Lisboa, Mafra
# 8        Portugal, Lisboa, Odivelas
# 9                          Portugal
# Name: LocalExecucao, dtype: str

# %% [markdown]
# fundamentacao (object)

# %%
count_null_and_empty(df_2019, 'fundamentacao')
# Out:
# Null (NaN) values: 30 (0.02%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019, 'fundamentacao', 10)
# Out:
# Top 10 most frequent values for 'fundamentacao':
# fundamentacao
# Artigo 20.º, n.º 1, alínea d) do Código dos Contratos Públicos                    35074
# Artigo 20.º, n.º 1, alínea c) do Código dos Contratos Públicos                    29783
# Artigo 259.º do Código dos Contratos Públicos                                     15738
# Artigo 24.º, n.º 1, alínea c) do Código dos Contratos Públicos                     9854
# Artigo 24.º, n.º 1, alínea e), subalínea ii) do Código dos Contratos Públicos      8770
# Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos                     7975
# Artigo 19.º, alínea c) do Código dos Contratos Públicos                            5127
# Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos                     4570
# Artigo 24.º, n.º 1, alínea e), subalínea iii) do Código dos Contratos Públicos     4332
# Artigo 19.º, alínea b) do Código dos Contratos Públicos                            2567
# Name: count, dtype: int64

# %% [markdown]
# ProcedimentoCentralizado (object)

# %%
count_null_and_empty(df_2019, 'ProcedimentoCentralizado')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019, 'ProcedimentoCentralizado', 10)
# Out:
# Top 10 most frequent values for 'ProcedimentoCentralizado':
# ProcedimentoCentralizado
# Não    140229
# Sim      5270
# Name: count, dtype: int64

# %% [markdown]
# DescrAcordoQuadro (object)

# %%
count_null_and_empty(df_2019, 'DescrAcordoQuadro')
# Out:
# Null (NaN) values: 127512 (87.64%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,"DescrAcordoQuadro",10)
# Out:
# Top 10 most frequent values for 'DescrAcordoQuadro':
# DescrAcordoQuadro
# CP 2017/6 - Acordo Quadro para fornecimento de Medicamentos do Foro Oncológico e Imunomoduladores, às Instituições e Serviços do Serviço Nacional de Saúde                                                                                                         2223
# CP 2017/5 - Acordo Quadro para fornecimento de Medicamentos anti-infeciosos: exceto antivíricos e antifúngicos                                                                                                                                                      533
# CP 2017/9 - Acordo quadro para fornecimento de Derivados do Plasma Humano às Instituições e Serviços do Serviço Nacional de Saúde                                                                                                                                   497
# ...

# %% [markdown]
# precoBaseProcedimento (float64)

# %%
count_null_and_empty(df_2019, 'precoBaseProcedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,"precoBaseProcedimento",10)
# Out:
# Top 10 most frequent values for 'precoBaseProcedimento':
# precoBaseProcedimento
# 0.0        5591
# 15000.0    1141
# 10000.0    1049
# 12000.0     789
# 6000.0      785
# 20000.0     779
# 9000.0      759
# 18000.0     752
# 8000.0      633
# 7500.0      622
# Name: count, dtype: int64
# -31200.0

# %% [markdown]
# dataDecisaoAdjudicacao (object)

# %%
count_null_and_empty(df_2019, 'dataDecisaoAdjudicacao')
# Out:
# Null (NaN) values: 29 (0.02%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,"dataDecisaoAdjudicacao",20)
# Out:
# Top 20 most frequent values for 'dataDecisaoAdjudicacao':
# dataDecisaoAdjudicacao
# 2019-01-24    1163
# 2019-01-31    1139
# 2019-05-16     988
# 2019-02-28     900
# 2019-04-04     854
# 2019-02-21     846
# 2019-02-14     826
# 2019-01-21     824
# 2019-03-14     802
# 2019-01-02     797
# 2019-02-07     793
# 2019-01-10     783
# 2019-03-07     782
# 2019-03-21     773
# 2019-01-30     754
# 2019-03-28     729
# 2019-01-22     721
# 2019-03-13     708
# 2019-01-17     707
# 2019-05-30     706
# Name: count, dtype: int64

# %% [markdown]
# dataFechoContrato (object)

# %%
count_null_and_empty(df_2019, 'dataFechoContrato')
# Out:
# Null (NaN) values: 90700 (62.34%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,"dataFechoContrato",10)
# Out:
# Top 10 most frequent values for 'dataFechoContrato':
# dataFechoContrato
# 2019-12-31    6805
# 2020-12-31    1222
# 2019-12-30    1009
# 2019-12-27     745
# 2019-12-20     697
# 2019-12-19     450
# 2019-12-26     401
# 2019-12-23     347
# 2019-12-17     336
# 2019-10-31     319
# Name: count, dtype: int64

# %% [markdown]
# PrecoTotalEfetivo

# %%
count_null_and_empty(df_2019, 'PrecoTotalEfetivo')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['PrecoTotalEfetivo'].head(10))
# Out:
# 0       0.00
# 1    3973.57
# 2       0.00
# 3       0.00
# 4    8869.44
# 5       0.00
# 6       0.00
# 7    8920.00
# 8       0.00
# 9       0.00
# Name: PrecoTotalEfetivo, dtype: float64

# %%
print_top_n(df_2019,"PrecoTotalEfetivo",10)
# Out:
# Top 10 most frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 0.0        90451
# 1000.0       254
# 6000.0       233
# 500.0        226
# 9000.0       214
# 15000.0      202
# 7500.0       180
# 10000.0      180
# 12000.0      163
# 18000.0      145
# Name: count, dtype: int64

# %%
print_bottom_n(df_2019,"PrecoTotalEfetivo",10)
# Out:
# Bottom 10 least frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 1554.60     1
# 598.82      1
# 190.97      1
# 32232.36    1
# 20960.30    1
# 85600.00    1
# 59313.07    1
# 7716.79     1
# 813.03      1
# 53553.60    1
# Name: count, dtype: int64

# %% [markdown]
# regime (object)

# %%
count_null_and_empty(df_2019, 'regime')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['regime'].head(10))
# Out:
# 0    Código dos Contratos Públicos ( DL 111-B/2017 )
# 1    Código dos Contratos Públicos ( DL 111-B/2017 )
# 2    Código dos Contratos Públicos ( DL 111-B/2017 )
# 3    Código dos Contratos Públicos ( DL 111-B/2017 )
# 4    Código dos Contratos Públicos ( DL 111-B/2017 )
# 5    Código dos Contratos Públicos ( DL 111-B/2017 )
# 6    Código dos Contratos Públicos ( DL 111-B/2017 )
# 7    Código dos Contratos Públicos ( DL 111-B/2017 )
# 8    Código dos Contratos Públicos ( DL 111-B/2017 )
# 9    Código dos Contratos Públicos ( DL 111-B/2017 )
# Name: regime, dtype: str

# %% [markdown]
# tipoFimContrato (object)

# %%
count_null_and_empty(df_2019, 'tipoFimContrato')
# Out:
# Null (NaN) values: 89767 (61.70%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019, 'tipoFimContrato', 10)
# Out:
# Top 10 most frequent values for 'tipoFimContrato':
# tipoFimContrato
# O cumprimento, a impossibilidade definitiva e todas as restantes causas de extinção das obrigações reconhecidas pelo direito civil    54434
# Resolução do Contrato                                                                                                                   912
# Revogação do Contrato                                                                                                                   339
# Anulado ou Declarado Nulo                                                                                                                34
# Contrato Anulado, Declarado Nulo ou Objecto de Recusa de Visto                                                                           11
# Objeto de recusa de visto do Tribunal de Contas                                                                                           2
# Name: count, dtype: int64

# %% [markdown]
# CritMateriais (object)

# %%
count_null_and_empty(df_2019, 'CritMateriais')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['CritMateriais'].head(10))
# Out:
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# 5    Não
# 6    Não
# 7    Não
# 8    Não
# 9    Não
# Name: CritMateriais, dtype: str

# %%
print_top_n(df_2019,"CritMateriais",2)
# Out:
# Top 2 most frequent values for 'CritMateriais':
# CritMateriais
# Não    114494
# Sim     31005
# Name: count, dtype: int64

# %% [markdown]
# concorrentes (object)

# %%
count_null_and_empty(df_2019, 'concorrentes')
# Out:
# Null (NaN) values: 91891 (63.16%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['concorrentes'].tail(10))
# Out:
# 145489            513975500-BOLEIXA ESGAIO UNIPESSOAL, LDA.
# 145490                       --Pedro Miguel Camejo Pernadas
# 145491              --MIGUEL BACEIRA ROLDÃO DA SILVA SANTOS
# 145492    503188620-SGALD Automotive - Soc Geral de Comé...
# 145493    503188620-SGALD Automotive - Soc Geral de Comé...
# 145494                                                  NaN
# 145495    504853635-Cascais Próxima - Gestão de Mobilida...
# 145496                511135610-Acin-Icloud Solutions, Lda.
# 145497    507052609-MAX ONE - MATERIAL DE ESCRITÓRIO, LD...
# 145498                                    502034831-Ferring
# Name: concorrentes, dtype: str

# %% [markdown]
# linkPecasProc (object)

# %%
count_null_and_empty(df_2019, 'linkPecasProc')
# Out:
# Null (NaN) values: 144626 (99.40%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Observacoes (object)

# %%
count_null_and_empty(df_2019, 'Observacoes')
# Out:
# Null (NaN) values: 132018 (90.73%)
# Empty string values: 320 (0.22%)

# %% [markdown]
# ContratEcologico (object)

# %%
count_null_and_empty(df_2019, 'ContratEcologico')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Ano (int64)

# %%
count_null_and_empty(df_2019, 'Ano')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2019['Ano'].head(10))
# Out:
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# 5    2019
# 6    2019
# 7    2019
# 8    2019
# 9    2019
# Name: Ano, dtype: int64

# %% [markdown]
# fundamentAjusteDireto

# %%
count_null_and_empty(df_2019, 'fundamentAjusteDireto')
# Out:
# Null (NaN) values: 73853 (50.76%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2019,'fundamentAjusteDireto',2)
# Out:
# Top 2 most frequent values for 'fundamentAjusteDireto':
# fundamentAjusteDireto
# ausência de recursos próprios    69356
# outros                            2290
# Name: count, dtype: int64
