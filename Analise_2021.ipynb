# %% [markdown]
# # Projeto Final Aplicado a Ciência de Dados
# ## Deteção de Outliers em Contratos Públicos e Previsão do Montante de Adjudição
#
# ## Grupo 08
# ## Membros:
# ###          - Afonso Alexandre nº 123425;
# ###          - André  Freitas nº 123409;
# ###          - Gonçalo Vilhena nº 123384;
# ###          - Rodolfo Nardy nº 123419

# %% [markdown]
# #### **Reading and checking data**

# %%
import pandas as pd

# %%
#Diretório onde os arquivos de dados do trabalho estão armazenados
data_dir = "./dados/"
df_2021 = pd.read_excel(data_dir + "contratos2021.xlsx")

# %% [markdown]
# ## Análise
#
#
# ### Funções auxiliares
#
# #### Função para os top X valores mais frequentes

# %%
def print_top_n(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate the top 'n' most frequent values
    top_n_values = df[column_name].value_counts().head(top_n)

    # Print the top 'n' values
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para os top X valores mais frequentes numa lista

# %%
def print_top_n_list(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Explode the lists into separate rows
    exploded = df[column_name].explode()

    # Calculate the top 'n' most frequent individual values
    top_n_values = exploded.value_counts().head(top_n)

    # Print the results
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para mostras os X menores valores menos frequentes

# %%
def print_bottom_n(df, column_name, bottom_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts and get the bottom 'n' values
    bottom_n_values = df[column_name].value_counts().sort_values(ascending=True).head(bottom_n)

    # Print the bottom 'n' values
    print(f"Bottom {bottom_n} least frequent values for '{column_name}':")

    print(bottom_n_values)

# %% [markdown]
#  #### Função para mostrar  X menores valores menos frequentes numa lista

# %% [markdown]
# #### Function to count null and empty values

# %%
def count_null_and_empty(df, column_name):
    total = len(df)

    # Count NaN (null) values
    null_count = df[column_name].isna().sum()
    null_pct = (null_count / total) * 100

    # Count empty string values (after stripping whitespace)
    empty_count = (df[column_name].astype(str).str.strip() == '').sum()
    empty_pct = (empty_count / total) * 100

    # Print results
    print(f"Null (NaN) values: {null_count} ({null_pct:.2f}%)")
    print(f"Empty string values: {empty_count} ({empty_pct:.2f}%)")

# %% [markdown]
# #### Informações gerais do ficheiro

# %%
df_2021.info()
df_2021.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 187356 entries, 0 to 187355
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                187356 non-null  int64
#  1   nAnuncio                  21563 non-null   str
#  2   TipoAnuncio               21563 non-null   str
#  3   idINCM                    21563 non-null   float64
#  4   tipoContrato              187355 non-null  str
#  5   idprocedimento            187356 non-null  int64
#  6   tipoprocedimento          187356 non-null  str
#  7   objectoContrato           187356 non-null  object
#  8   descContrato              187356 non-null  object
#  9   adjudicante               187356 non-null  str
#  10  adjudicatarios            187037 non-null  str
#  11  dataPublicacao            187356 non-null  datetime64[us]
#  12  dataCelebracaoContrato    177419 non-null  datetime64[us]
# ...

# %% [markdown]
# #### idcontrato (int64)

# %%
count_null_and_empty(df_2021, 'idcontrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
#não há repetidos
print_top_n(df_2021,"idcontrato",10)
# Out:
# Top 10 most frequent values for 'idcontrato':
# idcontrato
# 7740006     2
# 7740147     2
# 7756902     2
# 7884351     2
# 8028898     2
# 10426232    2
# 10428375    2
# 10429194    2
# 10433402    2
# 10437493    2
# Name: count, dtype: int64

# %% [markdown]
# #### tipoContrato (object)

# %%
count_null_and_empty(df_2021, 'tipoContrato')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n_list(df_2021,"tipoContrato",10)
df_2021['tipoContrato'].unique()
# Out:
# Top 10 most frequent values for 'tipoContrato':
# tipoContrato
# Aquisição de bens móveis                                                   104753
# Aquisição de serviços                                                       64764
# Empreitadas de obras públicas                                               13840
# Locação de bens móveis                                                       1633
# Aquisição de bens móveis\nAquisição de serviços                              1509
# Aquisição de serviços\nLocação de bens móveis                                 239
# Concessão de serviços públicos                                                128
# Aquisição de serviços\nEmpreitadas de obras públicas                           80
# Concessão de obras públicas                                                    76
# Aquisição de bens móveis\nAquisição de serviços\nLocação de bens móveis        67
# Name: count, dtype: int64
# <StringArray>
# ...

# %% [markdown]
# #### idProcedimento (int64)

# %%
count_null_and_empty(df_2021, 'idprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,"idprocedimento",10)
# Out:
# Top 10 most frequent values for 'idprocedimento':
# idprocedimento
# 5681368    139
# 5428309    127
# 5681595    116
# 5074597    115
# 5051397    107
# 5254191    101
# 5332530     99
# 5161289     98
# 5149591     91
# 4847303     80
# Name: count, dtype: int64

# %% [markdown]
# #### tipoprocedimento

# %%
count_null_and_empty(df_2021, 'tipoprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,"tipoprocedimento",10)  #(nem ha 10)
# Out:
# Top 10 most frequent values for 'tipoprocedimento':
# tipoprocedimento
# Ajuste Direto Regime Geral                                           96345
# Consulta Prévia                                                      37279
# Concurso público                                                     21322
# Ao abrigo de acordo-quadro (art.º 259.º)                             17147
# Ajuste direto simplificado                                            9656
# Ao abrigo de acordo-quadro (art.º 258.º)                              4843
# Concurso limitado por prévia qualificação                              309
# Ajuste direto simplificado ao abrigo da Lei n.º 30/2021, de 21.05      281
# Consulta Prévia Simplificada                                            89
# Contratação excluída II                                                 40
# Name: count, dtype: int64

# %% [markdown]
# #### objectoContrato

# %%
count_null_and_empty(df_2021, 'objectoContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,"objectoContrato",20)
# Out:
# Top 20 most frequent values for 'objectoContrato':
# objectoContrato
# MEDICAMENTOS                                                                                                                                                                                                                                                         1339
# VÁRIOS MEDICAMENTOS                                                                                                                                                                                                                                                   327
# Medicamentos                                                                                                                                                                                                                                                          178
# ...

# %% [markdown]
# #### descContrato (object)

# %%
count_null_and_empty(df_2021, 'descContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,"descContrato",20)
#df_2021[df_2021["descContrato"] == "Contrato de empreitada"]
# Out:
# Top 20 most frequent values for 'descContrato':
# descContrato
# MEDICAMENTOS                                                                                                                                                                                                                                                         1335
# Contrato de Avença                                                                                                                                                                                                                                                    158
# Procedimento agregado ao abrigo dos lotes 1, 2, 5 e 8 do acordo quadro para o fornecimento de combustíveis rodoviários                                                                                                                                                155
# ...

# %% [markdown]
# adjudicante (object)

# %%
count_null_and_empty(df_2021, 'adjudicante')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,"adjudicante",20)
# Out:
# Top 20 most frequent values for 'adjudicante':
# adjudicante
# 506362299 - Instituto Português de Oncologia do Porto Francisco Gentil, E. P. E.        15972
# 600012662 - Ministério da Defesa Nacional - Marinha                                      5556
# 508481287 - Centro Hospitalar Universitário de Lisboa Norte, E. P. E.                    3996
# 509822940 - Centro Hospitalar Tondela-Viseu, E. P. E.                                    3389
# 600010180 - Estado-Maior-General das Forças Armadas (EMGFA)                              2561
# 508094461 - Unidade Local de Saúde do Norte Alentejano, E. P. E.                         2276
# 510103448 - Centro Hospitalar e Universitário de Coimbra, E. P. E.                       2028
# 513606084 - Águas do Norte, S. A.                                                        1715
# 506361616 - Instituto Português de Oncologia de Lisboa Francisco Gentil, E. P. E.        1708
# ...

# %% [markdown]
# adjudicatarios (object)

# %%
count_null_and_empty(df_2021, 'adjudicatarios')
# Out:
# Null (NaN) values: 319 (0.17%)
# Empty string values: 0 (0.00%)

# %%
print(df_2021['adjudicatarios'].head(20))
# Out:
# 0     515655163 - Ambimerufe - Construções, Silvicul...
# 1                                      - - Cirque Aital
# 2     506565165 - Prodyalca - Comércio Produtos Quim...
# 3                         - - ASSOCIATION ML PRODUCTION
# 4     501390324 - Extincêndios, Equipamentos de Prot...
# 5      506093190 - Penasegur - Mediação de Seguros,Lda.
# 6                      - - Vítor Manuel Gonçalves Rocha
# 7                    509464513 - NUNEX - WORDWIDE, S.A.
# 8                             503694479 - FLOPONOR, S.A
# 9                            - - Fiksdal Dans Stiftelse
# 10                      515471836 - OFICINIA NOMADA LDA
# 11                              503724947 - BENEDITA FM
# 12    501467939 - Expandindústria - Estudos, Project...
# 13                      - - Filomena Guimarães Ferreira
# 14            514717610 - Malvalunar - Unipessoal, Lda.
# 15                          - - Fernando Vieira Pacheco
# 16                               - - António José Pinto
# ...

# %% [markdown]
# dataPublicacao (object)

# %%
count_null_and_empty(df_2021, 'dataPublicacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2021['dataPublicacao'].head(10))
# Out:
# 0   2020-08-07
# 1   2020-11-06
# 2   2020-11-10
# 3   2020-12-10
# 4   2020-12-17
# 5   2021-01-01
# 6   2021-01-01
# 7   2020-03-04
# 8   2020-06-15
# 9   2020-10-06
# Name: dataPublicacao, dtype: datetime64[us]

# %% [markdown]
# dataCelebracaoContrato (object)

# %%
count_null_and_empty(df_2021, 'dataCelebracaoContrato')
# Out:
# Null (NaN) values: 9937 (5.30%)
# Empty string values: 0 (0.00%)

# %%
print(df_2021['dataCelebracaoContrato'].head(10))
# Out:
# 0   2021-06-19
# 1          NaT
# 2          NaT
# 3          NaT
# 4          NaT
# 5   2021-01-01
# 6   2021-01-01
# 7   2021-09-06
# 8   2021-09-30
# 9          NaT
# Name: dataCelebracaoContrato, dtype: datetime64[us]

# %% [markdown]
# precoContratual (float64)

# %%
count_null_and_empty(df_2021, 'precoContratual')
min(df_2021['precoContratual'])
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# 0.0

# %%
print(df_2021['precoContratual'].head(10))
# Out:
# 0     111718.29
# 1      13797.11
# 2        247.00
# 3       5840.00
# 4      18750.00
# 5        111.87
# 6       3021.79
# 7     269969.40
# 8    1098846.87
# 9       9388.76
# Name: precoContratual, dtype: float64

# %%
print_top_n(df_2021,'precoContratual',10)
# Out:
# Top 10 most frequent values for 'precoContratual':
# precoContratual
# 15000.0    757
# 10000.0    689
# 6000.0     685
# 18000.0    591
# 12000.0    575
# 9000.0     533
# 19500.0    476
# 7500.0     474
# 20000.0    471
# 19900.0    398
# Name: count, dtype: int64

# %% [markdown]
# cpv (object)

# %%
count_null_and_empty(df_2021, 'CPV')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2021['CPV'].head(10))
# Out:
# 0                              45000000-7 - Construção
# 1    92000000-1 - Serviços recreativos, culturais e...
# 2                       24000000-4 - Produtos químicos
# 3                    92300000-4 - Serviços recreativos
# 4              33140000-3 - Material médico de consumo
# 5          66000000-0 - Serviços de finanças e seguros
# 6          66000000-0 - Serviços de finanças e seguros
# 7                    33751000-9 - Fraldas descartáveis
# 8       45214200-2 - Construção de edifícios escolares
# 9    92312100-2 - Serviços recreativos de produtore...
# Name: CPV, dtype: str

# %% [markdown]
# prazoExecucao (int64)

# %%
count_null_and_empty(df_2021, 'prazoExecucao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021, 'prazoExecucao', 10)
# Out:
# Top 10 most frequent values for 'prazoExecucao':
# prazoExecucao
# 365     25911
# 20      21627
# 30      16064
# 0       10020
# 60       7481
# 1        7179
# 1095     5654
# 90       5550
# 730      3964
# 15       3474
# Name: count, dtype: int64

# %%
print_bottom_n(df_2021,'prazoExecucao',10)
# Out:
# Bottom 10 least frequent values for 'prazoExecucao':
# prazoExecucao
# 32872     1
# 12053     1
# 10592     1
# 4414      1
# 1521      1
# 13879     1
# 133313    1
# 497       1
# 1492      1
# 829       1
# Name: count, dtype: int64

# %%
max_prazo_valor = df_2021['prazoExecucao'].max()
print("Maximum 'prazoExecucao (dias)':", max_prazo_valor)
print("Maximum 'prazoExecucao (anos)':", max_prazo_valor/365)
#impossível
# Out:
# Maximum 'prazoExecucao (dias)': 9826121
# Maximum 'prazoExecucao (anos)': 26920.879452054796

# %% [markdown]
# localExecucao (object)

# %%
count_null_and_empty(df_2021, 'LocalExecucao')
# Out:
# Null (NaN) values: 9489 (5.06%)
# Empty string values: 0 (0.00%)

# %%
print(df_2021['LocalExecucao'].head(10))
# Out:
# 0    Portugal, Viana do Castelo, Ponte de Lima
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5           Portugal, Aveiro, Castelo de Paiva
# 6           Portugal, Aveiro, Castelo de Paiva
# 7                                     Portugal
# 8                       Portugal, Viseu, Viseu
# 9                                          NaN
# Name: LocalExecucao, dtype: str

# %% [markdown]
# fundamentacao (object)

# %%
count_null_and_empty(df_2021, 'fundamentacao')
# Out:
# Null (NaN) values: 9940 (5.31%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021, 'fundamentacao', 10)
# Out:
# Top 10 most frequent values for 'fundamentacao':
# fundamentacao
# Artigo 20.º, n.º 1, alínea d) do Código dos Contratos Públicos                    35051
# Artigo 20.º, n.º 1, alínea c) do Código dos Contratos Públicos                    28826
# Artigo 24.º, n.º 1, alínea c) do Código dos Contratos Públicos                    27052
# Artigo 259.º do Código dos Contratos Públicos                                     16743
# Artigo 24.º, n.º 1, alínea e), subalínea ii) do Código dos Contratos Públicos     11205
# Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos                    10066
# Artigo 24.º, n.º 1, alínea e), subalínea iii) do Código dos Contratos Públicos     5966
# Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos                     5807
# Artigo 19.º, alínea c) do Código dos Contratos Públicos                            5539
# Artigo 19.º, alínea b) do Código dos Contratos Públicos                            3662
# Name: count, dtype: int64

# %% [markdown]
# ProcedimentoCentralizado (object)

# %%
count_null_and_empty(df_2021, 'ProcedimentoCentralizado')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021, 'ProcedimentoCentralizado', 10)
# Out:
# Top 10 most frequent values for 'ProcedimentoCentralizado':
# ProcedimentoCentralizado
# Não    181128
# Sim      6228
# Name: count, dtype: int64

# %% [markdown]
# DescrAcordoQuadro (object)

# %%
count_null_and_empty(df_2021, 'DescrAcordoQuadro')
# Out:
# Null (NaN) values: 166092 (88.65%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,"DescrAcordoQuadro",10)
# Out:
# Top 10 most frequent values for 'DescrAcordoQuadro':
# DescrAcordoQuadro
# CP 2021/6 - Medicamentos do foro oncológico e imunomoduladores                                                                                                       1340
# CP 2017/6 - Acordo Quadro para fornecimento de Medicamentos do Foro Oncológico e Imunomoduladores, às Instituições e Serviços do Serviço Nacional de Saúde           1321
# CP 2020/1 - Medicamentos do aparelho cardiovascular                                                                                                                   871
# CP 2020/2 - Medicamentos do sistema nervoso cerebrospinal exceto anestésicos, relaxantes musculares, analgésicos, antipiréticos, antidepressivos e antipsicóticos     816
# CP 2020/5 - Medicamentos anti-infeciosos: exceto antivíricos e antifúngicos                                                                                           747
# ...

# %% [markdown]
# precoBaseProcedimento (float64)

# %%
count_null_and_empty(df_2021, 'precoBaseProcedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,"precoBaseProcedimento",10)
# Out:
# Top 10 most frequent values for 'precoBaseProcedimento':
# precoBaseProcedimento
# 0.0        15024
# 15000.0     1039
# 10000.0      971
# 20000.0      799
# 6000.0       740
# 18000.0      727
# 12000.0      707
# 30000.0      621
# 9000.0       619
# 7500.0       580
# Name: count, dtype: int64

# %% [markdown]
# dataDecisaoAdjudicacao (object)

# %%
count_null_and_empty(df_2021, 'dataDecisaoAdjudicacao')
# Out:
# Null (NaN) values: 9932 (5.30%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,"dataDecisaoAdjudicacao",20)
# Out:
# Top 20 most frequent values for 'dataDecisaoAdjudicacao':
# dataDecisaoAdjudicacao
# 2021-09-17    1276
# 2021-01-21    1109
# 2021-01-28    1107
# 2021-12-09    1075
# 2021-03-25    1074
# 2021-04-15    1047
# 2021-06-09    1045
# 2021-02-11    1026
# 2021-02-25    1016
# 2021-01-27     985
# 2021-04-08     985
# 2021-09-21     970
# 2021-07-16     961
# 2021-02-18     960
# 2021-09-16     959
# 2021-05-27     952
# 2021-12-02     952
# 2021-01-25     932
# 2021-05-06     932
# 2021-03-30     923
# Name: count, dtype: int64

# %% [markdown]
# dataFechoContrato (object)

# %%
count_null_and_empty(df_2021, 'dataFechoContrato')
# Out:
# Null (NaN) values: 110550 (59.01%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,"dataFechoContrato",10)
# Out:
# Top 10 most frequent values for 'dataFechoContrato':
# dataFechoContrato
# 2021-12-31    6954
# 2021-12-30    1545
# 2022-12-31    1202
# 2021-12-29     789
# 2021-12-28     635
# 2021-12-22     550
# 2022-12-30     536
# 2021-12-20     527
# 2021-12-21     516
# 2021-12-27     487
# Name: count, dtype: int64

# %% [markdown]
# PrecoTotalEfetivo

# %%
count_null_and_empty(df_2021, 'PrecoTotalEfetivo')
min(df_2021['PrecoTotalEfetivo'])
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# -5266.05

# %%
print(df_2021['PrecoTotalEfetivo'].head(10))
# Out:
# 0     111718.29
# 1      13797.11
# 2        247.00
# 3       5840.00
# 4      18750.00
# 5        111.87
# 6       3021.73
# 7          0.00
# 8    1453543.21
# 9       9388.76
# Name: PrecoTotalEfetivo, dtype: float64

# %%
print_top_n(df_2021,"PrecoTotalEfetivo",10)
# Out:
# Top 10 most frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 0.0        111440
# 6000.0        314
# 15000.0       274
# 10000.0       262
# 7500.0        251
# 9000.0        231
# 18000.0       230
# 12000.0       230
# 8400.0        203
# 19500.0       175
# Name: count, dtype: int64

# %%
print_bottom_n(df_2021,"PrecoTotalEfetivo",10)
# Out:
# Bottom 10 least frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 90728.78      1
# 1480.20       1
# 19891.00      1
# 127641.51     1
# 1347037.29    1
# 2922.19       1
# 2466443.24    1
# 2721.25       1
# 259995.84     1
# 7705.54       1
# Name: count, dtype: int64

# %% [markdown]
# regime (object)

# %%
count_null_and_empty(df_2021, 'regime')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2021['regime'].head(10))
# Out:
# 0    Código dos Contratos Públicos ( DL 111-B/2017 )
# 1                Decreto-Lei n.º 10-A/2020, de 13.03
# 2                Decreto-Lei n.º 10-A/2020, de 13.03
# 3                Decreto-Lei n.º 10-A/2020, de 13.03
# 4                Decreto-Lei n.º 10-A/2020, de 13.03
# 5    Código dos Contratos Públicos ( DL 111-B/2017 )
# 6    Código dos Contratos Públicos ( DL 111-B/2017 )
# 7    Código dos Contratos Públicos ( DL 111-B/2017 )
# 8    Código dos Contratos Públicos ( DL 111-B/2017 )
# 9                Decreto-Lei n.º 10-A/2020, de 13.03
# Name: regime, dtype: str

# %% [markdown]
# tipoFimContrato (object)

# %%
count_null_and_empty(df_2021, 'tipoFimContrato')
# Out:
# Null (NaN) values: 120494 (64.31%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021, 'tipoFimContrato', 10)
# Out:
# Top 10 most frequent values for 'tipoFimContrato':
# tipoFimContrato
# O cumprimento, a impossibilidade definitiva e todas as restantes causas de extinção das obrigações reconhecidas pelo direito civil    65342
# Resolução do Contrato                                                                                                                   857
# Revogação do Contrato                                                                                                                   548
# Anulado ou Declarado Nulo                                                                                                                93
# Contrato Anulado, Declarado Nulo ou Objecto de Recusa de Visto                                                                           19
# Objeto de recusa de visto do Tribunal de Contas                                                                                           3
# Name: count, dtype: int64

# %% [markdown]
# CritMateriais (object)

# %%
count_null_and_empty(df_2021, 'CritMateriais')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2021['CritMateriais'].head(10))
# Out:
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# 5    Não
# 6    Não
# 7    Não
# 8    Não
# 9    Não
# Name: CritMateriais, dtype: str

# %%
print_top_n(df_2021,"CritMateriais",20)
# Out:
# Top 20 most frequent values for 'CritMateriais':
# CritMateriais
# Não    138841
# Sim     48515
# Name: count, dtype: int64

# %% [markdown]
# concorrentes (object)

# %%
count_null_and_empty(df_2021, 'concorrentes')
# Out:
# Null (NaN) values: 102514 (54.72%)
# Empty string values: 0 (0.00%)

# %%
print(df_2021['concorrentes'].tail(10))
# Out:
# 187346                              --Mariana da Cruz Alves
# 187347    501323325-UNISELF- SOCIEDADE DE RESTAURANTES P...
# 187348    500745749-Escola Superior de Saúde da Cruz Ver...
# 187349    502853417-OMNISERVIÇOS, REPRESENTAÇÕES SERV.\n...
# 187350    508476763-GLOBAL ONE INFORMÁTICA DE CONSUMO\n5...
# 187351                                                  NaN
# 187352                                                  NaN
# 187353                                                  NaN
# 187354                     506058654-Franklab Portugal, Lda
# 187355    503531588-LUSOPALEX PRODUTOS DE SAUDE UNIPESSO...
# Name: concorrentes, dtype: str

# %% [markdown]
# linkPecasProc (object)

# %%
count_null_and_empty(df_2021, 'linkPecasProc')
# Out:
# Null (NaN) values: 108396 (57.86%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Observacoes (object)

# %%
count_null_and_empty(df_2021, 'Observacoes')
# Out:
# Null (NaN) values: 178861 (95.47%)
# Empty string values: 76 (0.04%)

# %% [markdown]
# ContratEcologico (object)

# %%
count_null_and_empty(df_2021, 'ContratEcologico')
print_top_n(df_2021, 'ContratEcologico',2)
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# Top 2 most frequent values for 'ContratEcologico':
# ContratEcologico
# Não    180633
# Sim      6723
# Name: count, dtype: int64

# %% [markdown]
# Ano (int64)

# %%
count_null_and_empty(df_2021, 'Ano')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2021['Ano'].head(10))
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# 5    2021
# 6    2021
# 7    2021
# 8    2021
# 9    2021
# Name: Ano, dtype: int64

# %% [markdown]
# fundamentAjusteDireto (object)

# %%
count_null_and_empty(df_2021, 'fundamentAjusteDireto')
# Out:
# Null (NaN) values: 91623 (48.90%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2021,'fundamentAjusteDireto',2)
# Out:
# Top 2 most frequent values for 'fundamentAjusteDireto':
# fundamentAjusteDireto
# ausência de recursos próprios    92023
# outros                            3710
# Name: count, dtype: int64

# %% [markdown]
# Informação geral

# %%
df_2021.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 187356 entries, 0 to 187355
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                187356 non-null  int64
#  1   nAnuncio                  21563 non-null   str
#  2   TipoAnuncio               21563 non-null   str
#  3   idINCM                    21563 non-null   float64
#  4   tipoContrato              187355 non-null  str
#  5   idprocedimento            187356 non-null  int64
#  6   tipoprocedimento          187356 non-null  str
#  7   objectoContrato           187356 non-null  object
#  8   descContrato              187356 non-null  object
#  9   adjudicante               187356 non-null  str
#  10  adjudicatarios            187037 non-null  str
#  11  dataPublicacao            187356 non-null  datetime64[us]
#  12  dataCelebracaoContrato    177419 non-null  datetime64[us]
# ...
