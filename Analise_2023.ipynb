# %% [markdown]
# # Projeto Final Aplicado a Ciência de Dados
# ## Deteção de Outliers em Contratos Públicos e Previsão do Montante de Adjudição
#
# ## Grupo 08
# ## Membros:
# ###          - Afonso Alexandre nº 123425;
# ###          - André  Freitas nº 123409;
# ###          - Gonçalo Vilhena nº 123384;
# ###          - Rodolfo Nardy nº 123419

# %% [markdown]
# #### **Reading and checking data**

# %%
import pandas as pd

# %%
#Diretório onde os arquivos de dados do trabalho estão armazenados
data_dir = "./dados/"
df_2023 = pd.read_excel(data_dir + "contratos2023.xlsx")

# %% [markdown]
# ## Análise
#
#
# ### Funções auxiliares
#
# #### Função para os top X valores mais frequentes

# %%
def print_top_n(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate the top 'n' most frequent values
    top_n_values = df[column_name].value_counts().head(top_n)

    # Print the top 'n' values
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para os top X valores mais frequentes numa lista

# %%
def print_top_n_list(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Explode the lists into separate rows
    exploded = df[column_name].explode()

    # Calculate the top 'n' most frequent individual values
    top_n_values = exploded.value_counts().head(top_n)

    # Print the results
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para mostras os X menores valores menos frequentes

# %%
def print_bottom_n(df, column_name, bottom_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts and get the bottom 'n' values
    bottom_n_values = df[column_name].value_counts().sort_values(ascending=True).head(bottom_n)

    # Print the bottom 'n' values
    print(f"Bottom {bottom_n} least frequent values for '{column_name}':")

    print(bottom_n_values)

# %% [markdown]
#  #### Função para mostrar  X menores valores menos frequentes numa lista

# %% [markdown]
# #### Function to count null and empty values

# %%
def count_null_and_empty(df, column_name):
    total = len(df)

    # Count NaN (null) values
    null_count = df[column_name].isna().sum()
    null_pct = (null_count / total) * 100

    # Count empty string values (after stripping whitespace)
    empty_count = (df[column_name].astype(str).str.strip() == '').sum()
    empty_pct = (empty_count / total) * 100

    # Print results
    print(f"Null (NaN) values: {null_count} ({null_pct:.2f}%)")
    print(f"Empty string values: {empty_count} ({empty_pct:.2f}%)")

# %% [markdown]
# #### Informações gerais do ficheiro

# %%
df_2023.info()
df_2023.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 193234 entries, 0 to 193233
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                193234 non-null  int64
#  1   nAnuncio                  31023 non-null   str
#  2   TipoAnuncio               31023 non-null   str
#  3   idINCM                    31023 non-null   float64
#  4   tipoContrato              193233 non-null  str
#  5   idprocedimento            193234 non-null  int64
#  6   tipoprocedimento          193234 non-null  str
#  7   objectoContrato           193234 non-null  object
#  8   descContrato              193234 non-null  object
#  9   adjudicante               193226 non-null  str
#  10  adjudicatarios            192747 non-null  str
#  11  dataPublicacao            193234 non-null  datetime64[us]
#  12  dataCelebracaoContrato    192492 non-null  datetime64[us]
# ...

# %% [markdown]
# #### idcontrato (int64)

# %%
count_null_and_empty(df_2023, 'idcontrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
#não há repetidos
print_top_n(df_2023,"idcontrato",10)
#df_2019[df_2019["idcontrato"] == 10458767 ]
# Out:
# Top 10 most frequent values for 'idcontrato':
# idcontrato
# 9781197    2
# 9798830    2
# 9805961    2
# 9800134    2
# 9806273    2
# 9802370    2
# 9811185    2
# 9811451    2
# 9810207    2
# 9802346    2
# Name: count, dtype: int64

# %% [markdown]
# #### tipoContrato (object)

# %%
count_null_and_empty(df_2023, 'tipoContrato')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n_list(df_2023,"tipoContrato",10)
set(df_2023['tipoContrato'])
# Out:
# Top 10 most frequent values for 'tipoContrato':
# tipoContrato
# Aquisição de bens móveis                                101081
# Aquisição de serviços                                    75310
# Empreitadas de obras públicas                            12583
# Locação de bens móveis                                    2208
# Aquisição de bens móveis\nAquisição de serviços           1407
# Aquisição de serviços\nLocação de bens móveis              199
# Concessão de serviços públicos                             136
# Concessão de obras públicas                                 78
# Aquisição de bens móveis\nLocação de bens móveis            61
# Aquisição de serviços\nEmpreitadas de obras públicas        35
# Name: count, dtype: int64
# {'Aquisição de bens móveis',
#  'Aquisição de bens móveis\nAquisição de serviços',
#  'Aquisição de bens móveis\nAquisição de serviços\nConcessão de obras públicas',
#  'Aquisição de bens móveis\nAquisição de serviços\nEmpreitadas de obras públicas',
# ...

# %% [markdown]
# #### idProcedimento (int64)

# %%
count_null_and_empty(df_2023, 'idprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,"idprocedimento",10)
# Out:
# Top 10 most frequent values for 'idprocedimento':
# idprocedimento
# 6818690    264
# 6376374    228
# 6423944    213
# 6449699    210
# 6290223    205
# 6305673    167
# 6803556    163
# 6195445    157
# 6513994    155
# 6302453    154
# Name: count, dtype: int64

# %% [markdown]
# #### tipoprocedimento

# %%
count_null_and_empty(df_2023, 'tipoprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,"tipoprocedimento",15)  #(nem ha 10)
# Out:
# Top 15 most frequent values for 'tipoprocedimento':
# tipoprocedimento
# Ajuste Direto Regime Geral                                                        89232
# Consulta Prévia                                                                   41371
# Concurso público                                                                  30730
# Ao abrigo de acordo-quadro (art.º 259.º)                                          23292
# Ao abrigo de acordo-quadro (art.º 258.º)                                           5688
# Contratação excluída II                                                            1074
# Ajuste direto simplificado                                                          489
# Consulta Prévia Simplificada                                                        480
# Concurso limitado por prévia qualificação                                           315
# Ajuste direto simplificado ao abrigo da Lei n.º 30/2021, de 21.05                   253
# ...

# %% [markdown]
# #### objectoContrato

# %%
count_null_and_empty(df_2023, 'objectoContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,"objectoContrato",20)
# Out:
# Top 20 most frequent values for 'objectoContrato':
# objectoContrato
# MEDICAMENTOS                                                                                                                                                                                                1425
# Convite ao abrigo do(s) acordo(s)-quadro 2020/48, 2021/55, 2021/6, 2022/40 e 2022/55, para suprir necessidades na área da saúde                                                                              422
# Aquisição de serviço de viagens e alojamento – Plataforma SIAV                                                                                                                                               406
# Fornecimento de eletricidade em regime de mercado livre para Portugal Continental                                                                                                                            325
# ...

# %% [markdown]
# #### descContrato (object)

# %%
count_null_and_empty(df_2023, 'descContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,"descContrato",20)
# Out:
# Top 20 most frequent values for 'descContrato':
# descContrato
# MEDICAMENTOS                                                                                                                                           1421
# Aquisição de serviço de viagens e alojamento – Plataforma SIAV                                                                                          408
# Procedimento agregado ao abrigo do lote 6 do acordo quadro para o fornecimento de eletricidade em regime de mercado livre para Portugal Continental     325
# REAGENTES                                                                                                                                               256
# 249/2022                                                                                                                                                212
# ...

# %% [markdown]
# adjudicante (object)

# %%
count_null_and_empty(df_2023, 'adjudicante')
# Out:
# Null (NaN) values: 8 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,"adjudicante",20)
# Out:
# Top 20 most frequent values for 'adjudicante':
# adjudicante
# 509822940 - Centro Hospitalar Tondela-Viseu, E. P. E.                                4638
# 506362299 - Instituto Português de Oncologia do Porto Francisco Gentil, E. P. E.     2755
# 508094461 - Unidade Local de Saúde do Norte Alentejano, E. P. E.                     2704
# 508481287 - Centro Hospitalar Universitário de Lisboa Norte, E. P. E.                2617
# 600010180 - Estado-Maior-General das Forças Armadas (EMGFA)                          2517
# 510745997 - Centro Hospitalar Universitário do Algarve, E. P. E.                     2453
# 510103448 - Centro Hospitalar e Universitário de Coimbra, E. P. E.                   2323
# 508786193 - Unidade Local de Saúde do Alto Minho, E. P. E.                           2303
# 506361470 - Hospital Garcia de Orta, E. P. E.                                        2221
# 513606084 - Águas do Norte, S. A.                                                    2166
# ...

# %% [markdown]
# adjudicatarios (object)

# %%
count_null_and_empty(df_2023, 'adjudicatarios')
# Out:
# Null (NaN) values: 487 (0.25%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['adjudicatarios'].head(20))
# Out:
# 0                                                   NaN
# 1     509683681 - Probroker, Mediação de Seguros Uni...
# 2                           505042037 - Sumol+Compal,SA
# 3      503239470 - Corbroker, Corretores de Seguros SA
# 4                               - - José Costa Teixeira
# 5     503290688 - Qualitalhos - Indústria e Comércio...
# 6          501145923 - Canas Engenharia e Construção SA
# 7                             508305691 - MICATERM, Lda
# 8              510792804 - WEEKENDAPARTY UNIPESSOAL,LDA
# 9                      507477740 - Canon Portugal, S.A.
# 10                       500632758 - Aquário Mundo, Lda
# 11        500233810 - ROCHE  FARMACÊUTICA QUÍMICA, lDA.
# 12                         - - Matilde Rosa Lopes Neves
# 13    505235781 - Hpz, Com. Equip de telecomunicaçõe...
# 14    504970003 - POLARGEL, COMÉRCIO DE PRODUTOS ALI...
# 15                503015385 - MX3 - ARTES GRÁFICAS, LDA
# 16    502983485 - Kodis Comércio de Bebidas e Produt...
# ...

# %% [markdown]
# dataPublicacao (object)

# %%
count_null_and_empty(df_2023, 'dataPublicacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['dataPublicacao'].head(10))
# Out:
# 0   2022-12-26
# 1   2023-01-02
# 2   2023-01-02
# 3   2023-01-02
# 4   2022-09-20
# 5   2023-01-02
# 6   2023-01-02
# 7   2023-01-02
# 8   2023-01-02
# 9   2022-12-19
# Name: dataPublicacao, dtype: datetime64[us]

# %% [markdown]
# dataCelebracaoContrato (object)

# %%
count_null_and_empty(df_2023, 'dataCelebracaoContrato')
# Out:
# Null (NaN) values: 742 (0.38%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['dataCelebracaoContrato'].head(10))
# Out:
# 193224   2023-01-24
# 193225   2023-07-14
# 193226   2023-02-15
# 193227   2023-04-12
# 193228   2023-05-28
# 193229   2023-05-06
# 193230   2023-04-21
# 193231   2023-05-04
# 193232   2023-03-20
# 193233   2023-11-20
# Name: dataCelebracaoContrato, dtype: datetime64[us]

# %% [markdown]
# precoContratual (float64)

# %%
count_null_and_empty(df_2023, 'precoContratual')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['precoContratual'].head(10))
min(df_2023['precoContratual'])
# Out:
# 0       3245.56
# 1      84659.05
# 2       9120.00
# 3       7704.00
# 4    3519310.80
# 5      19999.99
# 6       6612.70
# 7      20940.00
# 8       5758.08
# 9      34991.40
# Name: precoContratual, dtype: float64
# -10566000.0

# %% [markdown]
# cpv (object)

# %%
count_null_and_empty(df_2023, 'CPV')
# Out:
# Null (NaN) values: 2 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['CPV'].head(10))
# Out:
# 0                        22110000-4 - Livros impressos
# 1                 15811000-6 - Produtos de panificação
# 2             90611000-3 - Serviços de limpeza de ruas
# 3    90600000-3 - Serviços de saneamento e limpeza ...
# 4                 45112700-2 - Trabalhos de paisagismo
# 5    72000000-5 - Serviços de TI: consultoria, dese...
# 6    90721700-4 - Serviços de protecção de espécies...
# 7           71317200-5 - Serviços de saúde e segurança
# 8    15800000-6 - Produtos alimentares diversos\n15...
# 9      30200000-1 - Equipamento e material informático
# Name: CPV, dtype: str

# %% [markdown]
# prazoExecucao (int64)

# %%
count_null_and_empty(df_2023, 'prazoExecucao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023, 'prazoExecucao', 10)
# Out:
# Top 10 most frequent values for 'prazoExecucao':
# prazoExecucao
# 366     19000
# 30      15871
# 365     14569
# 1096     7606
# 60       7527
# 20       7394
# 1        6228
# 90       5404
# 5        5132
# 731      4202
# Name: count, dtype: int64

# %%
print_bottom_n(df_2023,'prazoExecucao',10)
# Out:
# Bottom 10 least frequent values for 'prazoExecucao':
# prazoExecucao
# 771       1
# 598       1
# 786       1
# 880       1
# 800       1
# 955       1
# 657       1
# 947       1
# 366610    1
# 514       1
# Name: count, dtype: int64

# %%
max_prazo_valor = df_2023['prazoExecucao'].max()
print("Maximum 'prazoExecucao (dias)':", max_prazo_valor)
print("Maximum 'prazoExecucao (anos)':", max_prazo_valor/365)
#impossível
# Out:
# Maximum 'prazoExecucao (dias)': 739251
# Maximum 'prazoExecucao (anos)': 2025.345205479452

# %% [markdown]
# localExecucao (object)

# %%
count_null_and_empty(df_2023, 'LocalExecucao')
# Out:
# Null (NaN) values: 542 (0.28%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['LocalExecucao'].head(10))
# Out:
# 0         Portugal, Porto, Porto
# 1         Portugal, Braga, Braga
# 2    Portugal, Porto, Felgueiras
# 3    Portugal, Porto, Felgueiras
# 4      Portugal, Braga, Barcelos
# 5       Portugal, Guarda, Guarda
# 6       Portugal, Lisboa, Sintra
# 7      Portugal, Braga, Barcelos
# 8     Portugal, Leiria, Alcobaça
# 9         Portugal, Porto, Porto
# Name: LocalExecucao, dtype: str

# %% [markdown]
# fundamentacao (object)

# %%
count_null_and_empty(df_2023, 'fundamentacao')
# Out:
# Null (NaN) values: 748 (0.39%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023, 'fundamentacao', 10)
# Out:
# Top 10 most frequent values for 'fundamentacao':
# fundamentacao
# Artigo 20.º, n.º 1, alínea d) do Código dos Contratos Públicos                    41892
# Artigo 20.º, n.º 1, alínea c) do Código dos Contratos Públicos                    34912
# Artigo 259.º do Código dos Contratos Públicos                                     22690
# Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos                    16236
# Artigo 24.º, n.º 1, alínea c) do Código dos Contratos Públicos                    13283
# Artigo 24.º, n.º 1, alínea e), subalínea ii) do Código dos Contratos Públicos     11731
# Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos                     8386
# Artigo 24.º, n.º 1, alínea e), subalínea iii) do Código dos Contratos Públicos     7041
# Artigo 19.º, alínea c) do Código dos Contratos Públicos                            4062
# Artigo 258.º do Código dos Contratos Públicos                                      3908
# Name: count, dtype: int64

# %% [markdown]
# ProcedimentoCentralizado (object)

# %%
count_null_and_empty(df_2023, 'ProcedimentoCentralizado')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023, 'ProcedimentoCentralizado', 10)
# Out:
# Top 10 most frequent values for 'ProcedimentoCentralizado':
# ProcedimentoCentralizado
# Não    182912
# Sim     10322
# Name: count, dtype: int64

# %% [markdown]
# DescrAcordoQuadro (object)

# %%
count_null_and_empty(df_2023, 'DescrAcordoQuadro')
# Out:
# Null (NaN) values: 165108 (85.44%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,"DescrAcordoQuadro",10)
# Out:
# Top 10 most frequent values for 'DescrAcordoQuadro':
# DescrAcordoQuadro
# CP 2021/6 - Medicamentos do foro oncológico e imunomoduladores                                             4261
# CP 2022/55 - Acordo quadro para fornecimento de medicamentos diversos                                      1528
# Acordo Quadro de Viagens e Alojamento                                                                      1184
# 173/2022 - Medicamentos diversos                                                                            948
# CP 2021/47 - Medicamentos do aparelho locomotor, usados no tratamento das doenças endócrinas e hormonas     882
# CP 2022/19 - Medicamentos antipsicóticos, anestésicos e relaxantes musculares                               815
# CP 2021/55 - Medicamentos diversos                                                                          752
# CP 2021/61 - Medicamentos diversos                                                                          706
# ...

# %% [markdown]
# precoBaseProcedimento (float64)

# %%
count_null_and_empty(df_2023, 'precoBaseProcedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,"precoBaseProcedimento",10)
# Out:
# Top 10 most frequent values for 'precoBaseProcedimento':
# precoBaseProcedimento
# 0.0        4891
# 15000.0    1189
# 10000.0    1092
# 12000.0     972
# 20000.0     889
# 18000.0     863
# 6000.0      774
# 9000.0      755
# 30000.0     718
# 19500.0     648
# Name: count, dtype: int64

# %% [markdown]
# dataDecisaoAdjudicacao (object)

# %%
count_null_and_empty(df_2023, 'dataDecisaoAdjudicacao')
# Out:
# Null (NaN) values: 742 (0.38%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,"dataDecisaoAdjudicacao",20)
# Out:
# Top 20 most frequent values for 'dataDecisaoAdjudicacao':
# dataDecisaoAdjudicacao
# 2023-02-16    1293
# 2023-03-23    1281
# 2023-01-26    1254
# 2023-02-23    1251
# 2023-06-07    1127
# 2023-06-01    1116
# 2023-03-09    1113
# 2023-05-25    1100
# 2023-03-29    1077
# 2023-11-23    1076
# 2023-06-15    1056
# 2023-02-15    1045
# 2023-01-12    1039
# 2023-04-26    1023
# 2023-05-18    1023
# 2023-03-16    1016
# 2023-11-27    1012
# 2023-03-02     994
# 2023-01-25     988
# 2023-02-27     979
# Name: count, dtype: int64

# %% [markdown]
# dataFechoContrato (object)

# %%
count_null_and_empty(df_2023, 'dataFechoContrato')
# Out:
# Null (NaN) values: 134424 (69.57%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,"dataFechoContrato",10)
# Out:
# Top 10 most frequent values for 'dataFechoContrato':
# dataFechoContrato
# 2023-12-31    5841
# 2023-12-29    2452
# 2023-12-27     855
# 2023-12-28     768
# 2023-12-22     764
# 2024-12-31     734
# 2023-12-20     678
# 2023-12-21     630
# 2023-12-19     460
# 2023-12-14     367
# Name: count, dtype: int64

# %% [markdown]
# PrecoTotalEfetivo

# %%
count_null_and_empty(df_2023, 'PrecoTotalEfetivo')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['PrecoTotalEfetivo'].head(10))
# Out:
# 0       3245.56
# 1      84659.05
# 2       7296.00
# 3       7562.00
# 4    3429226.77
# 5          0.00
# 6          0.00
# 7          0.00
# 8       4953.04
# 9          0.00
# Name: PrecoTotalEfetivo, dtype: float64

# %%
print_top_n(df_2023,"PrecoTotalEfetivo",10)
# Out:
# Top 10 most frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 0.0        135215
# 15000.0       237
# 6000.0        225
# 12000.0       223
# 10000.0       210
# 9000.0        183
# 18000.0       176
# 7500.0        176
# 19500.0       154
# 8000.0        143
# Name: count, dtype: int64

# %%
print_bottom_n(df_2023,"PrecoTotalEfetivo",10)
# Out:
# Bottom 10 least frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 27105.88     1
# 197104.65    1
# 10039.60     1
# 15038.11     1
# 3889.48      1
# 1047.05      1
# 1418.10      1
# 81.06        1
# 4491.00      1
# 15209.60     1
# Name: count, dtype: int64

# %% [markdown]
# regime (object)

# %%
count_null_and_empty(df_2023, 'regime')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['regime'].head(10))
# Out:
# 0      Código dos Contratos Públicos ( DL 111-B/2017 )
# 1    Código dos Contratos Públicos (DL111-B/2017) e...
# 2      Código dos Contratos Públicos ( DL 111-B/2017 )
# 3      Código dos Contratos Públicos ( DL 111-B/2017 )
# 4    Código dos Contratos Públicos (DL111-B/2017) e...
# 5      Código dos Contratos Públicos ( DL 111-B/2017 )
# 6      Código dos Contratos Públicos ( DL 111-B/2017 )
# 7    Código dos Contratos Públicos (DL111-B/2017) e...
# 8      Código dos Contratos Públicos ( DL 111-B/2017 )
# 9      Código dos Contratos Públicos ( DL 111-B/2017 )
# Name: regime, dtype: str

# %% [markdown]
# tipoFimContrato (object)

# %%
count_null_and_empty(df_2023, 'tipoFimContrato')
# Out:
# Null (NaN) values: 135173 (69.95%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023, 'tipoFimContrato', 10)
# Out:
# Top 10 most frequent values for 'tipoFimContrato':
# tipoFimContrato
# O cumprimento, a impossibilidade definitiva e todas as restantes causas de extinção das obrigações reconhecidas pelo direito civil    56644
# Resolução do Contrato                                                                                                                   786
# Revogação do Contrato                                                                                                                   566
# Anulado ou Declarado Nulo                                                                                                                40
# Contrato Anulado, Declarado Nulo ou Objecto de Recusa de Visto                                                                           20
# Objeto de recusa de visto do Tribunal de Contas                                                                                           5
# Name: count, dtype: int64

# %% [markdown]
# CritMateriais (object)

# %%
count_null_and_empty(df_2023, 'CritMateriais')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['CritMateriais'].head(10))
# Out:
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# 5    Não
# 6    Não
# 7    Não
# 8    Sim
# 9    Não
# Name: CritMateriais, dtype: str

# %%
print_top_n(df_2023,"CritMateriais",2)
# Out:
# Top 2 most frequent values for 'CritMateriais':
# CritMateriais
# Não    160540
# Sim     32694
# Name: count, dtype: int64

# %% [markdown]
# concorrentes (object)

# %%
count_null_and_empty(df_2023, 'concorrentes')
# Out:
# Null (NaN) values: 80384 (41.60%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['concorrentes'].tail(10))
# Out:
# 193224    500006148-ABBOTT LABORATORIOS, LDA.           ...
# 193225    500347506-Eurest (Portugal) - Sociedade Europe...
# 193226    502722444-Toco &amp; César\n503852864-Carrisbu...
# 193227              508944767-ICNAS Pharma Unipessoal, Lda.
# 193228               515697613-NEURONCIRCUIT UNIPESSOAL LDA
# 193229              508944767-ICNAS Pharma Unipessoal, Lda.
# 193230    510433669-Waters Technologies LC-MS Portugal, ...
# 193231                         --PRECISION NANOSYSTEMS INC.
# 193232              502849444-TBA TELEMATICA E BUROTICA LDA
# 193233    503531588-LUSOPALEX - SOCIEDADE DISTRIBUIDORA ...
# Name: concorrentes, dtype: str

# %% [markdown]
# linkPecasProc (object)

# %%
count_null_and_empty(df_2023, 'linkPecasProc')
# Out:
# Null (NaN) values: 94390 (48.85%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Observacoes (object)

# %%
count_null_and_empty(df_2023, 'Observacoes')
# Out:
# Null (NaN) values: 186264 (96.39%)
# Empty string values: 88 (0.05%)

# %% [markdown]
# ContratEcologico (object)

# %%
count_null_and_empty(df_2023, 'ContratEcologico')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Ano (int64)

# %%
count_null_and_empty(df_2023, 'Ano')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2023['Ano'].head(10))
# Out:
# 0    2023
# 1    2023
# 2    2023
# 3    2023
# 4    2023
# 5    2023
# 6    2023
# 7    2023
# 8    2023
# 9    2023
# Name: Ano, dtype: int64

# %% [markdown]
# fundamentAjusteDireto

# %%
count_null_and_empty(df_2023, 'fundamentAjusteDireto')
# Out:
# Null (NaN) values: 145941 (75.53%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2023,'fundamentAjusteDireto',2)
# Out:
# Top 2 most frequent values for 'fundamentAjusteDireto':
# fundamentAjusteDireto
# ausência de recursos próprios    45841
# outros                            1452
# Name: count, dtype: int64
