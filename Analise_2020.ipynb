# %% [markdown]
# # Projeto Final Aplicado a Ciência de Dados
# ## Deteção de Outliers em Contratos Públicos e Previsão do Montante de Adjudição
#
# ## Grupo 08
# ## Membros:
# ###          - Afonso Alexandre nº 123425;
# ###          - André  Freitas nº 123409;
# ###          - Gonçalo Vilhena nº 123384;
# ###          - Rodolfo Nardy nº 123419

# %% [markdown]
# #### **Reading and checking data**

# %%
import pandas as pd

# %%
#Diretório onde os arquivos de dados do trabalho estão armazenados
data_dir = "./dados/"
df_2020 = pd.read_excel(data_dir + "contratos2020.xlsx")

# %% [markdown]
# ## Análise
#
#
# ### Funções auxiliares
#
# #### Função para os top X valores mais frequentes

# %%
def print_top_n(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate the top 'n' most frequent values
    top_n_values = df[column_name].value_counts().head(top_n)

    # Print the top 'n' values
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para os top X valores mais frequentes numa lista

# %%
def print_top_n_list(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Explode the lists into separate rows
    exploded = df[column_name].explode()

    # Calculate the top 'n' most frequent individual values
    top_n_values = exploded.value_counts().head(top_n)

    # Print the results
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para mostras os X menores valores menos frequentes

# %%
def print_bottom_n(df, column_name, bottom_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts and get the bottom 'n' values
    bottom_n_values = df[column_name].value_counts().sort_values(ascending=True).head(bottom_n)

    # Print the bottom 'n' values
    print(f"Bottom {bottom_n} least frequent values for '{column_name}':")

    print(bottom_n_values)

# %% [markdown]
#  #### Função para mostrar  X menores valores menos frequentes numa lista

# %% [markdown]
# #### Function to count null and empty values

# %%
def count_null_and_empty(df, column_name):
    total = len(df)

    # Count NaN (null) values
    null_count = df[column_name].isna().sum()
    null_pct = (null_count / total) * 100

    # Count empty string values (after stripping whitespace)
    empty_count = (df[column_name].astype(str).str.strip() == '').sum()
    empty_pct = (empty_count / total) * 100

    # Print results
    print(f"Null (NaN) values: {null_count} ({null_pct:.2f}%)")
    print(f"Empty string values: {empty_count} ({empty_pct:.2f}%)")

# %% [markdown]
# #### Informações gerais do ficheiro

# %%
df_2020.info()
df_2020.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 176488 entries, 0 to 176487
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                176488 non-null  int64
#  1   nAnuncio                  17644 non-null   str
#  2   TipoAnuncio               17644 non-null   str
#  3   idINCM                    17644 non-null   float64
#  4   tipoContrato              176487 non-null  str
#  5   idprocedimento            176488 non-null  int64
#  6   tipoprocedimento          176488 non-null  str
#  7   objectoContrato           176488 non-null  object
#  8   descContrato              176488 non-null  object
#  9   adjudicante               176488 non-null  str
#  10  adjudicatarios            176195 non-null  str
#  11  dataPublicacao            176488 non-null  datetime64[us]
#  12  dataCelebracaoContrato    149769 non-null  datetime64[us]
# ...

# %% [markdown]
# #### idcontrato (int64)

# %%
count_null_and_empty(df_2020, 'idcontrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"idcontrato",10)
# Out:
# Top 10 most frequent values for 'idcontrato':
# idcontrato
# 7327598     2
# 10408926    2
# 10427381    2
# 10429099    2
# 10449055    2
# 10459880    2
# 10462553    2
# 10462874    2
# 10585982    2
# 6915538     2
# Name: count, dtype: int64

# %%
#df_2020[df_2020["idcontrato"]==7327598]
df_2020[df_2020["idcontrato"]==6915538]
#só muda na variável "ContratEcologico"
# Out:
#         idcontrato nAnuncio TipoAnuncio  idINCM           tipoContrato  \
# 106375     6915538      NaN         NaN     NaN  Aquisição de serviços
# 111354     6915538      NaN         NaN     NaN  Aquisição de serviços
#
#         idprocedimento            tipoprocedimento  \
# 106375         4688145  Ajuste Direto Regime Geral
# 111354         4688145  Ajuste Direto Regime Geral
#
#                                           objectoContrato  \
# 106375  Aquisição de Serviços de Desinfeção para as Vi...
# 111354  Aquisição de Serviços de Desinfeção para as Vi...
#
#                                              descContrato  \
# 106375  Aquisição de Serviços de Desinfeção para as Vi...
# 111354  Aquisição de Serviços de Desinfeção para as Vi...
#
#                                        adjudicante  ...  \
# 106375  514387130 - Águas do Tejo Atlântico, S. A.  ...
# 111354  514387130 - Águas do Tejo Atlântico, S. A.  ...
#
#                                                  regime  \
# ...

# %% [markdown]
# #### tipoContrato (object)

# %%
count_null_and_empty(df_2020, 'tipoContrato')
# Out:
# Null (NaN) values: 1 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n_list(df_2020,"tipoContrato",10)
df_2020['tipoContrato'].unique()
# Out:
# Top 10 most frequent values for 'tipoContrato':
# tipoContrato
# Aquisição de bens móveis                            101809
# Aquisição de serviços                                58357
# Empreitadas de obras públicas                        12731
# Locação de bens móveis                                1552
# Aquisição de bens móveis\nAquisição de serviços       1374
# Aquisição de serviços\nLocação de bens móveis          147
# Concessão de serviços públicos                         129
# Concessão de obras públicas                             57
# Aquisição de bens móveis\nLocação de bens móveis        53
# Aquisição de serviços\nSociedade                        52
# Name: count, dtype: int64
# <StringArray>
# [                                                                                       'Aquisição de serviços',
#                                                                                 'Empreitadas de obras públicas',
# ...

# %% [markdown]
# #### idProcedimento (int64)

# %%
count_null_and_empty(df_2020, 'idprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"idprocedimento",10)
# Out:
# Top 10 most frequent values for 'idprocedimento':
# idprocedimento
# 5018771    152
# 5047290    142
# 4293095     73
# 4354955     60
# 4262618     59
# 4603150     58
# 5043543     58
# 4835791     53
# 4293785     50
# 4732262     50
# Name: count, dtype: int64

# %% [markdown]
# #### tipoprocedimento

# %%
count_null_and_empty(df_2020, 'tipoprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"tipoprocedimento",10)  #(nem ha 10)
# Out:
# Top 10 most frequent values for 'tipoprocedimento':
# tipoprocedimento
# Ajuste Direto Regime Geral                                           78335
# Consulta Prévia                                                      35060
# Ajuste direto simplificado                                           26258
# Concurso público                                                     17406
# Ao abrigo de acordo-quadro (art.º 259.º)                             15152
# Ao abrigo de acordo-quadro (art.º 258.º)                              3514
# Ajuste direto simplificado ao abrigo da Lei n.º 30/2021, de 21.05      461
# Concurso limitado por prévia qualificação                              289
# Contratação excluída II                                                  8
# Setores especiais – isenção parte II                                     3
# Name: count, dtype: int64

# %% [markdown]
# #### objectoContrato

# %%
count_null_and_empty(df_2020, 'objectoContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"objectoContrato",20)
# Out:
# Top 20 most frequent values for 'objectoContrato':
# objectoContrato
# MEDICAMENTOS                                                                                                                                                                                                                      2067
# Aquisição de material diverso                                                                                                                                                                                                      247
# MEDICAMENTOS                                                                                                                                                                                                                       214
# ...

# %% [markdown]
# #### descContrato (object)

# %%
count_null_and_empty(df_2020, 'descContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"descContrato",20)
# Out:
# Top 20 most frequent values for 'descContrato':
# descContrato
# MEDICAMENTOS                                                                                                                                                                                                                      1962
# MEDICAMENTOS                                                                                                                                                                                                                       303
# Contrato de prestação de serviços                                                                                                                                                                                                  217
# Aquisição de material diverso                                                                                                                                                                                                      197
# ...

# %% [markdown]
# adjudicante (object)

# %%
count_null_and_empty(df_2020, 'adjudicante')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"adjudicante",20)
# Out:
# Top 20 most frequent values for 'adjudicante':
# adjudicante
# 508481287 - Centro Hospitalar Universitário de Lisboa Norte, E. P. E.               4841
# 600012662 - Ministério da Defesa Nacional - Marinha                                 4685
# 508094461 - Unidade Local de Saúde do Norte Alentejano, E. P. E.                    3598
# 506362299 - Instituto Português de Oncologia do Porto Francisco Gentil, E. P. E.    3161
# 508142156 - Centro Hospitalar Vila Nova de Gaia - Espinho, E. P. E.                 2188
# 510103448 - Centro Hospitalar e Universitário de Coimbra, E. P. E.                  2039
# 507618319 - Centro Hospitalar de Lisboa Ocidental, E. P. E.                         1777
# 509822940 - Centro Hospitalar Tondela-Viseu, E. P. E.                               1639
# 506361470 - Hospital Garcia de Orta, E. P. E.                                       1576
# 509822932 - Centro Hospitalar de Leiria, E. P. E.                                   1568
# ...

# %% [markdown]
# adjudicatarios (object)

# %%
count_null_and_empty(df_2020, 'adjudicatarios')
# Out:
# Null (NaN) values: 293 (0.17%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['adjudicatarios'].head(20))
# Out:
# 0     506807266 - VIGIEXPERT, PREVENÇÃO E VIGILANCIA...
# 1     501351167 - Rentokil Initial Portugal - Serviç...
# 2     509094686 - Vierominho II - Construção e Reabi...
# 3                           510694381 - BEFEBAL II, LDA
# 4     500963363 - TPF – CONSULTORES DE ENGENHARIA E ...
# 5                     500684324 - MEDICINÁLIA CORMEDICA
# 6                   503552461 - SMITH &amp; NEPHEW, LDA
# 7            500399670 - QUILABAN QUIMICA LAB ANALITICA
# 8                          500042772 - Bastos Viegas SA
# 9                     501506543 - B. BRAUN MEDICAL, LDA
# 10           504988964 - BOSTON SCIENTIFIC PORTUGAL LDA
# 11                         500042772 - Bastos Viegas SA
# 12                      503505196 - INDAS PORTUGAL. LDA
# 13                    511101066 - MOLNLYCKE HEALTH CARE
# 14                                   503282480 - VISMEC
# 15          500730741 - DIMOR LUSITANA - COMÉRCIO, Lda.
# 16                         500042772 - Bastos Viegas SA
# ...

# %% [markdown]
# dataPublicacao (object)

# %%
count_null_and_empty(df_2020, 'dataPublicacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['dataPublicacao'].head(10))
# Out:
# 0   2019-09-27
# 1   2019-11-19
# 2   2019-12-16
# 3   2019-12-16
# 4   2019-12-26
# 5   2020-01-02
# 6   2020-01-02
# 7   2020-01-02
# 8   2020-01-02
# 9   2020-01-02
# Name: dataPublicacao, dtype: datetime64[us]

# %% [markdown]
# dataCelebracaoContrato (object)

# %%
count_null_and_empty(df_2020, 'dataCelebracaoContrato')
# Out:
# Null (NaN) values: 26719 (15.14%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['dataCelebracaoContrato'].head(10))
# Out:
# 0   2020-11-11
# 1   2020-06-01
# 2   2020-07-29
# 3   2020-07-23
# 4   2020-01-14
# 5   2020-01-02
# 6   2020-01-02
# 7   2020-01-02
# 8   2020-01-02
# 9   2020-01-02
# Name: dataCelebracaoContrato, dtype: datetime64[us]

# %% [markdown]
# precoContratual (float64)

# %%
count_null_and_empty(df_2020, 'precoContratual')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['precoContratual'].head(10))
# Out:
# 0     500000.00
# 1      14306.40
# 2    2575600.00
# 3    3738128.01
# 4      65000.00
# 5     104980.00
# 6      36870.00
# 7       2375.00
# 8       1436.40
# 9      35100.00
# Name: precoContratual, dtype: float64

# %%
min(df_2020['precoContratual'])
# Out:
# -173664.0

# %% [markdown]
# cpv (object)

# %%
count_null_and_empty(df_2020, 'CPV')
# Out:
# Null (NaN) values: 2 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['CPV'].head(10))
# Out:
# 0                  79714000-2 - Serviços de vigilância
# 1    90500000-2 - Serviços relativos a resíduos e l...
# 2                       45454100-5 - Obras de restauro
# 3                       45454100-5 - Obras de restauro
# 4                   71335000-5 - Estudos de engenharia
# 5              33140000-3 - Material médico de consumo
# 6      33141100-1 - Pensos; clipes, suturas, ligaduras
# 7                               33141200-2 - Cateteres
# 8    33198200-6 - Saquetas e invólucros de papel pa...
# 9              33111730-7 - Material para angioplastia
# Name: CPV, dtype: str

# %% [markdown]
# prazoExecucao (int64)

# %%
count_null_and_empty(df_2020, 'prazoExecucao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020, 'prazoExecucao', 10)
# Out:
# Top 10 most frequent values for 'prazoExecucao':
# prazoExecucao
# 0       26819
# 365     24120
# 30      14913
# 20       8565
# 60       6737
# 90       5772
# 1095     5571
# 1        5227
# 15       4325
# 180      3913
# Name: count, dtype: int64

# %%
print_bottom_n(df_2020,'prazoExecucao',10)
# Out:
# Bottom 10 least frequent values for 'prazoExecucao':
# prazoExecucao
# 1111    1
# 9785    1
# 6008    1
# 1545    1
# 778     1
# 793     1
# 1922    1
# 9000    1
# 409     1
# 1216    1
# Name: count, dtype: int64

# %%
max_prazo_valor = df_2020['prazoExecucao'].max()
print("Maximum 'prazoExecucao (dias)':", max_prazo_valor)
print("Maximum 'prazoExecucao (anos)':", max_prazo_valor/365)
#impossível
# Out:
# Maximum 'prazoExecucao (dias)': 30072020
# Maximum 'prazoExecucao (anos)': 82389.09589041096

# %% [markdown]
# localExecucao (object)

# %%
count_null_and_empty(df_2020, 'LocalExecucao')
# Out:
# Null (NaN) values: 26260 (14.88%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['LocalExecucao'].head(10))
# Out:
# 0    Portugal, Porto, Penafiel\nPortugal, Porto, Lo...
# 1                             Portugal, Lisboa, Lisboa
# 2                          Portugal, Porto, Matosinhos
# 3                          Portugal, Porto, Matosinhos
# 4                                             Portugal
# 5                             Portugal, Lisboa, Lisboa
# 6                                             Portugal
# 7                             Portugal, Lisboa, Lisboa
# 8                                             Portugal
# 9                             Portugal, Lisboa, Lisboa
# Name: LocalExecucao, dtype: str

# %% [markdown]
# fundamentacao (object)

# %%
count_null_and_empty(df_2020, 'fundamentacao')
# Out:
# Null (NaN) values: 26721 (15.14%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020, 'fundamentacao', 10)
# Out:
# Top 10 most frequent values for 'fundamentacao':
# fundamentacao
# Artigo 20.º, n.º 1, alínea d) do Código dos Contratos Públicos                    31611
# Artigo 20.º, n.º 1, alínea c) do Código dos Contratos Públicos                    27104
# Artigo 24.º, n.º 1, alínea c) do Código dos Contratos Públicos                    16119
# Artigo 259.º do Código dos Contratos Públicos                                     14886
# Artigo 24.º, n.º 1, alínea e), subalínea ii) do Código dos Contratos Públicos      8903
# Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos                     8101
# Artigo 19.º, alínea c) do Código dos Contratos Públicos                            5092
# Artigo 2º, n.º 1 do DL . nº 10-A/2020, de 13.03                                    4719
# Artigo 24.º, n.º 1, alínea e), subalínea iii) do Código dos Contratos Públicos     4523
# Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos                     4473
# Name: count, dtype: int64

# %% [markdown]
# ProcedimentoCentralizado (object)

# %%
count_null_and_empty(df_2020, 'ProcedimentoCentralizado')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020, 'ProcedimentoCentralizado', 10)
# Out:
# Top 10 most frequent values for 'ProcedimentoCentralizado':
# ProcedimentoCentralizado
# Não    170823
# Sim      5665
# Name: count, dtype: int64

# %% [markdown]
# DescrAcordoQuadro (object)

# %%
count_null_and_empty(df_2020, 'DescrAcordoQuadro')
# Out:
# Null (NaN) values: 158439 (89.77%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"DescrAcordoQuadro",10)
# Out:
# Top 10 most frequent values for 'DescrAcordoQuadro':
# DescrAcordoQuadro
# CP 2017/6 - Acordo Quadro para fornecimento de Medicamentos do Foro Oncológico e Imunomoduladores, às Instituições e Serviços do Serviço Nacional de Saúde                                                                                                         2277
# CP 2019/61 - Medicamentos diversos                                                                                                                                                                                                                                 1380
# CP 2018/64 - Medicamentos Diversos                                                                                                                                                                                                                                  777
# ...

# %% [markdown]
# precoBaseProcedimento (float64)

# %%
count_null_and_empty(df_2020, 'precoBaseProcedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"precoBaseProcedimento",10)
# Out:
# Top 10 most frequent values for 'precoBaseProcedimento':
# precoBaseProcedimento
# 0.0        32924
# 15000.0      953
# 10000.0      907
# 12000.0      805
# 20000.0      706
# 18000.0      688
# 9000.0       683
# 30000.0      624
# 6000.0       614
# 8000.0       527
# Name: count, dtype: int64

# %% [markdown]
# dataDecisaoAdjudicacao (object)

# %%
count_null_and_empty(df_2020, 'dataDecisaoAdjudicacao')
# Out:
# Null (NaN) values: 26698 (15.13%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"dataDecisaoAdjudicacao",20)
# Out:
# Top 20 most frequent values for 'dataDecisaoAdjudicacao':
# dataDecisaoAdjudicacao
# 2020-01-02    1003
# 2020-12-10     900
# 2020-12-17     894
# 2020-01-23     877
# 2020-12-03     860
# 2020-01-16     850
# 2020-03-12     849
# 2020-02-27     847
# 2020-02-06     844
# 2020-01-29     832
# 2020-10-15     819
# 2020-01-30     806
# 2020-10-29     785
# 2020-02-20     784
# 2020-11-19     780
# 2020-02-13     774
# 2020-01-22     768
# 2020-11-26     748
# 2020-02-05     747
# 2020-01-14     742
# Name: count, dtype: int64

# %% [markdown]
# dataFechoContrato (object)

# %%
count_null_and_empty(df_2020, 'dataFechoContrato')
# Out:
# Null (NaN) values: 97202 (55.08%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,"dataFechoContrato",10)
# Out:
# Top 10 most frequent values for 'dataFechoContrato':
# dataFechoContrato
# 2020-12-31    6245
# 2020-12-30    1267
# 2021-12-31     963
# 2020-12-29     766
# 2020-12-22     632
# 2020-12-28     621
# 2020-12-23     618
# 2020-09-30     488
# 2020-12-18     483
# 2020-04-30     448
# Name: count, dtype: int64

# %% [markdown]
# PrecoTotalEfetivo

# %%
count_null_and_empty(df_2020, 'PrecoTotalEfetivo')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['PrecoTotalEfetivo'].head(10))
# Out:
# 0     299700.01
# 1          0.00
# 2          0.00
# 3    4820306.43
# 4          0.00
# 5          0.00
# 6          0.00
# 7          0.00
# 8          0.00
# 9          0.00
# Name: PrecoTotalEfetivo, dtype: float64

# %%
print_top_n(df_2020,"PrecoTotalEfetivo",10)
# Out:
# Top 10 most frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 0.00        98044
# 12000.00      203
# 9000.00       197
# 6000.00       193
# 7500.00       192
# 15000.00      183
# 10000.00      178
# 18000.00      176
# 5573.54       168
# 20000.00      160
# Name: count, dtype: int64

# %%
print_bottom_n(df_2020,"PrecoTotalEfetivo",10)
# Out:
# Bottom 10 least frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 7625.11       1
# 36213.54      1
# 3852941.18    1
# 11606.40      1
# 921.50        1
# 26646.59      1
# 304.20        1
# 799.78        1
# 9215.95       1
# 476.75        1
# Name: count, dtype: int64

# %% [markdown]
# regime (object)

# %%
count_null_and_empty(df_2020, 'regime')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['regime'].head(10))
# Out:
# 0    Código dos Contratos Públicos ( DL 111-B/2017 )
# 1    Código dos Contratos Públicos ( DL 111-B/2017 )
# 2    Código dos Contratos Públicos ( DL 111-B/2017 )
# 3    Código dos Contratos Públicos ( DL 111-B/2017 )
# 4    Código dos Contratos Públicos ( DL 111-B/2017 )
# 5    Código dos Contratos Públicos ( DL 111-B/2017 )
# 6         Código dos Contratos Públicos (DL 18/2008)
# 7         Código dos Contratos Públicos (DL 18/2008)
# 8    Código dos Contratos Públicos ( DL 111-B/2017 )
# 9    Código dos Contratos Públicos ( DL 111-B/2017 )
# Name: regime, dtype: str

# %% [markdown]
# tipoFimContrato (object)

# %%
count_null_and_empty(df_2020, 'tipoFimContrato')
# Out:
# Null (NaN) values: 123891 (70.20%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020, 'tipoFimContrato', 10)
# Out:
# Top 10 most frequent values for 'tipoFimContrato':
# tipoFimContrato
# O cumprimento, a impossibilidade definitiva e todas as restantes causas de extinção das obrigações reconhecidas pelo direito civil    51253
# Resolução do Contrato                                                                                                                   686
# Revogação do Contrato                                                                                                                   485
# Anulado ou Declarado Nulo                                                                                                               143
# Contrato Anulado, Declarado Nulo ou Objecto de Recusa de Visto                                                                           30
# Name: count, dtype: int64

# %% [markdown]
# CritMateriais (object)

# %%
count_null_and_empty(df_2020, 'CritMateriais')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['CritMateriais'].head(10))
# Out:
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# 5    Não
# 6    Não
# 7    Não
# 8    Não
# 9    Não
# Name: CritMateriais, dtype: str

# %%
print_top_n(df_2020,"CritMateriais",20)
# Out:
# Top 20 most frequent values for 'CritMateriais':
# CritMateriais
# Não    136382
# Sim     40106
# Name: count, dtype: int64

# %% [markdown]
# concorrentes (object)

# %%
count_null_and_empty(df_2020, 'concorrentes')
# Out:
# Null (NaN) values: 115929 (65.69%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['concorrentes'].tail(10))
# Out:
# 176478    504853635-Cascais Próxima - Gestão de Mobilida...
# 176479                                                  NaN
# 176480                                                  NaN
# 176481                                                  NaN
# 176482    502584866-FINLOG\n502167610-LeasePlan Portugal...
# 176483                  509198520-HANNER &amp; HANNIEL, LDA
# 176484    514022876-Nonuslink - Telecomunicações e Infor...
# 176485    --José Abel Cantarinha Baptista Cunha\n5045366...
# 176486                            509981887-IT SQUARE, Lda.
# 176487    504282921-ROCHE SISTEMAS DE DIAGNOSTICOS, LDA ...
# Name: concorrentes, dtype: str

# %% [markdown]
# linkPecasProc (object)

# %%
count_null_and_empty(df_2020, 'linkPecasProc')
# Out:
# Null (NaN) values: 131055 (74.26%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Observacoes (object)

# %%
count_null_and_empty(df_2020, 'Observacoes')
# Out:
# Null (NaN) values: 167481 (94.90%)
# Empty string values: 216 (0.12%)

# %% [markdown]
# ContratEcologico (object)

# %%
count_null_and_empty(df_2020, 'ContratEcologico')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Ano (int64)

# %%
count_null_and_empty(df_2020, 'Ano')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2020['Ano'].head(10))
# Out:
# 0    2020
# 1    2020
# 2    2020
# 3    2020
# 4    2020
# 5    2020
# 6    2020
# 7    2020
# 8    2020
# 9    2020
# Name: Ano, dtype: int64

# %%
print_top_n(df_2020,"Ano",20)
# Out:
# Top 20 most frequent values for 'Ano':
# Ano
# 2020    176488
# Name: count, dtype: int64

# %% [markdown]
# fundamentAjusteDireto (object)

# %%
count_null_and_empty(df_2020, 'fundamentAjusteDireto')
# Out:
# Null (NaN) values: 98692 (55.92%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2020,'fundamentAjusteDireto',2)
# Out:
# Top 2 most frequent values for 'fundamentAjusteDireto':
# fundamentAjusteDireto
# ausência de recursos próprios    74566
# outros                            3230
# Name: count, dtype: int64

# %% [markdown]
# Informação geral

# %%
df_2020.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 176488 entries, 0 to 176487
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                176488 non-null  int64
#  1   nAnuncio                  17644 non-null   str
#  2   TipoAnuncio               17644 non-null   str
#  3   idINCM                    17644 non-null   float64
#  4   tipoContrato              176487 non-null  str
#  5   idprocedimento            176488 non-null  int64
#  6   tipoprocedimento          176488 non-null  str
#  7   objectoContrato           176488 non-null  object
#  8   descContrato              176488 non-null  object
#  9   adjudicante               176488 non-null  str
#  10  adjudicatarios            176195 non-null  str
#  11  dataPublicacao            176488 non-null  datetime64[us]
#  12  dataCelebracaoContrato    149769 non-null  datetime64[us]
# ...
