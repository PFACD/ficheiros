# %% [markdown]
# # Projeto Final Aplicado a Ciência de Dados
# ## Deteção de Outliers em Contratos Públicos e Previsão do Montante de Adjudição
#
# ## Grupo 08
# ## Membros:
# ###          - Afonso Alexandre nº 123425;
# ###          - André  Freitas nº 123409;
# ###          - Gonçalo Vilhena nº 123384;
# ###          - Rodolfo Nardy nº 123419

# %% [markdown]
# #### **Reading and checking data**

# %%
import pandas as pd

# %%
#Diretório onde os arquivos de dados do trabalho estão armazenados
data_dir = "./dados/"
df_2015 = pd.read_excel(data_dir + "contratos2015.xlsx")

# %% [markdown]
# ## Análise
#
#
# ### Funções auxiliares
#
# #### Função para os top X valores mais frequentes

# %%
def print_top_n(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate the top 'n' most frequent values
    top_n_values = df[column_name].value_counts().head(top_n)

    # Print the top 'n' values
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para os top X valores mais frequentes numa lista

# %%
def print_top_n_list(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Explode the lists into separate rows
    exploded = df[column_name].explode()

    # Calculate the top 'n' most frequent individual values
    top_n_values = exploded.value_counts().head(top_n)

    # Print the results
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para mostras os X menores valores menos frequentes

# %%
def print_bottom_n(df, column_name, bottom_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts and get the bottom 'n' values
    bottom_n_values = df[column_name].value_counts().sort_values(ascending=True).head(bottom_n)

    # Print the bottom 'n' values
    print(f"Bottom {bottom_n} least frequent values for '{column_name}':")

    print(bottom_n_values)

# %% [markdown]
#  #### Função para mostrar  X menores valores menos frequentes numa lista

# %% [markdown]
# #### Function to count null and empty values

# %%
def count_null_and_empty(df, column_name):
    total = len(df)

    # Count NaN (null) values
    null_count = df[column_name].isna().sum()
    null_pct = (null_count / total) * 100

    # Count empty string values (after stripping whitespace)
    empty_count = (df[column_name].astype(str).str.strip() == '').sum()
    empty_pct = (empty_count / total) * 100

    # Print results
    print(f"Null (NaN) values: {null_count} ({null_pct:.2f}%)")
    print(f"Empty string values: {empty_count} ({empty_pct:.2f}%)")

# %% [markdown]
# #### Informações gerais do ficheiro

# %%
df_2015.info()
df_2015.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 107635 entries, 0 to 107634
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                107635 non-null  int64
#  1   nAnuncio                  7678 non-null    str
#  2   TipoAnuncio               7678 non-null    str
#  3   idINCM                    7678 non-null    float64
#  4   tipoContrato              107626 non-null  str
#  5   idprocedimento            107635 non-null  int64
#  6   tipoprocedimento          107635 non-null  str
#  7   objectoContrato           107635 non-null  object
#  8   descContrato              107612 non-null  object
#  9   adjudicante               107632 non-null  str
#  10  adjudicatarios            107635 non-null  str
#  11  dataPublicacao            107635 non-null  datetime64[us]
#  12  dataCelebracaoContrato    107626 non-null  datetime64[us]
# ...

# %% [markdown]
# #### idcontrato (int64)

# %%
count_null_and_empty(df_2015, 'idcontrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
#não há repetidos
print_top_n(df_2015,"idcontrato",10)
# Out:
# Top 10 most frequent values for 'idcontrato':
# idcontrato
# 60239      1
# 1336744    1
# 1336799    1
# 1336802    1
# 1336813    1
# 1336816    1
# 27703      1
# 49954      1
# 1336741    1
# 1336742    1
# Name: count, dtype: int64

# %% [markdown]
# #### tipoContrato (object)

# %%
count_null_and_empty(df_2015, 'tipoContrato')
# Out:
# Null (NaN) values: 9 (0.01%)
# Empty string values: 0 (0.00%)

# %%
print_top_n_list(df_2015,"tipoContrato",10)
df_2015['tipoContrato'].unique()
# Out:
# Top 10 most frequent values for 'tipoContrato':
# tipoContrato
# Aquisição de bens móveis                           51471
# Aquisição de serviços                              41210
# Empreitadas de obras públicas                      12553
# Locação de bens móveis                              1051
# Aquisição de bens móveis\nAquisição de serviços      710
# Outros                                               167
# Aquisição de serviços\nLocação de bens móveis        130
# Concessão de obras públicas                           72
# Concessão de serviços públicos                        46
# Aquisição de bens móveis\nSociedade                   42
# Name: count, dtype: int64
# <StringArray>
# [                                                                             nan,
#                                                        'Aquisição de bens móveis',
#                                                   'Empreitadas de obras públicas',
# ...

# %% [markdown]
# #### idProcedimento (int64)

# %%
count_null_and_empty(df_2015, 'idprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,"idprocedimento",10)
df_2015[df_2015["idprocedimento"] == 1402513]
# Out:
# Top 10 most frequent values for 'idprocedimento':
# idprocedimento
# 1394211    59
# 1387251    58
# 1446367    38
# 1616310    35
# 1436809    33
# 1373264    32
# 2018206    32
# 1342734    30
# 1476517    28
# 1402513    27
# Name: count, dtype: int64
#        idcontrato nAnuncio TipoAnuncio  idINCM              tipoContrato  \
# 8646      1397436      NaN         NaN     NaN  Aquisição de bens móveis
# 8647      1397442      NaN         NaN     NaN  Aquisição de bens móveis
# 8665      1397504      NaN         NaN     NaN  Aquisição de bens móveis
# 8666      1397515      NaN         NaN     NaN  Aquisição de bens móveis
# 8678      1397554      NaN         NaN     NaN  Aquisição de bens móveis
# 8697      1397673      NaN         NaN     NaN  Aquisição de bens móveis
# 8846      1397457      NaN         NaN     NaN  Aquisição de bens móveis
# 8847      1397461      NaN         NaN     NaN  Aquisição de bens móveis
# ...

# %% [markdown]
# #### tipoprocedimento

# %%
count_null_and_empty(df_2015, 'tipoprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,"tipoprocedimento",10)  #(nem ha 10)
# Out:
# Top 10 most frequent values for 'tipoprocedimento':
# tipoprocedimento
# Ajuste Direto Regime Geral                   92400
# Concurso público                              7533
# Ao abrigo de acordo-quadro (art.º 259.º)      5905
# Ao abrigo de acordo-quadro (art.º 258.º)      1607
# Concurso limitado por prévia qualificação      188
# Procedimento de negociação                       2
# Name: count, dtype: int64

# %% [markdown]
# #### objectoContrato

# %%
count_null_and_empty(df_2015, 'objectoContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,"objectoContrato",20)
# Out:
# Top 20 most frequent values for 'objectoContrato':
# objectoContrato
# Formação                                                                                                                                                                                                     460
# Aquisição de reagentes                                                                                                                                                                                       406
# Medicamentos                                                                                                                                                                                                 401
# Aquisição de consumíveis                                                                                                                                                                                     316
# ...

# %% [markdown]
# #### descContrato (object)

# %%
count_null_and_empty(df_2015, 'descContrato')
# Out:
# Null (NaN) values: 23 (0.02%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,"descContrato",20)
# Out:
# Top 20 most frequent values for 'descContrato':
# descContrato
# Formador                                                     632
# Medicamentos                                                 360
# Ajuste direto                                                163
# Prestação de Serviços                                        159
# Contrato de Prestação de Serviços                            159
# Ajuste Direto                                                119
# Aquisição de serviços                                         97
# sem contrato escrito                                          92
# Prestação de serviços                                         72
# Contrato de empreitada                                        71
# AJUSTE DIRETO 05/2015                                         69
# CONTRATO DE PRESTAÇÃO DE SERVIÇOS                             69
# AQUISIÇÃO DE MATERIAL DE LIMPEZA                              67
# ...

# %% [markdown]
# adjudicante (object)

# %%
count_null_and_empty(df_2015, 'adjudicante')
# Out:
# Null (NaN) values: 3 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,"adjudicante",20)
# Out:
# Top 20 most frequent values for 'adjudicante':
# adjudicante
# 508142156 - Centro Hospitalar Vila Nova de Gaia - Espinho, E. P. E.                                7653
# 510745997 - Centro Hospitalar do Algarve, E. P. E.                                                 2405
# 510103448 - Centro Hospitalar e Universitário de Coimbra, E. P. E.                                 2260
# 508481287 - Centro Hospitalar Lisboa Norte, E. P. E.                                               2101
# 508080142 - Centro Hospitalar de Lisboa Central, E. P. E.                                          1585
# 510345271 - Instituto Nacional de Investigação Agrária e Veterinária, I. P.                        1361
# 509186998 - Centro Hospitalar Barreiro Montijo, E. P. E.                                           1233
# 500051070 - Município de Lisboa                                                                    1187
# ...

# %% [markdown]
# adjudicatarios (object)

# %%
count_null_and_empty(df_2015, 'adjudicatarios')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['adjudicatarios'].head(20))
# Out:
# 0                       - - Jaime Jorge Rocha Rodrigues
# 1     508472830 - Kedrion Portugal - Dist. Prod.Farm...
# 2                          505792362 - Overpharma, Lda.
# 3     502376899 - P.M.H. - PROD. MÉDICO-HOSPITALARES...
# 4               501895558 - H.R. PRODUTOS QUIMICOS, LDA
# 5              500684324 - Medicinália - Cormédica, Lda
# 6     505001764 - Electro Requetim – Distribuição de...
# 7            508080975 - Ricoh Portugal Unipessoal, Lda
# 8                          503047201 - CSL Behring, Lda
# 9                     502041285 - GRIFOLS PORTUGAL, LDA
# 10                               502820780 - OCTAPHARMA
# 11                                   500203130 - NORMAX
# 12                            508592909 - DOCWORLD, Lda
# 13                   504193279 - PRICEWATERHOUSECOOPERS
# 14    502480840 - Teletejo, Telecomunicações do Riba...
# 15    503365998 - CT Q- Projectos de Engenharia e Ge...
# 16                506229580 - Olímpia &amp; Filhos, Lda
# ...

# %% [markdown]
# dataPublicacao (object)

# %%
count_null_and_empty(df_2015, 'dataPublicacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['dataPublicacao'].head(10))
# Out:
# 0   2009-06-05
# 1   2015-01-02
# 2   2015-01-02
# 3   2015-01-02
# 4   2015-01-02
# 5   2015-01-02
# 6   2008-10-30
# 7   2009-05-07
# 8   2015-01-02
# 9   2015-01-02
# Name: dataPublicacao, dtype: datetime64[us]

# %% [markdown]
# dataCelebracaoContrato (object)

# %%
count_null_and_empty(df_2015, 'dataCelebracaoContrato')
# Out:
# Null (NaN) values: 9 (0.01%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['dataCelebracaoContrato'].head(10))
# Out:
# 0          NaT
# 1   2015-01-02
# 2   2015-01-02
# 3   2015-01-02
# 4   2015-01-02
# 5   2015-01-02
# 6          NaT
# 7          NaT
# 8   2015-01-02
# 9   2015-01-02
# Name: dataCelebracaoContrato, dtype: datetime64[us]

# %% [markdown]
# precoContratual (float64)

# %%
count_null_and_empty(df_2015, 'precoContratual')
min(df_2015['precoContratual'])
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)
# -74990.0

# %%
print(df_2015['precoContratual'].head(10))
# Out:
# 0     12000.00
# 1        40.50
# 2     21646.00
# 3     11647.50
# 4     16139.20
# 5     39400.00
# 6     36529.96
# 7      9760.00
# 8    600607.50
# 9    281238.60
# Name: precoContratual, dtype: float64

# %% [markdown]
# cpv (object)

# %%
count_null_and_empty(df_2015, 'CPV')
# Out:
# Null (NaN) values: 12 (0.01%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['CPV'].head(10))
# Out:
# 0                                    NaN
# 1    33600000-6 - Produtos farmacêuticos
# 2        33100000-1 - Equipamento médico
# 3        33100000-1 - Equipamento médico
# 4        33100000-1 - Equipamento médico
# 5        33100000-1 - Equipamento médico
# 6                                    NaN
# 7                                    NaN
# 8    33600000-6 - Produtos farmacêuticos
# 9    33600000-6 - Produtos farmacêuticos
# Name: CPV, dtype: str

# %% [markdown]
# prazoExecucao (int64)

# %%
count_null_and_empty(df_2015, 'prazoExecucao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015, 'prazoExecucao', 10)
# Out:
# Top 10 most frequent values for 'prazoExecucao':
# prazoExecucao
# 365     18246
# 30      10525
# 60       6035
# 1        5507
# 90       4764
# 5        3958
# 15       3948
# 20       3712
# 10       3112
# 1095     2631
# Name: count, dtype: int64

# %%
print_bottom_n(df_2015,'prazoExecucao',10)
# Out:
# Bottom 10 least frequent values for 'prazoExecucao':
# prazoExecucao
# 969     1
# 830     1
# 694     1
# 1040    1
# 1077    1
# 478     1
# 564     1
# 825     1
# 942     1
# 1041    1
# Name: count, dtype: int64

# %%
max_prazo_valor = df_2015['prazoExecucao'].max()
print("Maximum 'prazoExecucao (dias)':", max_prazo_valor)
print("Maximum 'prazoExecucao (anos)':", max_prazo_valor/365)
#impossível
# Out:
# Maximum 'prazoExecucao (dias)': 1202852
# Maximum 'prazoExecucao (anos)': 3295.4849315068495

# %% [markdown]
# localExecucao (object)

# %%
count_null_and_empty(df_2015, 'LocalExecucao')
# Out:
# Null (NaN) values: 7 (0.01%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['LocalExecucao'].head(10))
# Out:
# 0           Portugal, Vila Real, Chaves
# 1    Portugal, Porto, Vila Nova de Gaia
# 2    Portugal, Porto, Vila Nova de Gaia
# 3    Portugal, Porto, Vila Nova de Gaia
# 4    Portugal, Porto, Vila Nova de Gaia
# 5    Portugal, Porto, Vila Nova de Gaia
# 6                                   NaN
# 7                                   NaN
# 8    Portugal, Porto, Vila Nova de Gaia
# 9    Portugal, Porto, Vila Nova de Gaia
# Name: LocalExecucao, dtype: str

# %% [markdown]
# fundamentacao (object)

# %%
count_null_and_empty(df_2015, 'fundamentacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015, 'fundamentacao', 10)
# Out:
# Top 10 most frequent values for 'fundamentacao':
# fundamentacao
# Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos    60291
# Artigo 24.º, n.º 1, alínea e) do Código dos Contratos Públicos    10876
# Artigo 19.º, alínea a) do Código dos Contratos Públicos           10690
# Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos     6239
# Artigo 24.º, n.º 1, alínea c) do Código dos Contratos Públicos     5987
# Artigo 259.º do Código dos Contratos Públicos                      5278
# Artigo 19.º, alínea b) do Código dos Contratos Públicos            1541
# Artigo 258.º do Código dos Contratos Públicos                      1337
# Artigo 26.º, n.º 1, alínea e) do Código dos Contratos Públicos     1142
# Artigo 26.º, n.º 1, alínea a) do Código dos Contratos Públicos      525
# Name: count, dtype: int64

# %% [markdown]
# ProcedimentoCentralizado (object)

# %%
count_null_and_empty(df_2015, 'ProcedimentoCentralizado')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015, 'ProcedimentoCentralizado', 10)
# Out:
# Top 10 most frequent values for 'ProcedimentoCentralizado':
# ProcedimentoCentralizado
# Não    106865
# Sim       770
# Name: count, dtype: int64

# %% [markdown]
# DescrAcordoQuadro (object)

# %%
count_null_and_empty(df_2015, 'DescrAcordoQuadro')
# Out:
# Null (NaN) values: 100123 (93.02%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,"DescrAcordoQuadro",10)
# Out:
# Top 10 most frequent values for 'DescrAcordoQuadro':
# DescrAcordoQuadro
# Acordo quadro de licenciamento de software e serviços conexos                                                                                                                                                                                                                                                          489
# CONCURSO PÚBLICO PARA A CELEBRAÇÃO DE CONTRATOS PÚBLICOS DE APROVISIONAMENTO PARA A ÁREA DA SAÚDE, COM VISTA AO FORNECIMENTO DE MEDICAMENTOS DO FORO ONCOLÓGICO, ÀS INSTITUIÇÕES E SERVIÇOS DO SERVIÇO NACIONAL DE SAÚDE                                                                                               248
# ...

# %% [markdown]
# precoBaseProcedimento (float64)

# %%
count_null_and_empty(df_2015, 'precoBaseProcedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,"precoBaseProcedimento",10)
# Out:
# Top 10 most frequent values for 'precoBaseProcedimento':
# precoBaseProcedimento
# 0.0        7539
# 10000.0     802
# 15000.0     788
# 20000.0     633
# 75000.0     599
# 6000.0      567
# 30000.0     567
# 25000.0     563
# 12000.0     543
# 9000.0      500
# Name: count, dtype: int64

# %% [markdown]
# dataDecisaoAdjudicacao (object)

# %%
count_null_and_empty(df_2015, 'dataDecisaoAdjudicacao')
# Out:
# Null (NaN) values: 9 (0.01%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,"dataDecisaoAdjudicacao",20)
# Out:
# Top 20 most frequent values for 'dataDecisaoAdjudicacao':
# dataDecisaoAdjudicacao
# 2015-01-29    696
# 2015-01-22    652
# 2015-01-08    582
# 2014-12-30    579
# 2015-06-04    577
# 2015-01-14    572
# 2015-01-02    565
# 2015-03-05    565
# 2015-09-30    564
# 2015-05-21    558
# 2015-01-27    552
# 2015-12-04    550
# 2015-03-30    548
# 2015-01-28    543
# 2015-03-12    538
# 2015-02-26    532
# 2015-05-28    525
# 2015-07-02    518
# 2015-02-05    516
# 2015-06-08    516
# Name: count, dtype: int64

# %% [markdown]
# dataFechoContrato (object)

# %%
count_null_and_empty(df_2015, 'dataFechoContrato')
# Out:
# Null (NaN) values: 66781 (62.04%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,"dataFechoContrato",10)
# Out:
# Top 10 most frequent values for 'dataFechoContrato':
# dataFechoContrato
# 2015-12-31    8050
# 2015-12-30     708
# 2016-12-31     704
# 2015-09-30     399
# 2015-06-30     393
# 2015-12-18     340
# 2015-12-29     338
# 2015-12-28     318
# 2015-07-31     309
# 2016-08-31     304
# Name: count, dtype: int64

# %% [markdown]
# PrecoTotalEfetivo

# %%
count_null_and_empty(df_2015, 'PrecoTotalEfetivo')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['PrecoTotalEfetivo'].head(10))
# Out:
# 0    11220.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
# 5        0.00
# 6    36529.96
# 7     9760.00
# 8        0.00
# 9        0.00
# Name: PrecoTotalEfetivo, dtype: float64

# %%
print_top_n(df_2015,"PrecoTotalEfetivo",10)
# Out:
# Top 10 most frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 0.00        60267
# 46183.83      316
# 6000.00       170
# 15000.00      148
# 720.00        137
# 360.00        132
# 10000.00      126
# 7500.00       126
# 1500.00       119
# 12000.00      113
# Name: count, dtype: int64

# %%
print_bottom_n(df_2015,"PrecoTotalEfetivo",10)
# Out:
# Bottom 10 least frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 494531.59     1
# 2575.00       1
# 8122.76       1
# 209.70        1
# 139.50        1
# 94703.40      1
# 6482.70       1
# 854.99        1
# 2299000.00    1
# 653.40        1
# Name: count, dtype: int64

# %% [markdown]
# regime (object)

# %%
count_null_and_empty(df_2015, 'regime')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['regime'].head(10))
# Out:
# 0    Código dos Contratos Públicos (DL 18/2008)
# 1    Código dos Contratos Públicos (DL 18/2008)
# 2    Código dos Contratos Públicos (DL 18/2008)
# 3    Código dos Contratos Públicos (DL 18/2008)
# 4    Código dos Contratos Públicos (DL 18/2008)
# 5    Código dos Contratos Públicos (DL 18/2008)
# 6    Código dos Contratos Públicos (DL 18/2008)
# 7    Código dos Contratos Públicos (DL 18/2008)
# 8    Código dos Contratos Públicos (DL 18/2008)
# 9    Código dos Contratos Públicos (DL 18/2008)
# Name: regime, dtype: str

# %% [markdown]
# tipoFimContrato (object)

# %%
count_null_and_empty(df_2015, 'tipoFimContrato')
# Out:
# Null (NaN) values: 59618 (55.39%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015, 'tipoFimContrato', 10)
# Out:
# Top 10 most frequent values for 'tipoFimContrato':
# tipoFimContrato
# O cumprimento, a impossibilidade definitiva e todas as restantes causas de extinção das obrigações reconhecidas pelo direito civil    46924
# Resolução do Contrato                                                                                                                   866
# Revogação do Contrato                                                                                                                   189
# Anulado ou Declarado Nulo                                                                                                                26
# Contrato Anulado, Declarado Nulo ou Objecto de Recusa de Visto                                                                           10
# Objeto de recusa de visto do Tribunal de Contas                                                                                           2
# Name: count, dtype: int64

# %% [markdown]
# CritMateriais (object)

# %%
count_null_and_empty(df_2015, 'CritMateriais')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['CritMateriais'].head(10))
# Out:
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# 5    Não
# 6    Não
# 7    Não
# 8    Não
# 9    Não
# Name: CritMateriais, dtype: str

# %%
print_top_n(df_2015,"CritMateriais",20)
# Out:
# Top 20 most frequent values for 'CritMateriais':
# CritMateriais
# Não    107635
# Name: count, dtype: int64

# %% [markdown]
# concorrentes (object)

# %%
count_null_and_empty(df_2015, 'concorrentes')
# Out:
# Null (NaN) values: 80426 (74.72%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['concorrentes'].tail(10))
# Out:
# 107625    503222364-SSTIC - Tecnologia de Informação e C...
# 107626                 507946839-Oficina de Conceitos, Lda.
# 107627         980079659-Informática El Corte Inglês, S. A.
# 107628       500229147-REGRA - Sistemas de Informação, S.A.
# 107629    509067913-PRATIKRIGOR, Manutenção e Instalaçõe...
# 107630    980079659-INFORMATICA EL CORTE INGLES\n5013334...
# 107631    507928210-Caetano Coatings, S.A.\n503439304-PR...
# 107632                                                  NaN
# 107633    980079659-INFORMATICA EL CORTE INGLES\n5013334...
# 107634     506035638-Corte &amp; Terra, Terraplanagens, Lda
# Name: concorrentes, dtype: str

# %% [markdown]
# linkPecasProc (object)

# %%
count_null_and_empty(df_2015, 'linkPecasProc')
# Out:
# Null (NaN) values: 107635 (100.00%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Observacoes (object)

# %%
count_null_and_empty(df_2015, 'Observacoes')
# Out:
# Null (NaN) values: 104430 (97.02%)
# Empty string values: 36 (0.03%)

# %% [markdown]
# ContratEcologico (object)

# %%
count_null_and_empty(df_2015, 'ContratEcologico')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Ano (int64)

# %%
count_null_and_empty(df_2015, 'Ano')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2015['Ano'].head(10))
# Out:
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# 5    2015
# 6    2015
# 7    2015
# 8    2015
# 9    2015
# Name: Ano, dtype: int64

# %% [markdown]
# fundamentAjusteDireto (object)

# %%
count_null_and_empty(df_2015, 'fundamentAjusteDireto')
# Out:
# Null (NaN) values: 61260 (56.91%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2015,'fundamentAjusteDireto',2)
# Out:
# Top 2 most frequent values for 'fundamentAjusteDireto':
# fundamentAjusteDireto
# ausência de recursos próprios    44737
# outros                            1638
# Name: count, dtype: int64

# %% [markdown]
# Informação geral

# %%
df_2015.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 107635 entries, 0 to 107634
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                107635 non-null  int64
#  1   nAnuncio                  7678 non-null    str
#  2   TipoAnuncio               7678 non-null    str
#  3   idINCM                    7678 non-null    float64
#  4   tipoContrato              107626 non-null  str
#  5   idprocedimento            107635 non-null  int64
#  6   tipoprocedimento          107635 non-null  str
#  7   objectoContrato           107635 non-null  object
#  8   descContrato              107612 non-null  object
#  9   adjudicante               107632 non-null  str
#  10  adjudicatarios            107635 non-null  str
#  11  dataPublicacao            107635 non-null  datetime64[us]
#  12  dataCelebracaoContrato    107626 non-null  datetime64[us]
# ...
