# %% [markdown]
# # Projeto Final Aplicado a Ciência de Dados
# ## Deteção de Outliers em Contratos Públicos e Previsão do Montante de Adjudição
#
# ## Grupo 08
# ## Membros:
# ###          - Afonso Alexandre nº 123425;
# ###          - André  Freitas nº 123409;
# ###          - Gonçalo Vilhena nº 123384;
# ###          - Rodolfo Nardy nº 123419

# %% [markdown]
# #### **Reading and checking data**

# %%
import pandas as pd

# %%
#Diretório onde os arquivos de dados do trabalho estão armazenados
data_dir = "./dados/"
df_2022 = pd.read_excel(data_dir + "contratos2022.xlsx")

# %% [markdown]
# ## Análise
#
#
# ### Funções auxiliares
#
# #### Função para os top X valores mais frequentes

# %%
def print_top_n(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate the top 'n' most frequent values
    top_n_values = df[column_name].value_counts().head(top_n)

    # Print the top 'n' values
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para os top X valores mais frequentes numa lista

# %%
def print_top_n_list(df, column_name, top_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Explode the lists into separate rows
    exploded = df[column_name].explode()

    # Calculate the top 'n' most frequent individual values
    top_n_values = exploded.value_counts().head(top_n)

    # Print the results
    print(f"Top {top_n} most frequent values for '{column_name}':")
    print(top_n_values)

# %% [markdown]
# #### Função para mostras os X menores valores menos frequentes

# %%
def print_bottom_n(df, column_name, bottom_n=20):
    if column_name not in df.columns:
        print(f"Column '{column_name}' not found in the DataFrame.")
        return

    # Calculate value counts and get the bottom 'n' values
    bottom_n_values = df[column_name].value_counts().sort_values(ascending=True).head(bottom_n)

    # Print the bottom 'n' values
    print(f"Bottom {bottom_n} least frequent values for '{column_name}':")

    print(bottom_n_values)

# %% [markdown]
#  #### Função para mostrar  X menores valores menos frequentes numa lista

# %% [markdown]
# #### Function to count null and empty values

# %%
def count_null_and_empty(df, column_name):
    total = len(df)

    # Count NaN (null) values
    null_count = df[column_name].isna().sum()
    null_pct = (null_count / total) * 100

    # Count empty string values (after stripping whitespace)
    empty_count = (df[column_name].astype(str).str.strip() == '').sum()
    empty_pct = (empty_count / total) * 100

    # Print results
    print(f"Null (NaN) values: {null_count} ({null_pct:.2f}%)")
    print(f"Empty string values: {empty_count} ({empty_pct:.2f}%)")

# %% [markdown]
# #### Informações gerais do ficheiro

# %%
df_2022.info()
df_2022.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176506 entries, 0 to 176505
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   idcontrato                176506 non-null  int64
#  1   nAnuncio                  22592 non-null   object
#  2   TipoAnuncio               22592 non-null   object
#  3   idINCM                    22592 non-null   float64
#  4   tipoContrato              176501 non-null  object
#  5   idprocedimento            176506 non-null  int64
#  6   tipoprocedimento          176506 non-null  object
#  7   objectoContrato           176506 non-null  object
#  8   descContrato              176506 non-null  object
#  9   adjudicante               176506 non-null  object
#  10  adjudicatarios            176090 non-null  object
#  11  dataPublicacao            176506 non-null  datetime64[ns]
#  12  dataCelebracaoContrato    174064 non-null  datetime64[ns]
# ...

# %% [markdown]
# #### idcontrato (int64)

# %%
count_null_and_empty(df_2022, 'idcontrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
#não há repetidos
print_top_n(df_2022,"idcontrato",10)
# Out:
# Top 10 most frequent values for 'idcontrato':
# idcontrato
# 9090025    2
# 9428110    2
# 9629160    2
# 9677509    2
# 9722987    2
# 9731216    2
# 9731794    2
# 9740624    2
# 9797190    2
# 9798413    2
# Name: count, dtype: int64

# %% [markdown]
# #### tipoContrato (object)

# %%
count_null_and_empty(df_2022, 'tipoContrato')
# Out:
# Null (NaN) values: 5 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n_list(df_2022,"tipoContrato",10)
df_2022['tipoContrato'].unique()
# Out:
# Top 10 most frequent values for 'tipoContrato':
# tipoContrato
# Aquisição de bens móveis                           51471
# Aquisição de serviços                              41210
# Empreitadas de obras públicas                      12553
# Locação de bens móveis                              1051
# Aquisição de bens móveis\nAquisição de serviços      710
# Outros                                               167
# Aquisição de serviços\nLocação de bens móveis        130
# Concessão de obras públicas                           72
# Concessão de serviços públicos                        46
# Aquisição de bens móveis\nSociedade                   42
# Name: count, dtype: int64
# <StringArray>
# [                                                                             nan,
#                                                        'Aquisição de bens móveis',
#                                                   'Empreitadas de obras públicas',
# ...

# %% [markdown]
# #### idProcedimento (int64)

# %%
count_null_and_empty(df_2022, 'idprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,"idprocedimento",10)
# Out:
# Top 10 most frequent values for 'idprocedimento':
# idprocedimento
# 6069067    261
# 5785758    240
# 5833262    208
# 5862006    203
# 5925921    196
# 6210856    153
# 5956425    153
# 5744947    150
# 5848300    139
# 6038685    132
# Name: count, dtype: int64

# %% [markdown]
# #### tipoprocedimento

# %%
count_null_and_empty(df_2022, 'tipoprocedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,"tipoprocedimento",10)  #(nem ha 10)
# Out:
# Top 10 most frequent values for 'tipoprocedimento':
# tipoprocedimento
# Ajuste Direto Regime Geral                                           90276
# Consulta Prévia                                                      36718
# Concurso público                                                     22334
# Ao abrigo de acordo-quadro (art.º 259.º)                             18972
# Ao abrigo de acordo-quadro (art.º 258.º)                              4720
# Ajuste direto simplificado                                            2217
# Contratação excluída II                                                354
# Concurso limitado por prévia qualificação                              298
# Consulta Prévia Simplificada                                           270
# Ajuste direto simplificado ao abrigo da Lei n.º 30/2021, de 21.05      225
# Name: count, dtype: int64

# %% [markdown]
# #### objectoContrato

# %%
count_null_and_empty(df_2022, 'objectoContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,"objectoContrato",20)
# Out:
# Top 20 most frequent values for 'objectoContrato':
# objectoContrato
# MEDICAMENTOS                                                                                                                                                                                                1107
# 112/2022                                                                                                                                                                                                     249
# P259-2022-028 - Convite ao abrigo do(s) acordo(s)-quadro CP 2021/6 - Medicamentos do Foro Oncológico e  Imunomoduladores,  CP 2020/61 - Medicamentos Diversos, CP 2019/55 - Medicamentos Diversos, CP 20     233
# REAGENTES                                                                                                                                                                                                    210
# ...

# %% [markdown]
# #### descContrato (object)

# %%
count_null_and_empty(df_2022, 'descContrato')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,"descContrato",20)
# Out:
# Top 20 most frequent values for 'descContrato':
# descContrato
# Formador                                                     632
# Medicamentos                                                 360
# Ajuste direto                                                163
# Prestação de Serviços                                        159
# Contrato de Prestação de Serviços                            159
# Ajuste Direto                                                119
# Aquisição de serviços                                         97
# sem contrato escrito                                          92
# Prestação de serviços                                         72
# Contrato de empreitada                                        71
# AJUSTE DIRETO 05/2015                                         69
# CONTRATO DE PRESTAÇÃO DE SERVIÇOS                             69
# AQUISIÇÃO DE MATERIAL DE LIMPEZA                              67
# ...

# %% [markdown]
# adjudicante (object)

# %%
count_null_and_empty(df_2022, 'adjudicante')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,"adjudicante",20)
# Out:
# Top 20 most frequent values for 'adjudicante':
# adjudicante
# 506362299 - Instituto Português de Oncologia do Porto Francisco Gentil, E. P. E.        7181
# 509822940 - Centro Hospitalar Tondela-Viseu, E. P. E.                                   4736
# 508481287 - Centro Hospitalar Universitário de Lisboa Norte, E. P. E.                   3283
# 600012662 - Ministério da Defesa Nacional - Marinha                                     3253
# 600010180 - Estado-Maior-General das Forças Armadas (EMGFA)                             2646
# 510103448 - Centro Hospitalar e Universitário de Coimbra, E. P. E.                      2129
# 508094461 - Unidade Local de Saúde do Norte Alentejano, E. P. E.                        2129
# 506361470 - Hospital Garcia de Orta, E. P. E.                                           2083
# 510745997 - Centro Hospitalar Universitário do Algarve, E. P. E.                        1947
# ...

# %% [markdown]
# adjudicatarios (object)

# %%
count_null_and_empty(df_2022, 'adjudicatarios')
# Out:
# Null (NaN) values: 416 (0.24%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['adjudicatarios'].head(20))
# Out:
# 0      506093190 - Penasegur - Mediação de Seguros, Lda
# 1                               - - José Costa Teixeira
# 2                           - - Fernando Vieira Pacheco
# 3                                - - António José Pinto
# 4                             - - José Teixeira Moreira
# 5                 515083704 - ADSTERPT, Unipessoal Lda.
# 6                            503653179 - NAUTILUS, S.A.
# 7     500203261 - NORTECNICA-REPRESENTAÇÃO E TÉCNICA...
# 8     500990255 - ALDINI - Sociedade de Importações,...
# 9         507443080 - Combigal - Combustiveis e Gás Lda
# 10           514274557 - Kforcek-Segurança Privada, S.A
# 11                500013810 -  Albino Dias Andrade; Lda
# 12                         - - Sabrina Magalhães Araujo
# 13                        504918052 - Pragosa Betão, SA
# 14    503140600 - Primavera Business Software Soluti...
# 15    507675100 - CONTIPAPER - ARTIGOS DE PAPELARIA ...
# 16    515137049 - Significativa Paisagem Engenharia ...
# ...

# %% [markdown]
# dataPublicacao (object)

# %%
count_null_and_empty(df_2022, 'dataPublicacao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['dataPublicacao'].head(10))
# Out:
# 0   2022-01-01
# 1   2022-01-02
# 2   2022-01-02
# 3   2022-01-02
# 4   2022-01-02
# 5   2022-01-03
# 6   2022-01-03
# 7   2022-01-03
# 8   2022-01-03
# 9   2022-01-03
# Name: dataPublicacao, dtype: datetime64[ns]

# %% [markdown]
# dataCelebracaoContrato (object)

# %%
count_null_and_empty(df_2022, 'dataCelebracaoContrato')
# Out:
# Null (NaN) values: 2442 (1.38%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['dataCelebracaoContrato'].head(10))
# Out:
# 0          NaT
# 1   2015-01-02
# 2   2015-01-02
# 3   2015-01-02
# 4   2015-01-02
# 5   2015-01-02
# 6          NaT
# 7          NaT
# 8   2015-01-02
# 9   2015-01-02
# Name: dataCelebracaoContrato, dtype: datetime64[us]

# %% [markdown]
# precoContratual (float64)

# %%
count_null_and_empty(df_2022, 'precoContratual')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['precoContratual'].head(10))
# Out:
# 0      773.28
# 1     7163.16
# 2    10200.00
# 3     7800.00
# 4     7980.00
# 5    10638.98
# 6     7956.00
# 7    68264.36
# 8    65700.00
# 9     6200.00
# Name: precoContratual, dtype: float64

# %% [markdown]
# cpv (object)

# %%
count_null_and_empty(df_2022, 'CPV')
# Out:
# Null (NaN) values: 5 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['CPV'].head(10))
# Out:
# 0        66512100-3 - Serviços de seguros de acidentes
# 1    77311000-3 - Serviços de manutenção de jardins...
# 2             90611000-3 - Serviços de limpeza de ruas
# 3             90611000-3 - Serviços de limpeza de ruas
# 4             90611000-3 - Serviços de limpeza de ruas
# 5    50800000-3 - Serviços de reparação e manutençã...
# 6            30195500-7 - Quadros de giz ou acessórios
# 7                    31711000-3 - Material electrónico
# 8    50110000-9 - Serviços de reparação e manutençã...
# 9                             09122100-1 - Gás propano
# Name: CPV, dtype: object

# %% [markdown]
# prazoExecucao (int64)

# %%
count_null_and_empty(df_2022, 'prazoExecucao')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022, 'prazoExecucao', 10)
# Out:
# Top 10 most frequent values for 'prazoExecucao':
# prazoExecucao
# 365     27243
# 30      14066
# 20      11834
# 1        7716
# 1096     6584
# 60       6298
# 90       5401
# 5        3594
# 92       3311
# 15       3215
# Name: count, dtype: int64

# %%
print_bottom_n(df_2022,'prazoExecucao',10)
# Out:
# Bottom 10 least frequent values for 'prazoExecucao':
# prazoExecucao
# 3150      1
# 1682      1
# 21912     1
# 399       1
# 1155      1
# 120529    1
# 1215      1
# 121990    1
# 133314    1
# 765       1
# Name: count, dtype: int64

# %%
max_prazo_valor = df_2022['prazoExecucao'].max()
print("Maximum 'prazoExecucao (dias)':", max_prazo_valor)
print("Maximum 'prazoExecucao (anos)':", max_prazo_valor/365)
#impossível
# Out:
# Maximum 'prazoExecucao (dias)': 738521
# Maximum 'prazoExecucao (anos)': 2023.345205479452

# %% [markdown]
# localExecucao (object)

# %%
count_null_and_empty(df_2022, 'LocalExecucao')
# Out:
# Null (NaN) values: 2192 (1.24%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['LocalExecucao'].head(10))
# Out:
# 0                   Portugal, Aveiro, Castelo de Paiva
# 1                          Portugal, Porto, Felgueiras
# 2                   Portugal, Porto, Paços de Ferreira
# 3                               Portugal, Porto, Baião
# 4                          Portugal, Porto, Felgueiras
# 5                             Portugal, Lisboa, Lisboa
# 6                           Portugal, Setúbal, Setúbal
# 7    Portugal, Setúbal, Montijo\nPortugal, Setúbal,...
# 8                            Portugal, Lisboa, Cascais
# 9               Portugal, Guarda, Fig. Castelo Rodrigo
# Name: LocalExecucao, dtype: object

# %% [markdown]
# fundamentacao (object)

# %%
count_null_and_empty(df_2022, 'fundamentacao')
# Out:
# Null (NaN) values: 2446 (1.39%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022, 'fundamentacao', 10)
# Out:
# Top 10 most frequent values for 'fundamentacao':
# fundamentacao
# Artigo 20.º, n.º 1, alínea d) do Código dos Contratos Públicos                    39014
# Artigo 20.º, n.º 1, alínea c) do Código dos Contratos Públicos                    30523
# Artigo 259.º do Código dos Contratos Públicos                                     18526
# Artigo 24.º, n.º 1, alínea c) do Código dos Contratos Públicos                    16324
# Artigo 24.º, n.º 1, alínea e), subalínea ii) do Código dos Contratos Públicos     11331
# Artigo 20.º, n.º 1, alínea b) do Código dos Contratos Públicos                    11301
# Artigo 24.º, n.º 1, alínea e), subalínea iii) do Código dos Contratos Públicos     6751
# Artigo 20.º, n.º 1, alínea a) do Código dos Contratos Públicos                     6722
# Artigo 19.º, alínea c) do Código dos Contratos Públicos                            3637
# Artigo 258.º do Código dos Contratos Públicos                                      3164
# Name: count, dtype: int64

# %% [markdown]
# ProcedimentoCentralizado (object)

# %%
count_null_and_empty(df_2022, 'ProcedimentoCentralizado')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022, 'ProcedimentoCentralizado', 10)
# Out:
# Top 10 most frequent values for 'ProcedimentoCentralizado':
# ProcedimentoCentralizado
# Não    168328
# Sim      8178
# Name: count, dtype: int64

# %% [markdown]
# DescrAcordoQuadro (object)

# %%
count_null_and_empty(df_2022, 'DescrAcordoQuadro')
# Out:
# Null (NaN) values: 153616 (87.03%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,"DescrAcordoQuadro",10)
# Out:
# Top 10 most frequent values for 'DescrAcordoQuadro':
# DescrAcordoQuadro
# CP 2021/6 - Medicamentos do foro oncológico e imunomoduladores                                                                                                       4435
# CP 2021/47 - Medicamentos do aparelho locomotor, usados no tratamento das doenças endócrinas e hormonas                                                               984
# CP 2021/55 - Medicamentos diversos                                                                                                                                    826
# CP 2019/40 - Medicamentos antirretrovíricos para o tratamento da infeção por VIH                                                                                      630
# CP 2022/40 - Medicamentos antirretrovíricos para o tratamento da infeção por VIH                                                                                      616
# ...

# %% [markdown]
# precoBaseProcedimento (float64)

# %%
count_null_and_empty(df_2022, 'precoBaseProcedimento')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,"precoBaseProcedimento",10)
# Out:
# Top 10 most frequent values for 'precoBaseProcedimento':
# precoBaseProcedimento
# 0.0        7821
# 15000.0    1095
# 10000.0    1040
# 6000.0      913
# 12000.0     893
# 18000.0     890
# 20000.0     811
# 9000.0      781
# 30000.0     738
# 19500.0     599
# Name: count, dtype: int64

# %% [markdown]
# dataDecisaoAdjudicacao (object)

# %%
count_null_and_empty(df_2022, 'dataDecisaoAdjudicacao')
# Out:
# Null (NaN) values: 2438 (1.38%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,"dataDecisaoAdjudicacao",20)
# Out:
# Top 20 most frequent values for 'dataDecisaoAdjudicacao':
# dataDecisaoAdjudicacao
# 2022-02-24    1180
# 2022-02-03    1180
# 2022-02-10    1177
# 2022-01-20    1110
# 2022-03-17    1105
# 2022-02-17    1063
# 2022-03-03    1060
# 2022-01-13    1032
# 2022-01-27    1028
# 2022-03-10    1021
# 2022-02-09    1018
# 2022-03-31     992
# 2022-05-12     975
# 2022-03-23     945
# 2022-02-16     944
# 2022-03-09     944
# 2022-06-30     936
# 2022-07-07     922
# 2022-04-21     921
# 2022-05-05     921
# Name: count, dtype: int64

# %% [markdown]
# dataFechoContrato (object)

# %%
count_null_and_empty(df_2022, 'dataFechoContrato')
# Out:
# Null (NaN) values: 107527 (60.92%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,"dataFechoContrato",10)
# Out:
# Top 10 most frequent values for 'dataFechoContrato':
# dataFechoContrato
# 2022-12-31    6197
# 2022-12-30    2087
# 2022-12-29    1209
# 2022-12-27     777
# 2022-12-22     721
# 2022-12-20     669
# 2022-12-28     649
# 2023-12-31     607
# 2022-12-21     526
# 2023-12-29     509
# Name: count, dtype: int64

# %% [markdown]
# PrecoTotalEfetivo

# %%
count_null_and_empty(df_2022, 'PrecoTotalEfetivo')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['PrecoTotalEfetivo'].head(10))
# Out:
# 0      773.28
# 1     7163.18
# 2    10200.00
# 3     7800.00
# 4     7980.00
# 5        0.00
# 6        0.00
# 7        0.00
# 8    29183.41
# 9        0.00
# Name: PrecoTotalEfetivo, dtype: float64

# %%
print_top_n(df_2022,"PrecoTotalEfetivo",10)
# Out:
# Top 10 most frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 0.0        108415
# 6000.0        329
# 12000.0       305
# 9000.0        287
# 15000.0       285
# 10000.0       277
# 18000.0       258
# 7500.0        214
# 8000.0        191
# 19900.0       178
# Name: count, dtype: int64

# %%
print_bottom_n(df_2022,"PrecoTotalEfetivo",10)
# Out:
# Bottom 10 least frequent values for 'PrecoTotalEfetivo':
# PrecoTotalEfetivo
# 157.45       1
# 6512.07      1
# 2060.45      1
# 5098.72      1
# 166596.00    1
# 3830.00      1
# 2273.98      1
# 109.00       1
# 5040.40      1
# 972.98       1
# Name: count, dtype: int64

# %% [markdown]
# regime (object)

# %%
count_null_and_empty(df_2022, 'regime')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['regime'].head(10))
# Out:
# 0      Código dos Contratos Públicos ( DL 111-B/2017 )
# 1      Código dos Contratos Públicos ( DL 111-B/2017 )
# 2      Código dos Contratos Públicos ( DL 111-B/2017 )
# 3      Código dos Contratos Públicos ( DL 111-B/2017 )
# 4      Código dos Contratos Públicos ( DL 111-B/2017 )
# 5    Código dos Contratos Públicos (DL111-B/2017) e...
# 6    Código dos Contratos Públicos (DL111-B/2017) e...
# 7      Código dos Contratos Públicos ( DL 111-B/2017 )
# 8    Código dos Contratos Públicos (DL111-B/2017) e...
# 9      Código dos Contratos Públicos ( DL 111-B/2017 )
# Name: regime, dtype: object

# %% [markdown]
# tipoFimContrato (object)

# %%
count_null_and_empty(df_2022, 'tipoFimContrato')
# Out:
# Null (NaN) values: 109979 (62.31%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022, 'tipoFimContrato', 10)
# Out:
# Top 10 most frequent values for 'tipoFimContrato':
# tipoFimContrato
# O cumprimento, a impossibilidade definitiva e todas as restantes causas de extinção das obrigações reconhecidas pelo direito civil    64952
# Resolução do Contrato                                                                                                                   790
# Revogação do Contrato                                                                                                                   673
# Anulado ou Declarado Nulo                                                                                                                76
# Contrato Anulado, Declarado Nulo ou Objecto de Recusa de Visto                                                                           35
# Objeto de recusa de visto do Tribunal de Contas                                                                                           1
# Name: count, dtype: int64

# %% [markdown]
# CritMateriais (object)

# %%
count_null_and_empty(df_2022, 'CritMateriais')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['CritMateriais'].head(10))
# Out:
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# 5    Não
# 6    Não
# 7    Não
# 8    Não
# 9    Não
# Name: CritMateriais, dtype: object

# %%
print_top_n(df_2022,"CritMateriais",20)
# Out:
# Top 20 most frequent values for 'CritMateriais':
# CritMateriais
# Não    139129
# Sim     37377
# Name: count, dtype: int64

# %% [markdown]
# concorrentes (object)

# %%
count_null_and_empty(df_2022, 'concorrentes')
# Out:
# Null (NaN) values: 87045 (49.32%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['concorrentes'].tail(10))
# Out:
# 176496    515007897-MASTER - INVITRO - COMERCIALIZAÇÃO D...
# 176497                          510664024-ASSOCIAÇÃO DNS.PT
# 176498                                                  NaN
# 176499    500960410-APQ - ASSOCIAÇÃO PORTUGUESA PARA A Q...
# 176500    502167610-LeasePlan Portugal – Comércio e Alug...
# 176501    509174094-MNTC – SERVIÇOS TÉCNICOS DE ENGENHAR...
# 176502    503504564-EDP Comercial, SA\n500099790-Oz Ener...
# 176503    504615947-1 - MEO - SERVIÇOS DE COMUNICAÇÕES E...
# 176504            501990941-Construções Abílio &amp; Serras
# 176505    510342191-Entidade de Serviços Partilhados da ...
# Name: concorrentes, dtype: object

# %% [markdown]
# linkPecasProc (object)

# %%
count_null_and_empty(df_2022, 'linkPecasProc')
# Out:
# Null (NaN) values: 95434 (54.07%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Observacoes (object)

# %%
count_null_and_empty(df_2022, 'Observacoes')
# Out:
# Null (NaN) values: 169938 (96.28%)
# Empty string values: 111 (0.06%)

# %% [markdown]
# ContratEcologico (object)

# %%
count_null_and_empty(df_2022, 'ContratEcologico')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %% [markdown]
# Ano (int64)

# %%
count_null_and_empty(df_2022, 'Ano')
# Out:
# Null (NaN) values: 0 (0.00%)
# Empty string values: 0 (0.00%)

# %%
print(df_2022['Ano'].head(10))
# Out:
# 0    2022
# 1    2022
# 2    2022
# 3    2022
# 4    2022
# 5    2022
# 6    2022
# 7    2022
# 8    2022
# 9    2022
# Name: Ano, dtype: int64

# %% [markdown]
# fundamentAjusteDireto (object)

# %%
count_null_and_empty(df_2022, 'fundamentAjusteDireto')
# Out:
# Null (NaN) values: 87796 (49.74%)
# Empty string values: 0 (0.00%)

# %%
print_top_n(df_2022,'fundamentAjusteDireto',2)
# Out:
# Top 2 most frequent values for 'fundamentAjusteDireto':
# fundamentAjusteDireto
# ausência de recursos próprios    84194
# outros                            4516
# Name: count, dtype: int64

# %% [markdown]
# Informação geral

# %%
df_2022.info(verbose=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 107635 entries, 0 to 107634
# Data columns (total 59 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   idcontrato                     107635 non-null  int64
#  1   nAnuncio                       7678 non-null    str
#  2   TipoAnuncio                    7678 non-null    str
#  3   idINCM                         7678 non-null    float64
#  4   tipoContrato                   107626 non-null  str
#  5   idprocedimento                 107635 non-null  int64
#  6   tipoprocedimento               107635 non-null  str
#  7   objectoContrato                107635 non-null  object
#  8   descContrato                   107612 non-null  string
#  9   adjudicante                    107632 non-null  str
#  10  adjudicatarios                 107635 non-null  str
#  11  dataPublicacao                 107635 non-null  string
# ...
